# %%
import requests
import pyspark.sql.functions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import statsmodels.api as sm
import sklearn
import statsmodels
import sodapy
from statsmodels.formula.api import ols
from sklearn.impute import SimpleImputer
from pyspark.sql.functions import *
from pyspark.sql.types import StringType,DecimalType
from pyspark.sql.functions import input_file_name, substring
from pyspark.sql.functions import isnan, when, count, col
from sodapy import Socrata

# Importing important info
from config import database, server, k_username, k_password

# %%
requests.__version__, pyspark.__version__, pd.__version__, np.__version__, scipy.__version__, statsmodels.__version__, sklearn.__version__, sodapy.__version__
# Out:
# Out[39]: ('2.28.1', '3.3.0', '1.3.4', '1.20.3', '1.7.1', '0.12.2', '0.24.2', '2.2.0')

# %%
###### Mount Point 1 through Oauth security.
storageAccount = "gen10datafund2207"
storageContainer = "healthcare-capstone-group3"
clientSecret = "Cty8Q~AvEO_qC-MjvPvosYauiNsffOHKnMpj7cmd"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/healthcare/modeldataIn" # the mount point will be unique to you

configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

dbutils.fs.mount(
source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
mount_point = mount_point,
extra_configs = configs)
# Out:
# /mnt/healthcare/modeldataIn has been unmounted.
# Out[2]: True

# %%
display(dbutils.fs.ls("/mnt/healthcare/modeldataIn/ModelData"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/healthcare/modeldataIn/ModelData/Demographics Test Data 2020.csv</td><td>Demographics Test Data 2020.csv</td><td>3303579</td><td>1664465328000</td></tr><tr><td>dbfs:/mnt/healthcare/modeldataIn/ModelData/Health Insurance Characteristics 2015.csv</td><td>Health Insurance Characteristics 2015.csv</td><td>1484769</td><td>1664223416000</td></tr><tr><td>dbfs:/mnt/healthcare/modeldataIn/ModelData/Health Insurance Characteristics 2016.csv</td><td>Health Insurance Characteristics 2016.csv</td><td>1484129</td><td>1664223416000</td></tr><tr><td>dbfs:/mnt/healthcare/modeldataIn/ModelData/Health Insurance Characteristics 2017.csv</td><td>Health Insurance Characteristics 2017.csv</td><td>1473853</td><td>1664223416000</td></tr><tr><td>dbfs:/mnt/healthcare/modeldataIn/ModelData/Health Insurance Characteristics 2018.csv</td><td>Health Insurance Characteristics 2018.csv</td><td>1476522</td><td>1664223416000</td></tr><tr><td>dbfs:/mnt/healthcare/modeldataIn/ModelData/Health Insurance Characteristics.csv</td><td>Health Insurance Characteristics.csv</td><td>1480572</td><td>1664374667000</td></tr></tbody></table></div>

# %% [markdown]
# **Cleaning Health15 Dataset**

# %%
health15 = spark.read.options(header = 'True').csv("/mnt/healthcare/modeldataIn/ModelData/Health Insurance Characteristics 2015.csv").toPandas()

# Counting and dropping all null values within each dataset
health15.dropna(inplace = True)

# Resetting the index for each dataset
rows = []
for i in range(0, health15.shape[0]):
    rows.append(i)

health15[''] = rows
health15 = health15.set_index('')

Category = []

for i in health15['Label (Grouping)']:
    Category.append(i.strip())

health15['Label (Grouping)'] = Category

newcolumns15 = list(health15['Label (Grouping)'])

# Transposing so the states become the rows and the categories become the columns
health15 = health15.transpose()

categories = list(health15.index)[1:]
Counties = ['County']
States = ['State']
Insurance = ['PopCategory']

for i in categories:
    state = i.split(',')[1]
    Counties.append(i.split(',')[0])
    States.append(state.split('!!')[0])
    Insurance.append(state.split('!!')[1])

health15['61'] = Counties
health15['62'] = States
health15['63'] = Insurance

newcolumns15.append('County')
newcolumns15.append('State')
newcolumns15.append('PopCategory')

health15.columns = newcolumns15

health15.drop(index = 'Label (Grouping)', inplace = True)

indeces = []

for i in range(0, health15.shape[0]):
    indeces.append(i)
health15[''] = indeces
health15.set_index('', inplace = True)

health15.replace('N', 0, inplace = True)

dropColumns = ['18 to 64 years', '65 years and older', \
    'Two or more races', 'White alone, not Hispanic or Latino', \
    'In family households', 'In married couple families', 'In other families', 'Male householder, no wife present', \
    'Female householder, no husband present', 'In non-family households and other living arrangements', \
    'With a disability', 'No disability', 'Civilian noninstitutionalized population 25 years and over', \
    'Civilian noninstitutionalized population 18 years and over', 'In labor force', 'Employed', \
    'Unemployed', 'Not in labor force', 'Civilian noninstitutionalized population 18 to 64 years', \
    'Worked full-time, year round in the past 12 months', 'Worked less than full-time, year round in the past 12 months', \
    'Did not work', 'Total household population', 'Civilian noninstitutionalized population for whom poverty status is determined', \
    'Below 138 percent of the poverty threshold', '138 to 199 percent of the poverty threshold', \
    '200 to 399 percent of the poverty threshold', 'At or above 400 percent of the poverty threshold']
health15.drop(columns = dropColumns, inplace = True)
health15.rename(columns = {'Civilian noninstitutionalized population':'Total Population', 'PopCategory':'Insurance Category'}, inplace = True)

sortColumns = ['State', 'County', 'Insurance Category', 'Total Population', 'Under 6 years', '6 to 17 years', 'Under 18 years', '18 to 24 years', '19 to 25 years', '25 to 34 years', '35 to 44 years', '45 to 54 years', '55 to 64 years', \
    '65 to 74 years', '75 years and older', 'Male', 'Female', 'White alone', 'Black or African American alone', 'American Indian and Alaska Native alone', 'Asian alone', \
    'Native Hawaiian and Other Pacific Islander alone', 'Some other race alone', 'Hispanic or Latino (of any race)', 'Native born', 'Foreign born', 'Naturalized', \
    'Not a citizen', 'Less than high school graduate', 'High school graduate (includes equivalency)', "Some college or associate's degree", "Bachelor's degree or higher", \
    'Under $25,000', '$25,000 to $49,999', '$50,000 to $74,999', '$75,000 to $99,999', '$100,000 and over']
health15 = health15[sortColumns]

columns = list(health15.columns)[3:]
for i in columns:
       health15[i] = health15[i].str.replace(',', '')
       health15[i] = pd.to_numeric(health15[i])

# Imputing the 0 values for the mean of the population
health15.fillna(0, inplace = True)
imp = SimpleImputer(strategy = 'mean', missing_values = 0)

health15[columns] = imp.fit_transform(health15[columns])
health15[columns] = health15[columns].astype(int)

health15['State'] = health15['State'].str.lstrip()
health15['State'] = health15['State'].str.replace(' ', '_')
health15['State'] = health15['State'].replace('District_of_Columbia', 'DC')

health15['6 to 18 years'] = (health15['Under 18 years'] - health15['6 to 17 years']) + health15['6 to 17 years']
health15.drop(columns = ['6 to 17 years', 'Under 18 years'], inplace = True)

health15['26 to 34 years'] = health15['25 to 34 years'] - (health15['19 to 25 years'] - (health15['Under 6 years'] + health15['6 to 18 years'] + health15['18 to 24 years']))
health15.drop(columns = ['25 to 34 years', '18 to 24 years'], inplace = True)

health15 = health15[['State', 'County', 'Insurance Category', 'Total Population',
       'Under 6 years', '6 to 18 years',  '19 to 25 years', '26 to 34 years', '35 to 44 years',
       '45 to 54 years', '55 to 64 years', '65 to 74 years',
       '75 years and older', 'Male', 'Female', 'White alone',
       'Black or African American alone',
       'American Indian and Alaska Native alone', 'Asian alone',
       'Native Hawaiian and Other Pacific Islander alone',
       'Some other race alone', 'Hispanic or Latino (of any race)',
       'Native born', 'Foreign born', 'Naturalized', 'Not a citizen',
       'Less than high school graduate',
       'High school graduate (includes equivalency)',
       "Some college or associate's degree", "Bachelor's degree or higher",
       'Under $25,000', '$25,000 to $49,999', '$50,000 to $74,999',
       '$75,000 to $99,999', '$100,000 and over']]

health15.columns = ['State', 'County', 'Insurance_Category', \
    'Total_Population', 'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y', \
    '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male', \
    'Female', 'White', 'African_American', 'American_Indian', 'Asian', 'Pacific_Islander', \
    'Some_Other_Race', 'Hispanic', \
    'Native_Born', 'Foreign_Born', 'Naturalized', 'Not_A_Citizen', \
    'Less_Than_High_School', 'High_School_or_Equivalent', \
    "Some_College", "Bachelors_or_Higher", 'Under_25000S', '_25000_to_49999S', \
    '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']

# %% [markdown]
# **Cleaning Health16 Dataset**

# %%
health16 = spark.read.options(header = 'True').csv("/mnt/healthcare/modeldataIn/ModelData/Health Insurance Characteristics 2016.csv").toPandas()

# Counting and dropping all null values within each dataset
health16.dropna(inplace = True)

# Resetting the index for each dataset
rows = []
for i in range(0, health16.shape[0]):
    rows.append(i)

health16[''] = rows
health16 = health16.set_index('')

Category = []

for i in health16['Label (Grouping)']:
    Category.append(i.strip())

health16['Label (Grouping)'] = Category

newcolumns15 = list(health16['Label (Grouping)'])

# Transposing so the states become the rows and the categories become the columns
health16 = health16.transpose()

categories = list(health16.index)[1:]
Counties = ['County']
States = ['State']
Insurance = ['PopCategory']

for i in categories:
    state = i.split(',')[1]
    Counties.append(i.split(',')[0])
    States.append(state.split('!!')[0])
    Insurance.append(state.split('!!')[1])

health16['61'] = Counties
health16['62'] = States
health16['63'] = Insurance

newcolumns15.append('County')
newcolumns15.append('State')
newcolumns15.append('PopCategory')

health16.columns = newcolumns15

health16.drop(index = 'Label (Grouping)', inplace = True)

indeces = []

for i in range(0, health16.shape[0]):
    indeces.append(i)
health16[''] = indeces
health16.set_index('', inplace = True)

health16.replace('N', 0, inplace = True)

dropColumns = ['18 to 64 years', '65 years and older', \
    'Two or more races', 'White alone, not Hispanic or Latino', \
    'In family households', 'In married couple families', 'In other families', 'Male householder, no wife present', \
    'Female householder, no husband present', 'In non-family households and other living arrangements', \
    'With a disability', 'No disability', 'Civilian noninstitutionalized population 25 years and over', \
    'Civilian noninstitutionalized population 18 years and over', 'In labor force', 'Employed', \
    'Unemployed', 'Not in labor force', 'Civilian noninstitutionalized population 18 to 64 years', \
    'Worked full-time, year round in the past 12 months', 'Worked less than full-time, year round in the past 12 months', \
    'Did not work', 'Total household population', 'Civilian noninstitutionalized population for whom poverty status is determined', \
    'Below 138 percent of the poverty threshold', '138 to 199 percent of the poverty threshold', \
    '200 to 399 percent of the poverty threshold', 'At or above 400 percent of the poverty threshold']
health16.drop(columns = dropColumns, inplace = True)
health16.rename(columns = {'Civilian noninstitutionalized population':'Total Population', 'PopCategory':'Insurance Category'}, inplace = True)

sortColumns = ['State', 'County', 'Insurance Category', 'Total Population', 'Under 6 years', '6 to 17 years', 'Under 18 years', '18 to 24 years', '19 to 25 years', '25 to 34 years', '35 to 44 years', '45 to 54 years', '55 to 64 years', \
    '65 to 74 years', '75 years and older', 'Male', 'Female', 'White alone', 'Black or African American alone', 'American Indian and Alaska Native alone', 'Asian alone', \
    'Native Hawaiian and Other Pacific Islander alone', 'Some other race alone', 'Hispanic or Latino (of any race)', 'Native born', 'Foreign born', 'Naturalized', \
    'Not a citizen', 'Less than high school graduate', 'High school graduate (includes equivalency)', "Some college or associate's degree", "Bachelor's degree or higher", \
    'Under $25,000', '$25,000 to $49,999', '$50,000 to $74,999', '$75,000 to $99,999', '$100,000 and over']
health16 = health16[sortColumns]

columns = list(health16.columns)[3:]
for i in columns:
       health16[i] = health16[i].str.replace(',', '')
       health16[i] = pd.to_numeric(health16[i])

# Imputing the 0 values for the mean of the population
health16.fillna(0, inplace = True)
imp = SimpleImputer(strategy = 'mean', missing_values = 0)

health16[columns] = imp.fit_transform(health16[columns])
health16[columns] = health16[columns].astype(int)

health16['State'] = health16['State'].str.lstrip()
health16['State'] = health16['State'].str.replace(' ', '_')
health16['State'] = health16['State'].replace('District_of_Columbia', 'DC')

health16['6 to 18 years'] = (health16['Under 18 years'] - health16['6 to 17 years']) + health16['6 to 17 years']
health16.drop(columns = ['6 to 17 years', 'Under 18 years'], inplace = True)

health16['26 to 34 years'] = health16['25 to 34 years'] - (health16['19 to 25 years'] - (health16['Under 6 years'] + health16['6 to 18 years'] + health16['18 to 24 years']))
health16.drop(columns = ['25 to 34 years', '18 to 24 years'], inplace = True)

health16 = health16[['State', 'County', 'Insurance Category', 'Total Population',
       'Under 6 years', '6 to 18 years',  '19 to 25 years', '26 to 34 years', '35 to 44 years',
       '45 to 54 years', '55 to 64 years', '65 to 74 years',
       '75 years and older', 'Male', 'Female', 'White alone',
       'Black or African American alone',
       'American Indian and Alaska Native alone', 'Asian alone',
       'Native Hawaiian and Other Pacific Islander alone',
       'Some other race alone', 'Hispanic or Latino (of any race)',
       'Native born', 'Foreign born', 'Naturalized', 'Not a citizen',
       'Less than high school graduate',
       'High school graduate (includes equivalency)',
       "Some college or associate's degree", "Bachelor's degree or higher",
       'Under $25,000', '$25,000 to $49,999', '$50,000 to $74,999',
       '$75,000 to $99,999', '$100,000 and over']]

health16.columns = ['State', 'County', 'Insurance_Category', \
    'Total_Population', 'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y', \
    '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male', \
    'Female', 'White', 'African_American', 'American_Indian', 'Asian', 'Pacific_Islander', \
    'Some_Other_Race', 'Hispanic', \
    'Native_Born', 'Foreign_Born', 'Naturalized', 'Not_A_Citizen', \
    'Less_Than_High_School', 'High_School_or_Equivalent', \
    "Some_College", "Bachelors_or_Higher", 'Under_25000S', '_25000_to_49999S', \
    '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']

# %% [markdown]
# **Cleaning Health17 Dataset**

# %%
health17 = spark.read.options(header = 'True').csv("/mnt/healthcare/modeldataIn/ModelData/Health Insurance Characteristics 2017.csv").toPandas()

# Counting and dropping all null values in each dataset
health17.dropna(inplace = True)

# Resetting the index for each dataset
rows = []
for i in range(0, health17.shape[0]):
    rows.append(i)

health17[''] = rows
health17 = health17.set_index('')

Category = []

for i in health17['Label (Grouping)']:
    Category.append(i.strip())

health17['Label (Grouping)'] = Category

newcolumns15 = list(health17['Label (Grouping)'])

# Transposing so the states become the rows and the categories become the columns
health17 = health17.transpose()

categories = list(health17.index)[1:]
Counties = ['County']
States = ['State']
Insurance = ['PopCategory']

for i in categories:
    state = i.split(',')[1]
    Counties.append(i.split(',')[0])
    States.append(state.split('!!')[0])
    Insurance.append(state.split('!!')[1])

health17['61'] = Counties
health17['62'] = States
health17['63'] = Insurance

newcolumns15.append('County')
newcolumns15.append('State')
newcolumns15.append('PopCategory')

health17.columns = newcolumns15

health17.drop(index = 'Label (Grouping)', inplace = True)

indeces = []

for i in range(0, health17.shape[0]):
    indeces.append(i)
health17[''] = indeces
health17.set_index('', inplace = True)

health17.replace('N', 0, inplace = True)

dropColumns = ['Under 19 years', '19 to 64 years', '65 years and older', 'Two or more races', 'White alone, not Hispanic or Latino', 'In family households', \
    'In married couple families', 'In other families', 'Male householder, no wife present', 'Female householder, no husband present', \
    'In non-family households and other living arrangements', 'With a disability', 'No disability', 'Civilian noninstitutionalized population 26 years and over', \
    'Civilian noninstitutionalized population 19 to 64 years', 'In labor force', 'Employed', 'Unemployed', 'Not in labor force', \
    'Civilian noninstitutionalized population 19 to 64 years', 'Worked full-time, year round in the past 12 months', \
    'Worked less than full-time, year round in the past 12 months', 'Did not work', 'Total household population', \
    'Civilian noninstitutionalized population for whom poverty status is determined', 'Below 138 percent of the poverty threshold', \
    '138 to 399 percent of the poverty threshold', 'At or above 400 percent of the poverty threshold', 'Below 100 percent of the poverty threshold']

health17.drop(columns = dropColumns, inplace = True)
health17.rename(columns = {'Civilian noninstitutionalized population':'Total Population', 'PopCategory':'Insurance Category'}, inplace = True)

sortColumns = ['State', 'County', 'Insurance Category', 'Total Population', 'Under 6 years', '6 to 18 years', '19 to 25 years', '26 to 34 years', '35 to 44 years', '45 to 54 years', '55 to 64 years', \
    '65 to 74 years', '75 years and older', 'Male', 'Female', 'White alone', 'Black or African American alone', 'American Indian and Alaska Native alone', 'Asian alone', \
    'Native Hawaiian and Other Pacific Islander alone', 'Some other race alone', 'Hispanic or Latino (of any race)', 'Native born', 'Foreign born', 'Naturalized', \
    'Not a citizen', 'Less than high school graduate', 'High school graduate (includes equivalency)', "Some college or associate's degree", "Bachelor's degree or higher", \
    'Under $25,000', '$25,000 to $49,999', '$50,000 to $74,999', '$75,000 to $99,999', '$100,000 and over']

health17 = health17[sortColumns]

columns = list(health17.columns)[3:]
for i in columns:
       health17[i] = health17[i].str.replace(',', '')
       health17[i] = pd.to_numeric(health17[i])

# Imputing the 0 values for the mean of the population
health17.fillna(0, inplace = True)
imp = SimpleImputer(strategy = 'mean', missing_values = 0)

health17[columns] = imp.fit_transform(health17[columns])
health17[columns] = health17[columns].astype(int)

health17.columns = ['State', 'County', 'Insurance_Category', \
    'Total_Population', 'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y', \
    '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male', \
    'Female', 'White', 'African_American', 'American_Indian', 'Asian', 'Pacific_Islander', \
    'Some_Other_Race', 'Hispanic', \
    'Native_Born', 'Foreign_Born', 'Naturalized', 'Not_A_Citizen', \
    'Less_Than_High_School', 'High_School_or_Equivalent', \
    "Some_College", "Bachelors_or_Higher", 'Under_25000S', '_25000_to_49999S', \
    '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']

health17['State'] = health17['State'].str.lstrip()
health17['State'] = health17['State'].str.replace(' ', '_')
health17['State'] = health17['State'].replace('District_of_Columbia', 'DC')

# %% [markdown]
# **Cleaning Health18 Dataset**

# %%
health18 = spark.read.options(header = 'True').csv("/mnt/healthcare/modeldataIn/ModelData/Health Insurance Characteristics 2018.csv").toPandas()

# Counting and dropping all null values in each dataset
health18.dropna(inplace = True)

# Resetting the index for each dataset
rows = []
for i in range(0, health18.shape[0]):
    rows.append(i)

health18[''] = rows
health18 = health18.set_index('')

Category = []

for i in health18['Label (Grouping)']:
    Category.append(i.strip())

health18['Label (Grouping)'] = Category

newcolumns15 = list(health18['Label (Grouping)'])

# Transposing so the states become the rows and the categories become the columns
health18 = health18.transpose()

categories = list(health18.index)[1:]
Counties = ['County']
States = ['State']
Insurance = ['PopCategory']

for i in categories:
    state = i.split(',')[1]
    Counties.append(i.split(',')[0])
    States.append(state.split('!!')[0])
    Insurance.append(state.split('!!')[1])

health18['61'] = Counties
health18['62'] = States
health18['63'] = Insurance

newcolumns15.append('County')
newcolumns15.append('State')
newcolumns15.append('PopCategory')

health18.columns = newcolumns15

health18.drop(index = 'Label (Grouping)', inplace = True)

indeces = []

for i in range(0, health18.shape[0]):
    indeces.append(i)
health18[''] = indeces
health18.set_index('', inplace = True)

health18.replace('N', 0, inplace = True)

dropColumns = ['Under 19 years', '19 to 64 years', '65 years and older', 'Two or more races', 'White alone, not Hispanic or Latino', 'In family households', \
    'In married couple families', 'In other families', 'Male householder, no wife present', 'Female householder, no husband present', \
    'In non-family households and other living arrangements', 'With a disability', 'No disability', 'Civilian noninstitutionalized population 26 years and over', \
    'Civilian noninstitutionalized population 19 to 64 years', 'In labor force', 'Employed', 'Unemployed', 'Not in labor force', \
    'Civilian noninstitutionalized population 19 to 64 years', 'Worked full-time, year round in the past 12 months', \
    'Worked less than full-time, year round in the past 12 months', 'Did not work', 'Total household population', \
    'Civilian noninstitutionalized population for whom poverty status is determined', 'Below 138 percent of the poverty threshold', \
    '138 to 399 percent of the poverty threshold', 'At or above 400 percent of the poverty threshold', 'Below 100 percent of the poverty threshold']

health18.drop(columns = dropColumns, inplace = True)
health18.rename(columns = {'Civilian noninstitutionalized population':'Total Population', 'PopCategory':'Insurance Category'}, inplace = True)

sortColumns = ['State', 'County', 'Insurance Category', 'Total Population', 'Under 6 years', '6 to 18 years', '19 to 25 years', '26 to 34 years', '35 to 44 years', '45 to 54 years', '55 to 64 years', \
    '65 to 74 years', '75 years and older', 'Male', 'Female', 'White alone', 'Black or African American alone', 'American Indian and Alaska Native alone', 'Asian alone', \
    'Native Hawaiian and Other Pacific Islander alone', 'Some other race alone', 'Hispanic or Latino (of any race)', 'Native born', 'Foreign born', 'Naturalized', \
    'Not a citizen', 'Less than high school graduate', 'High school graduate (includes equivalency)', "Some college or associate's degree", "Bachelor's degree or higher", \
    'Under $25,000', '$25,000 to $49,999', '$50,000 to $74,999', '$75,000 to $99,999', '$100,000 and over']

health18 = health18[sortColumns]

columns = list(health18.columns)[3:]
for i in columns:
       health18[i] = health18[i].str.replace(',', '')
       health18[i] = pd.to_numeric(health18[i])

# Imputing the 0 values for the mean of the population
health18.fillna(0, inplace = True)
imp = SimpleImputer(strategy = 'mean', missing_values = 0)

health18[columns] = imp.fit_transform(health18[columns])
health18[columns] = health18[columns].astype(int)

health18.columns = ['State', 'County', 'Insurance_Category', \
    'Total_Population', 'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y', \
    '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male', \
    'Female', 'White', 'African_American', 'American_Indian', 'Asian', 'Pacific_Islander', \
    'Some_Other_Race', 'Hispanic', \
    'Native_Born', 'Foreign_Born', 'Naturalized', 'Not_A_Citizen', \
    'Less_Than_High_School', 'High_School_or_Equivalent', \
    "Some_College", "Bachelors_or_Higher", 'Under_25000S', '_25000_to_49999S', \
    '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']

health18['State'] = health18['State'].str.lstrip()
health18['State'] = health18['State'].str.replace(' ', '_')
health18['State'] = health18['State'].replace('District_of_Columbia', 'DC')

# %% [markdown]
# **Cleaning Health19 Dataset**

# %%
health19 = spark.read.options(header = 'True').csv("/mnt/healthcare/modeldataIn/ModelData/Health Insurance Characteristics.csv").toPandas()

# Counting the NA values in each column
health19.isna().sum()

# Dropping the NA rows since there was 5 in every row
health19.dropna(inplace=True)

# Making sure all NA values are gone
health19.isna().sum()

rows = []
for i in range(0, health19.shape[0]):
    rows.append(i)

health19[''] = rows
health19 = health19.set_index('')

Category = []

for i in health19['Label (Grouping)']:
    Category.append(i.strip())

health19['Label (Grouping)'] = Category

newcolumns = list(health19['Label (Grouping)'])

# Transposing so the states become the rows and the categories become the columns
health19 = health19.transpose()

categories = list(health19.index)[1:]
Counties = ['County']
States = ['State']
Insurance = ['PopCategory']

for i in categories:
    state = i.split(',')[1]
    Counties.append(i.split(',')[0])
    States.append(state.split('!!')[0])
    Insurance.append(state.split('!!')[1])

health19['61'] = Counties
health19['62'] = States
health19['63'] = Insurance

newcolumns.append('County')
newcolumns.append('State')
newcolumns.append('PopCategory')

health19.columns = newcolumns

health19.drop(index = 'Label (Grouping)', inplace = True)

indeces = []

for i in range(0, health19.shape[0]):
    indeces.append(i)
health19[''] = indeces
health19.set_index('', inplace = True)

health19.replace('N', 0, inplace = True)

health19.drop(columns = ['Total household population', 'In non-family households and other living arrangements', \
    'In family households', 'In married couple families', 'In other families', 'Male reference person, no spouse present', \
    'Female reference person, no spouse present', 'With a disability', 'No disability', 'Civilian noninstitutionalized population 19 to 64 years', \
    'In labor force', 'Employed', 'Unemployed', 'Not in labor force', 'Worked full-time, year round in the past 12 months', \
    'Worked less than full-time, year round in the past 12 months', 'Did not work', 'Civilian noninstitutionalized population for whom poverty status is determined', \
    'Civilian noninstitutionalized population 26 years and over', 'Under 19 years', '19 to 64 years', '65 years and older', 'Two or more races', \
    'White alone, not Hispanic or Latino', 'Below 138 percent of the poverty threshold', '138 to 399 percent of the poverty threshold', \
    'At or above 400 percent of the poverty threshold', 'Below 100 percent of the poverty threshold'], inplace = True)

columns = list(health19.columns)[:-3]
for i in columns:
       health19[i] = health19[i].str.replace(',', '')
       health19[i] = pd.to_numeric(health19[i])

# Imputing the 0 values for the mean of the population
health19.fillna(0, inplace = True)
imp = SimpleImputer(strategy = 'mean', missing_values = 0)

health19[columns] = imp.fit_transform(health19[columns])
health19[columns] = health19[columns].astype(int)

newColumns = ['State', 'County', 'PopCategory', \
    'Civilian noninstitutionalized population', 'Under 6 years', '6 to 18 years', '19 to 25 years', '26 to 34 years', '35 to 44 years', \
    '45 to 54 years', '55 to 64 years', '65 to 74 years', '75 years and older', 'Male', \
    'Female', 'White alone', 'Black or African American alone', 'American Indian and Alaska Native alone', 'Asian alone', 'Native Hawaiian and Other Pacific Islander alone', \
    'Some other race alone', 'Hispanic or Latino (of any race)', \
    'Native born', 'Foreign born', 'Naturalized', 'Not a citizen', \
    'Less than high school graduate', 'High school graduate (includes equivalency)', \
    "Some college or associate's degree", "Bachelor's degree or higher", 'Under $25,000', '$25,000 to $49,999', \
    '$50,000 to $74,999', '$75,000 to $99,999', '$100,000 and over']

health19 = health19[newColumns]

health19.columns = ['State', 'County', 'Insurance_Category', \
    'Total_Population', 'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y', \
    '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male', \
    'Female', 'White', 'African_American', 'American_Indian', 'Asian', 'Pacific_Islander', \
    'Some_Other_Race', 'Hispanic', \
    'Native_Born', 'Foreign_Born', 'Naturalized', 'Not_A_Citizen', \
    'Less_Than_High_School', 'High_School_or_Equivalent', \
    "Some_College", "Bachelors_or_Higher", 'Under_25000S', '_25000_to_49999S', \
    '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']

health19['State'] = health19['State'].str.lstrip()
health19['State'] = health19['State'].str.replace(' ', '_')
health19['State'] = health19['State'].replace('District_of_Columbia', 'DC')

# %%
health15['Year'] = 2015
health16['Year'] = 2016
health17['Year'] = 2017
health18['Year'] = 2018
health19['Year'] = 2019

# %% [markdown]
# **ANOVA tests**

# %%
# ANOVA Test for 2015

healthAnova = health15.rename(columns = {'Insurance_Category':'InsuranceCategory', 'Total_Population':'TotalPopulation', 'Under_6Y':'Undersixyears', \
            '_6_to_18Y':'sixtoeighteenyears',  '_19_to_25Y':'nineteentotwentyfiveyears', '_26_to_34Y':'twentysixtothirtyfouryears', \
            '_35_to_44Y':'thirtyfivetofourtyfouryears', '_45_to_54Y':'fourtyfivetofiftyfouryears', '_55_to_64Y':'fiftyfivetosixtyfouryears', \
            '_65_to_74Y':'sixtyfivetoseventyfouryears', '_75_and_Older':'seventyfiveandmoreyears', \
            'African_American':'AfricanAmerican', 'American_Indian':'AmericanIndian', \
            'Pacific_Islander':'PacificIslander', 'Some_Other_Race':'Someotherrace', \
            'Native_Born':'Nativeborn', 'Foreign_Born':'Foreignborn', 'Not_A_Citizen':'Notacitizen', \
            'Less_Than_High_School':'Lessthanhighschoolgraduate', 'High_School_or_Equivalent':'Highschoolgraduate',  \
            "Some_College":"Somecollege", "Bachelors_or_Higher":"Bachelors", 'Under_25000S':'Undertwentyfive', \
            '_25000_to_49999S':'twentyfivetofourtyninesalary', '_50000_to_74999S':'fiftytoseventyfoursalary', \
            '_75000_to_99999S':'seventyfivetoninetyninesalary', 'Over_100000S':'onehundredandoversalary'}).copy()

anovaColumns = []
for i in list(healthAnova.columns):
    anovaColumns.append(i)

anovaColumns = anovaColumns[4:-1]

for i in anovaColumns:
    data15 = healthAnova[[i, 'InsuranceCategory', 'State']]
    health15_lm = ols(f'{i} ~ C(InsuranceCategory, Sum)*C(State, Sum)', data = data15).fit()

    table = sm.stats.anova_lm(health15_lm, typ = 2)
    print(i, table['PR(>F)'])
# Out:
# Undersixyears C(InsuranceCategory, Sum)                  7.693176e-45
# C(State, Sum)                              1.981502e-17
# C(InsuranceCategory, Sum):C(State, Sum)    6.103525e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# sixtoeighteenyears C(InsuranceCategory, Sum)                  3.065630e-52
# C(State, Sum)                              2.928655e-20
# C(InsuranceCategory, Sum):C(State, Sum)    7.466754e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# nineteentotwentyfiveyears C(InsuranceCategory, Sum)                  1.837883e-39
# C(State, Sum)                              1.957823e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.793527e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# twentysixtothirtyfouryears C(InsuranceCategory, Sum)                  5.806177e-45
# C(State, Sum)                              5.464271e-20
# C(InsuranceCategory, Sum):C(State, Sum)    9.044096e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# thirtyfivetofourtyfouryears C(InsuranceCategory, Sum)                  6.615512e-38
# C(State, Sum)                              7.639863e-21
# C(InsuranceCategory, Sum):C(State, Sum)    9.943081e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fourtyfivetofiftyfouryears C(InsuranceCategory, Sum)                  2.073060e-46
# C(State, Sum)                              6.332653e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.482570e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fiftyfivetosixtyfouryears C(InsuranceCategory, Sum)                  7.779288e-57
# C(State, Sum)                              4.785965e-22
# C(InsuranceCategory, Sum):C(State, Sum)    8.013154e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# sixtyfivetoseventyfouryears C(InsuranceCategory, Sum)                  3.208088e-37
# C(State, Sum)                              2.186307e-21
# C(InsuranceCategory, Sum):C(State, Sum)    5.406948e-04
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# seventyfiveandmoreyears C(InsuranceCategory, Sum)                  6.126924e-21
# C(State, Sum)                              1.046092e-21
# C(InsuranceCategory, Sum):C(State, Sum)    1.378859e-04
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Male C(InsuranceCategory, Sum)                  5.528346e-47
# C(State, Sum)                              1.389166e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.258443e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Female C(InsuranceCategory, Sum)                  6.670424e-50
# C(State, Sum)                              1.015000e-20
# C(InsuranceCategory, Sum):C(State, Sum)    8.975249e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# White C(InsuranceCategory, Sum)                  1.251526e-68
# C(State, Sum)                              3.013370e-26
# C(InsuranceCategory, Sum):C(State, Sum)    6.620321e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# AfricanAmerican C(InsuranceCategory, Sum)                  6.190802e-26
# C(State, Sum)                              2.003394e-02
# C(InsuranceCategory, Sum):C(State, Sum)    9.999983e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# AmericanIndian C(InsuranceCategory, Sum)                  1.223361e-11
# C(State, Sum)                              1.390373e-70
# C(InsuranceCategory, Sum):C(State, Sum)    2.375755e-18
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Asian C(InsuranceCategory, Sum)                  1.692611e-11
# C(State, Sum)                              2.014435e-20
# C(InsuranceCategory, Sum):C(State, Sum)    2.611736e-02
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# PacificIslander C(InsuranceCategory, Sum)                  2.604938e-04
# C(State, Sum)                              9.316812e-78
# C(InsuranceCategory, Sum):C(State, Sum)    1.110705e-65
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Someotherrace C(InsuranceCategory, Sum)                  6.378041e-05
# C(State, Sum)                              3.279473e-10
# C(InsuranceCategory, Sum):C(State, Sum)    9.948331e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Hispanic C(InsuranceCategory, Sum)                  1.036863e-09
# C(State, Sum)                              2.578844e-25
# C(InsuranceCategory, Sum):C(State, Sum)    8.321824e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Nativeborn C(InsuranceCategory, Sum)                  2.513599e-66
# C(State, Sum)                              1.989237e-18
# C(InsuranceCategory, Sum):C(State, Sum)    8.798628e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Foreignborn C(InsuranceCategory, Sum)                  2.433626e-09
# C(State, Sum)                              2.750270e-25
# C(InsuranceCategory, Sum):C(State, Sum)    9.858780e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Naturalized C(InsuranceCategory, Sum)                  4.803986e-10
# C(State, Sum)                              6.090054e-21
# C(InsuranceCategory, Sum):C(State, Sum)    5.964854e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Notacitizen C(InsuranceCategory, Sum)                  5.447230e-07
# C(State, Sum)                              1.617570e-27
# C(InsuranceCategory, Sum):C(State, Sum)    9.999480e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Lessthanhighschoolgraduate C(InsuranceCategory, Sum)                  2.038176e-16
# C(State, Sum)                              1.035357e-24
# C(InsuranceCategory, Sum):C(State, Sum)    9.997543e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Highschoolgraduate C(InsuranceCategory, Sum)                  1.759795e-56
# C(State, Sum)                              6.386713e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.720480e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Somecollege C(InsuranceCategory, Sum)                  1.676134e-55
# C(State, Sum)                              4.445601e-27
# C(InsuranceCategory, Sum):C(State, Sum)    5.477479e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Bachelors C(InsuranceCategory, Sum)                  4.170796e-47
# C(State, Sum)                              2.251460e-17
# C(InsuranceCategory, Sum):C(State, Sum)    8.682795e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Undertwentyfive C(InsuranceCategory, Sum)                  8.210556e-38
# C(State, Sum)                              8.705153e-16
# C(InsuranceCategory, Sum):C(State, Sum)    9.995830e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# twentyfivetofourtyninesalary C(InsuranceCategory, Sum)                  3.944495e-41
# C(State, Sum)                              1.005868e-19
# C(InsuranceCategory, Sum):C(State, Sum)    9.980366e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fiftytoseventyfoursalary C(InsuranceCategory, Sum)                  1.605189e-50
# C(State, Sum)                              2.129345e-21
# C(InsuranceCategory, Sum):C(State, Sum)    9.776375e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# seventyfivetoninetyninesalary C(InsuranceCategory, Sum)                  1.612838e-54
# C(State, Sum)                              3.804601e-22
# C(InsuranceCategory, Sum):C(State, Sum)    8.396177e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# onehundredandoversalary C(InsuranceCategory, Sum)                  2.704127e-47
# C(State, Sum)                              2.536543e-27
# C(InsuranceCategory, Sum):C(State, Sum)    2.239010e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64

# %%
# ANOVA Test for 2016

healthAnova = health16.rename(columns = {'Insurance_Category':'InsuranceCategory', 'Total_Population':'TotalPopulation', 'Under_6Y':'Undersixyears', \
            '_6_to_18Y':'sixtoeighteenyears',  '_19_to_25Y':'nineteentotwentyfiveyears', '_26_to_34Y':'twentysixtothirtyfouryears', \
            '_35_to_44Y':'thirtyfivetofourtyfouryears', '_45_to_54Y':'fourtyfivetofiftyfouryears', '_55_to_64Y':'fiftyfivetosixtyfouryears', \
            '_65_to_74Y':'sixtyfivetoseventyfouryears', '_75_and_Older':'seventyfiveandmoreyears', \
            'African_American':'AfricanAmerican', 'American_Indian':'AmericanIndian', \
            'Pacific_Islander':'PacificIslander', 'Some_Other_Race':'Someotherrace', \
            'Native_Born':'Nativeborn', 'Foreign_Born':'Foreignborn', 'Not_A_Citizen':'Notacitizen', \
            'Less_Than_High_School':'Lessthanhighschoolgraduate', 'High_School_or_Equivalent':'Highschoolgraduate',  \
            "Some_College":"Somecollege", "Bachelors_or_Higher":"Bachelors", 'Under_25000S':'Undertwentyfive', \
            '_25000_to_49999S':'twentyfivetofourtyninesalary', '_50000_to_74999S':'fiftytoseventyfoursalary', \
            '_75000_to_99999S':'seventyfivetoninetyninesalary', 'Over_100000S':'onehundredandoversalary'}).copy()

anovaColumns = []
for i in list(healthAnova.columns):
    anovaColumns.append(i)

anovaColumns = anovaColumns[4:-1]

for i in anovaColumns:
    data16 = healthAnova[[i, 'InsuranceCategory', 'State']]
    health16_lm = ols(f'{i} ~ C(InsuranceCategory, Sum)*C(State, Sum)', data = data16).fit()

    table = sm.stats.anova_lm(health16_lm, typ = 2)
    print(i, table['PR(>F)'])
# Out:
# Undersixyears C(InsuranceCategory, Sum)                  2.355100e-45
# C(State, Sum)                              2.289768e-18
# C(InsuranceCategory, Sum):C(State, Sum)    6.617319e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# sixtoeighteenyears C(InsuranceCategory, Sum)                  1.280698e-52
# C(State, Sum)                              2.555523e-20
# C(InsuranceCategory, Sum):C(State, Sum)    7.181955e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# nineteentotwentyfiveyears C(InsuranceCategory, Sum)                  1.266526e-41
# C(State, Sum)                              1.215429e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.386632e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# twentysixtothirtyfouryears C(InsuranceCategory, Sum)                  1.006376e-45
# C(State, Sum)                              7.125087e-20
# C(InsuranceCategory, Sum):C(State, Sum)    8.816443e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# thirtyfivetofourtyfouryears C(InsuranceCategory, Sum)                  7.788405e-39
# C(State, Sum)                              8.867557e-21
# C(InsuranceCategory, Sum):C(State, Sum)    9.902453e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fourtyfivetofiftyfouryears C(InsuranceCategory, Sum)                  5.199688e-47
# C(State, Sum)                              1.644338e-21
# C(InsuranceCategory, Sum):C(State, Sum)    9.359100e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fiftyfivetosixtyfouryears C(InsuranceCategory, Sum)                  1.142892e-57
# C(State, Sum)                              5.902452e-22
# C(InsuranceCategory, Sum):C(State, Sum)    7.963112e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# sixtyfivetoseventyfouryears C(InsuranceCategory, Sum)                  1.002598e-38
# C(State, Sum)                              2.920291e-21
# C(InsuranceCategory, Sum):C(State, Sum)    8.288697e-04
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# seventyfiveandmoreyears C(InsuranceCategory, Sum)                  6.030641e-17
# C(State, Sum)                              7.224461e-22
# C(InsuranceCategory, Sum):C(State, Sum)    1.064498e-04
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Male C(InsuranceCategory, Sum)                  3.112534e-48
# C(State, Sum)                              2.425795e-22
# C(InsuranceCategory, Sum):C(State, Sum)    8.912685e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Female C(InsuranceCategory, Sum)                  6.850464e-51
# C(State, Sum)                              1.499260e-20
# C(InsuranceCategory, Sum):C(State, Sum)    8.690142e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# White C(InsuranceCategory, Sum)                  4.408613e-71
# C(State, Sum)                              4.370496e-26
# C(InsuranceCategory, Sum):C(State, Sum)    5.879501e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# AfricanAmerican C(InsuranceCategory, Sum)                  4.631420e-27
# C(State, Sum)                              1.013376e-02
# C(InsuranceCategory, Sum):C(State, Sum)    9.999969e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# AmericanIndian C(InsuranceCategory, Sum)                  6.332044e-13
# C(State, Sum)                              3.079718e-70
# C(InsuranceCategory, Sum):C(State, Sum)    1.372861e-22
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Asian C(InsuranceCategory, Sum)                  7.379161e-12
# C(State, Sum)                              1.429079e-20
# C(InsuranceCategory, Sum):C(State, Sum)    1.472936e-02
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# PacificIslander C(InsuranceCategory, Sum)                  1.881374e-04
# C(State, Sum)                              8.149892e-82
# C(InsuranceCategory, Sum):C(State, Sum)    8.019304e-71
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Someotherrace C(InsuranceCategory, Sum)                  4.123847e-05
# C(State, Sum)                              1.031555e-10
# C(InsuranceCategory, Sum):C(State, Sum)    9.906043e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Hispanic C(InsuranceCategory, Sum)                  3.529471e-10
# C(State, Sum)                              4.422897e-25
# C(InsuranceCategory, Sum):C(State, Sum)    7.408848e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Nativeborn C(InsuranceCategory, Sum)                  2.072094e-67
# C(State, Sum)                              3.824557e-18
# C(InsuranceCategory, Sum):C(State, Sum)    8.578384e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Foreignborn C(InsuranceCategory, Sum)                  5.285914e-10
# C(State, Sum)                              5.924005e-25
# C(InsuranceCategory, Sum):C(State, Sum)    9.669028e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Naturalized C(InsuranceCategory, Sum)                  1.980589e-10
# C(State, Sum)                              9.919919e-21
# C(InsuranceCategory, Sum):C(State, Sum)    5.198985e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Notacitizen C(InsuranceCategory, Sum)                  1.303735e-07
# C(State, Sum)                              1.666595e-27
# C(InsuranceCategory, Sum):C(State, Sum)    9.997327e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Lessthanhighschoolgraduate C(InsuranceCategory, Sum)                  7.969016e-17
# C(State, Sum)                              5.032396e-25
# C(InsuranceCategory, Sum):C(State, Sum)    9.987310e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Highschoolgraduate C(InsuranceCategory, Sum)                  4.183046e-58
# C(State, Sum)                              3.312264e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.484968e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Somecollege C(InsuranceCategory, Sum)                  6.789693e-57
# C(State, Sum)                              1.229596e-26
# C(InsuranceCategory, Sum):C(State, Sum)    5.187205e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Bachelors C(InsuranceCategory, Sum)                  1.064851e-47
# C(State, Sum)                              5.918751e-17
# C(InsuranceCategory, Sum):C(State, Sum)    8.505834e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Undertwentyfive C(InsuranceCategory, Sum)                  4.651852e-38
# C(State, Sum)                              2.936531e-14
# C(InsuranceCategory, Sum):C(State, Sum)    9.996431e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# twentyfivetofourtyninesalary C(InsuranceCategory, Sum)                  2.865965e-43
# C(State, Sum)                              6.379486e-20
# C(InsuranceCategory, Sum):C(State, Sum)    9.957522e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fiftytoseventyfoursalary C(InsuranceCategory, Sum)                  1.891887e-51
# C(State, Sum)                              2.800941e-21
# C(InsuranceCategory, Sum):C(State, Sum)    9.660043e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# seventyfivetoninetyninesalary C(InsuranceCategory, Sum)                  4.312474e-55
# C(State, Sum)                              1.447893e-20
# C(InsuranceCategory, Sum):C(State, Sum)    8.978420e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# onehundredandoversalary C(InsuranceCategory, Sum)                  2.294708e-47
# C(State, Sum)                              1.221466e-27
# C(InsuranceCategory, Sum):C(State, Sum)    1.515125e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64

# %%
# ANOVA Test for 2017

healthAnova = health17.rename(columns = {'Insurance_Category':'InsuranceCategory', 'Total_Population':'TotalPopulation', 'Under_6Y':'Undersixyears', \
            '_6_to_18Y':'sixtoeighteenyears',  '_19_to_25Y':'nineteentotwentyfiveyears', '_26_to_34Y':'twentysixtothirtyfouryears', \
            '_35_to_44Y':'thirtyfivetofourtyfouryears', '_45_to_54Y':'fourtyfivetofiftyfouryears', '_55_to_64Y':'fiftyfivetosixtyfouryears', \
            '_65_to_74Y':'sixtyfivetoseventyfouryears', '_75_and_Older':'seventyfiveandmoreyears', \
            'African_American':'AfricanAmerican', 'American_Indian':'AmericanIndian', \
            'Pacific_Islander':'PacificIslander', 'Some_Other_Race':'Someotherrace', \
            'Native_Born':'Nativeborn', 'Foreign_Born':'Foreignborn', 'Not_A_Citizen':'Notacitizen', \
            'Less_Than_High_School':'Lessthanhighschoolgraduate', 'High_School_or_Equivalent':'Highschoolgraduate',  \
            "Some_College":"Somecollege", "Bachelors_or_Higher":"Bachelors", 'Under_25000S':'Undertwentyfive', \
            '_25000_to_49999S':'twentyfivetofourtyninesalary', '_50000_to_74999S':'fiftytoseventyfoursalary', \
            '_75000_to_99999S':'seventyfivetoninetyninesalary', 'Over_100000S':'onehundredandoversalary'}).copy()

anovaColumns = []
for i in list(healthAnova.columns):
    anovaColumns.append(i)

anovaColumns = anovaColumns[4:-1]

for i in anovaColumns:
    data17 = healthAnova[[i, 'InsuranceCategory', 'State']]
    health17_lm = ols(f'{i} ~ C(InsuranceCategory, Sum)*C(State, Sum)', data = data17).fit()

    table = sm.stats.anova_lm(health17_lm, typ = 2)
    print(i, table['PR(>F)'])
# Out:
# Undersixyears C(InsuranceCategory, Sum)                  2.950097e-45
# C(State, Sum)                              1.831959e-18
# C(InsuranceCategory, Sum):C(State, Sum)    6.284932e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# sixtoeighteenyears C(InsuranceCategory, Sum)                  5.903963e-54
# C(State, Sum)                              9.120012e-22
# C(InsuranceCategory, Sum):C(State, Sum)    6.920769e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# nineteentotwentyfiveyears C(InsuranceCategory, Sum)                  5.006703e-42
# C(State, Sum)                              1.627442e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.309926e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# twentysixtothirtyfouryears C(InsuranceCategory, Sum)                  4.311536e-33
# C(State, Sum)                              6.505066e-20
# C(InsuranceCategory, Sum):C(State, Sum)    9.897061e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# thirtyfivetofourtyfouryears C(InsuranceCategory, Sum)                  2.574650e-39
# C(State, Sum)                              1.837704e-21
# C(InsuranceCategory, Sum):C(State, Sum)    9.823175e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fourtyfivetofiftyfouryears C(InsuranceCategory, Sum)                  3.224930e-46
# C(State, Sum)                              6.326159e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.244111e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fiftyfivetosixtyfouryears C(InsuranceCategory, Sum)                  4.129011e-57
# C(State, Sum)                              9.715684e-23
# C(InsuranceCategory, Sum):C(State, Sum)    7.532094e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# sixtyfivetoseventyfouryears C(InsuranceCategory, Sum)                  7.552443e-38
# C(State, Sum)                              9.859233e-21
# C(InsuranceCategory, Sum):C(State, Sum)    6.075605e-04
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# seventyfiveandmoreyears C(InsuranceCategory, Sum)                  2.019318e-19
# C(State, Sum)                              6.087993e-21
# C(InsuranceCategory, Sum):C(State, Sum)    1.629215e-05
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Male C(InsuranceCategory, Sum)                  2.901292e-48
# C(State, Sum)                              7.242462e-23
# C(InsuranceCategory, Sum):C(State, Sum)    8.660006e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Female C(InsuranceCategory, Sum)                  6.161301e-51
# C(State, Sum)                              4.797896e-21
# C(InsuranceCategory, Sum):C(State, Sum)    8.376238e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# White C(InsuranceCategory, Sum)                  5.493463e-71
# C(State, Sum)                              5.319675e-26
# C(InsuranceCategory, Sum):C(State, Sum)    5.919565e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# AfricanAmerican C(InsuranceCategory, Sum)                  2.487518e-27
# C(State, Sum)                              2.994684e-02
# C(InsuranceCategory, Sum):C(State, Sum)    9.999948e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# AmericanIndian C(InsuranceCategory, Sum)                  1.768675e-12
# C(State, Sum)                              5.155017e-70
# C(InsuranceCategory, Sum):C(State, Sum)    1.868045e-20
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Asian C(InsuranceCategory, Sum)                  3.522473e-12
# C(State, Sum)                              1.314045e-19
# C(InsuranceCategory, Sum):C(State, Sum)    1.277203e-02
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# PacificIslander C(InsuranceCategory, Sum)                  2.407317e-03
# C(State, Sum)                              1.527903e-59
# C(InsuranceCategory, Sum):C(State, Sum)    3.983661e-63
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Someotherrace C(InsuranceCategory, Sum)                  4.892992e-05
# C(State, Sum)                              3.028730e-12
# C(InsuranceCategory, Sum):C(State, Sum)    9.674470e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Hispanic C(InsuranceCategory, Sum)                  1.772898e-10
# C(State, Sum)                              4.342678e-26
# C(InsuranceCategory, Sum):C(State, Sum)    6.837987e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Nativeborn C(InsuranceCategory, Sum)                  6.493295e-67
# C(State, Sum)                              1.120015e-18
# C(InsuranceCategory, Sum):C(State, Sum)    8.341904e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Foreignborn C(InsuranceCategory, Sum)                  1.457801e-10
# C(State, Sum)                              6.793586e-25
# C(InsuranceCategory, Sum):C(State, Sum)    9.514502e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Naturalized C(InsuranceCategory, Sum)                  2.208262e-10
# C(State, Sum)                              2.476782e-21
# C(InsuranceCategory, Sum):C(State, Sum)    4.630172e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Notacitizen C(InsuranceCategory, Sum)                  3.588335e-08
# C(State, Sum)                              9.273744e-27
# C(InsuranceCategory, Sum):C(State, Sum)    9.995204e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Lessthanhighschoolgraduate C(InsuranceCategory, Sum)                  8.802966e-17
# C(State, Sum)                              1.842345e-24
# C(InsuranceCategory, Sum):C(State, Sum)    9.978983e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Highschoolgraduate C(InsuranceCategory, Sum)                  9.627048e-58
# C(State, Sum)                              1.228022e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.280985e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Somecollege C(InsuranceCategory, Sum)                  6.199020e-57
# C(State, Sum)                              2.971005e-27
# C(InsuranceCategory, Sum):C(State, Sum)    4.511312e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Bachelors C(InsuranceCategory, Sum)                  2.328671e-48
# C(State, Sum)                              7.535417e-18
# C(InsuranceCategory, Sum):C(State, Sum)    8.282467e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Undertwentyfive C(InsuranceCategory, Sum)                  2.491876e-40
# C(State, Sum)                              1.643656e-14
# C(InsuranceCategory, Sum):C(State, Sum)    9.993883e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# twentyfivetofourtyninesalary C(InsuranceCategory, Sum)                  3.169616e-43
# C(State, Sum)                              3.852349e-19
# C(InsuranceCategory, Sum):C(State, Sum)    9.966048e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fiftytoseventyfoursalary C(InsuranceCategory, Sum)                  6.299668e-49
# C(State, Sum)                              7.101305e-20
# C(InsuranceCategory, Sum):C(State, Sum)    9.842046e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# seventyfivetoninetyninesalary C(InsuranceCategory, Sum)                  8.060616e-55
# C(State, Sum)                              1.534675e-21
# C(InsuranceCategory, Sum):C(State, Sum)    8.918173e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# onehundredandoversalary C(InsuranceCategory, Sum)                  6.693389e-48
# C(State, Sum)                              5.969173e-29
# C(InsuranceCategory, Sum):C(State, Sum)    1.299100e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64

# %%
# ANOVA Test for 2018

healthAnova = health18.rename(columns = {'Insurance_Category':'InsuranceCategory', 'Total_Population':'TotalPopulation', 'Under_6Y':'Undersixyears', \
            '_6_to_18Y':'sixtoeighteenyears',  '_19_to_25Y':'nineteentotwentyfiveyears', '_26_to_34Y':'twentysixtothirtyfouryears', \
            '_35_to_44Y':'thirtyfivetofourtyfouryears', '_45_to_54Y':'fourtyfivetofiftyfouryears', '_55_to_64Y':'fiftyfivetosixtyfouryears', \
            '_65_to_74Y':'sixtyfivetoseventyfouryears', '_75_and_Older':'seventyfiveandmoreyears', \
            'African_American':'AfricanAmerican', 'American_Indian':'AmericanIndian', \
            'Pacific_Islander':'PacificIslander', 'Some_Other_Race':'Someotherrace', \
            'Native_Born':'Nativeborn', 'Foreign_Born':'Foreignborn', 'Not_A_Citizen':'Notacitizen', \
            'Less_Than_High_School':'Lessthanhighschoolgraduate', 'High_School_or_Equivalent':'Highschoolgraduate',  \
            "Some_College":"Somecollege", "Bachelors_or_Higher":"Bachelors", 'Under_25000S':'Undertwentyfive', \
            '_25000_to_49999S':'twentyfivetofourtyninesalary', '_50000_to_74999S':'fiftytoseventyfoursalary', \
            '_75000_to_99999S':'seventyfivetoninetyninesalary', 'Over_100000S':'onehundredandoversalary'}).copy()

anovaColumns = []
for i in list(healthAnova.columns):
    anovaColumns.append(i)

anovaColumns = anovaColumns[4:-1]

for i in anovaColumns:
    data18 = healthAnova[[i, 'InsuranceCategory', 'State']]
    health18_lm = ols(f'{i} ~ C(InsuranceCategory, Sum)*C(State, Sum)', data = data18).fit()

    table = sm.stats.anova_lm(health18_lm, typ = 2)
    print(i, table['PR(>F)'])
# Out:
# Undersixyears C(InsuranceCategory, Sum)                  3.771909e-46
# C(State, Sum)                              4.920595e-19
# C(InsuranceCategory, Sum):C(State, Sum)    6.456554e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# sixtoeighteenyears C(InsuranceCategory, Sum)                  2.262457e-54
# C(State, Sum)                              4.457221e-22
# C(InsuranceCategory, Sum):C(State, Sum)    6.537141e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# nineteentotwentyfiveyears C(InsuranceCategory, Sum)                  1.441693e-42
# C(State, Sum)                              1.743460e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.397849e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# twentysixtothirtyfouryears C(InsuranceCategory, Sum)                  2.523872e-33
# C(State, Sum)                              3.298694e-20
# C(InsuranceCategory, Sum):C(State, Sum)    9.890650e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# thirtyfivetofourtyfouryears C(InsuranceCategory, Sum)                  1.110870e-39
# C(State, Sum)                              7.727982e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.788268e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fourtyfivetofiftyfouryears C(InsuranceCategory, Sum)                  6.841422e-46
# C(State, Sum)                              5.511412e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.354111e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fiftyfivetosixtyfouryears C(InsuranceCategory, Sum)                  6.762708e-57
# C(State, Sum)                              7.886868e-23
# C(InsuranceCategory, Sum):C(State, Sum)    7.389303e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# sixtyfivetoseventyfouryears C(InsuranceCategory, Sum)                  2.618336e-38
# C(State, Sum)                              8.169008e-21
# C(InsuranceCategory, Sum):C(State, Sum)    6.619885e-04
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# seventyfiveandmoreyears C(InsuranceCategory, Sum)                  2.395826e-18
# C(State, Sum)                              2.177195e-22
# C(InsuranceCategory, Sum):C(State, Sum)    5.245280e-05
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Male C(InsuranceCategory, Sum)                  1.403805e-48
# C(State, Sum)                              3.919366e-23
# C(InsuranceCategory, Sum):C(State, Sum)    8.577157e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Female C(InsuranceCategory, Sum)                  3.066551e-51
# C(State, Sum)                              2.741761e-21
# C(InsuranceCategory, Sum):C(State, Sum)    8.360972e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# White C(InsuranceCategory, Sum)                  7.430841e-70
# C(State, Sum)                              2.731030e-26
# C(InsuranceCategory, Sum):C(State, Sum)    5.900112e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# AfricanAmerican C(InsuranceCategory, Sum)                  9.914479e-28
# C(State, Sum)                              1.238460e-02
# C(InsuranceCategory, Sum):C(State, Sum)    9.999934e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# AmericanIndian C(InsuranceCategory, Sum)                  2.048183e-12
# C(State, Sum)                              8.352567e-70
# C(InsuranceCategory, Sum):C(State, Sum)    1.072560e-20
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Asian C(InsuranceCategory, Sum)                  1.934890e-12
# C(State, Sum)                              3.741464e-20
# C(InsuranceCategory, Sum):C(State, Sum)    9.467365e-03
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# PacificIslander C(InsuranceCategory, Sum)                  7.665072e-04
# C(State, Sum)                              1.113888e-65
# C(InsuranceCategory, Sum):C(State, Sum)    1.018379e-61
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Someotherrace C(InsuranceCategory, Sum)                  1.240738e-05
# C(State, Sum)                              1.286092e-11
# C(InsuranceCategory, Sum):C(State, Sum)    9.467848e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Hispanic C(InsuranceCategory, Sum)                  1.271203e-10
# C(State, Sum)                              5.903625e-26
# C(InsuranceCategory, Sum):C(State, Sum)    6.662269e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Nativeborn C(InsuranceCategory, Sum)                  6.743988e-67
# C(State, Sum)                              1.917524e-18
# C(InsuranceCategory, Sum):C(State, Sum)    8.313836e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Foreignborn C(InsuranceCategory, Sum)                  1.034519e-10
# C(State, Sum)                              4.190037e-25
# C(InsuranceCategory, Sum):C(State, Sum)    9.367876e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Naturalized C(InsuranceCategory, Sum)                  8.067747e-11
# C(State, Sum)                              3.230992e-22
# C(InsuranceCategory, Sum):C(State, Sum)    3.952646e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Notacitizen C(InsuranceCategory, Sum)                  4.077611e-08
# C(State, Sum)                              2.512651e-26
# C(InsuranceCategory, Sum):C(State, Sum)    9.993967e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Lessthanhighschoolgraduate C(InsuranceCategory, Sum)                  1.073473e-16
# C(State, Sum)                              2.515905e-24
# C(InsuranceCategory, Sum):C(State, Sum)    9.983676e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Highschoolgraduate C(InsuranceCategory, Sum)                  4.856696e-58
# C(State, Sum)                              3.653331e-23
# C(InsuranceCategory, Sum):C(State, Sum)    9.203411e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Somecollege C(InsuranceCategory, Sum)                  2.520269e-57
# C(State, Sum)                              7.001931e-28
# C(InsuranceCategory, Sum):C(State, Sum)    4.524032e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Bachelors C(InsuranceCategory, Sum)                  3.314599e-48
# C(State, Sum)                              6.461846e-18
# C(InsuranceCategory, Sum):C(State, Sum)    8.160334e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Undertwentyfive C(InsuranceCategory, Sum)                  1.684872e-41
# C(State, Sum)                              5.727345e-15
# C(InsuranceCategory, Sum):C(State, Sum)    9.991648e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# twentyfivetofourtyninesalary C(InsuranceCategory, Sum)                  1.314197e-43
# C(State, Sum)                              1.775446e-18
# C(InsuranceCategory, Sum):C(State, Sum)    9.981320e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fiftytoseventyfoursalary C(InsuranceCategory, Sum)                  1.975549e-49
# C(State, Sum)                              1.283572e-20
# C(InsuranceCategory, Sum):C(State, Sum)    9.831830e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# seventyfivetoninetyninesalary C(InsuranceCategory, Sum)                  4.128161e-54
# C(State, Sum)                              1.809539e-21
# C(InsuranceCategory, Sum):C(State, Sum)    8.958192e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# onehundredandoversalary C(InsuranceCategory, Sum)                  1.461972e-47
# C(State, Sum)                              1.077815e-28
# C(InsuranceCategory, Sum):C(State, Sum)    1.326098e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64

# %%
# ANOVA Test for 2019

healthAnova = health19.rename(columns = {'Insurance_Category':'InsuranceCategory', 'Total_Population':'TotalPopulation', 'Under_6Y':'Undersixyears', \
            '_6_to_18Y':'sixtoeighteenyears',  '_19_to_25Y':'nineteentotwentyfiveyears', '_26_to_34Y':'twentysixtothirtyfouryears', \
            '_35_to_44Y':'thirtyfivetofourtyfouryears', '_45_to_54Y':'fourtyfivetofiftyfouryears', '_55_to_64Y':'fiftyfivetosixtyfouryears', \
            '_65_to_74Y':'sixtyfivetoseventyfouryears', '_75_and_Older':'seventyfiveandmoreyears', \
            'African_American':'AfricanAmerican', 'American_Indian':'AmericanIndian', \
            'Pacific_Islander':'PacificIslander', 'Some_Other_Race':'Someotherrace', \
            'Native_Born':'Nativeborn', 'Foreign_Born':'Foreignborn', 'Not_A_Citizen':'Notacitizen', \
            'Less_Than_High_School':'Lessthanhighschoolgraduate', 'High_School_or_Equivalent':'Highschoolgraduate',  \
            "Some_College":"Somecollege", "Bachelors_or_Higher":"Bachelors", 'Under_25000S':'Undertwentyfive', \
            '_25000_to_49999S':'twentyfivetofourtyninesalary', '_50000_to_74999S':'fiftytoseventyfoursalary', \
            '_75000_to_99999S':'seventyfivetoninetyninesalary', 'Over_100000S':'onehundredandoversalary'}).copy()

anovaColumns = []
for i in list(healthAnova.columns):
    anovaColumns.append(i)

anovaColumns = anovaColumns[4:-1]

for i in anovaColumns:
    data19 = healthAnova[[i, 'InsuranceCategory', 'State']]
    health19_lm = ols(f'{i} ~ C(InsuranceCategory, Sum)*C(State, Sum)', data = data19).fit()

    table = sm.stats.anova_lm(health19_lm, typ = 2)
    print(i, table['PR(>F)'])
# Out:
# Undersixyears C(InsuranceCategory, Sum)                  9.978424e-47
# C(State, Sum)                              2.082104e-18
# C(InsuranceCategory, Sum):C(State, Sum)    6.692977e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# sixtoeighteenyears C(InsuranceCategory, Sum)                  2.674696e-54
# C(State, Sum)                              8.826126e-22
# C(InsuranceCategory, Sum):C(State, Sum)    7.429791e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# nineteentotwentyfiveyears C(InsuranceCategory, Sum)                  1.013831e-42
# C(State, Sum)                              3.777651e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.654195e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# twentysixtothirtyfouryears C(InsuranceCategory, Sum)                  3.696843e-33
# C(State, Sum)                              1.041934e-19
# C(InsuranceCategory, Sum):C(State, Sum)    9.942671e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# thirtyfivetofourtyfouryears C(InsuranceCategory, Sum)                  7.565011e-40
# C(State, Sum)                              2.033669e-21
# C(InsuranceCategory, Sum):C(State, Sum)    9.832771e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fourtyfivetofiftyfouryears C(InsuranceCategory, Sum)                  2.275187e-45
# C(State, Sum)                              1.559277e-21
# C(InsuranceCategory, Sum):C(State, Sum)    9.675196e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fiftyfivetosixtyfouryears C(InsuranceCategory, Sum)                  1.510732e-56
# C(State, Sum)                              1.627277e-22
# C(InsuranceCategory, Sum):C(State, Sum)    8.193975e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# sixtyfivetoseventyfouryears C(InsuranceCategory, Sum)                  7.269419e-43
# C(State, Sum)                              1.404345e-20
# C(InsuranceCategory, Sum):C(State, Sum)    2.623588e-03
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# seventyfiveandmoreyears C(InsuranceCategory, Sum)                  5.314201e-17
# C(State, Sum)                              3.358535e-23
# C(InsuranceCategory, Sum):C(State, Sum)    3.001803e-04
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Male C(InsuranceCategory, Sum)                  1.327423e-48
# C(State, Sum)                              1.070955e-22
# C(InsuranceCategory, Sum):C(State, Sum)    8.959292e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Female C(InsuranceCategory, Sum)                  2.074433e-51
# C(State, Sum)                              7.244458e-21
# C(InsuranceCategory, Sum):C(State, Sum)    8.826983e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# White C(InsuranceCategory, Sum)                  4.154503e-69
# C(State, Sum)                              5.930743e-26
# C(InsuranceCategory, Sum):C(State, Sum)    6.685369e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# AfricanAmerican C(InsuranceCategory, Sum)                  4.741433e-28
# C(State, Sum)                              6.499148e-03
# C(InsuranceCategory, Sum):C(State, Sum)    9.999899e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# AmericanIndian C(InsuranceCategory, Sum)                  1.771851e-12
# C(State, Sum)                              6.490162e-73
# C(InsuranceCategory, Sum):C(State, Sum)    6.389412e-20
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Asian C(InsuranceCategory, Sum)                  1.224668e-12
# C(State, Sum)                              2.235796e-20
# C(InsuranceCategory, Sum):C(State, Sum)    1.351011e-02
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# PacificIslander C(InsuranceCategory, Sum)                  1.793049e-03
# C(State, Sum)                              1.330739e-74
# C(InsuranceCategory, Sum):C(State, Sum)    1.186928e-59
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Someotherrace C(InsuranceCategory, Sum)                  8.156996e-06
# C(State, Sum)                              9.996360e-12
# C(InsuranceCategory, Sum):C(State, Sum)    9.513743e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Hispanic C(InsuranceCategory, Sum)                  1.022547e-10
# C(State, Sum)                              1.524108e-26
# C(InsuranceCategory, Sum):C(State, Sum)    7.423575e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Nativeborn C(InsuranceCategory, Sum)                  1.468667e-66
# C(State, Sum)                              3.241207e-18
# C(InsuranceCategory, Sum):C(State, Sum)    8.684681e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Foreignborn C(InsuranceCategory, Sum)                  6.948797e-11
# C(State, Sum)                              1.920436e-24
# C(InsuranceCategory, Sum):C(State, Sum)    9.629599e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Naturalized C(InsuranceCategory, Sum)                  2.464312e-11
# C(State, Sum)                              9.884960e-22
# C(InsuranceCategory, Sum):C(State, Sum)    4.674692e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Notacitizen C(InsuranceCategory, Sum)                  6.062469e-08
# C(State, Sum)                              3.645640e-25
# C(InsuranceCategory, Sum):C(State, Sum)    9.998330e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Lessthanhighschoolgraduate C(InsuranceCategory, Sum)                  1.419563e-16
# C(State, Sum)                              2.103724e-24
# C(InsuranceCategory, Sum):C(State, Sum)    9.990909e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Highschoolgraduate C(InsuranceCategory, Sum)                  2.104008e-58
# C(State, Sum)                              1.078852e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.511286e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Somecollege C(InsuranceCategory, Sum)                  9.155032e-58
# C(State, Sum)                              7.754458e-28
# C(InsuranceCategory, Sum):C(State, Sum)    5.067687e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Bachelors C(InsuranceCategory, Sum)                  9.130752e-48
# C(State, Sum)                              2.699232e-17
# C(InsuranceCategory, Sum):C(State, Sum)    8.730084e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# Undertwentyfive C(InsuranceCategory, Sum)                  1.347414e-42
# C(State, Sum)                              1.187521e-13
# C(InsuranceCategory, Sum):C(State, Sum)    9.997392e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# twentyfivetofourtyninesalary C(InsuranceCategory, Sum)                  5.243040e-44
# C(State, Sum)                              4.289738e-18
# C(InsuranceCategory, Sum):C(State, Sum)    9.990322e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# fiftytoseventyfoursalary C(InsuranceCategory, Sum)                  4.220315e-48
# C(State, Sum)                              2.779834e-19
# C(InsuranceCategory, Sum):C(State, Sum)    9.971379e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# seventyfivetoninetyninesalary C(InsuranceCategory, Sum)                  5.711568e-54
# C(State, Sum)                              1.725243e-22
# C(InsuranceCategory, Sum):C(State, Sum)    9.187375e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64
# onehundredandoversalary C(InsuranceCategory, Sum)                  7.973545e-48
# C(State, Sum)                              4.603854e-28
# C(InsuranceCategory, Sum):C(State, Sum)    2.168800e-01
# Residual                                            NaN
# Name: PR(>F), dtype: float64

# %% [markdown]
# **Joining all datasets together for the model**

# %%
health_model = pd.concat([health15, health16, health17, health18, health19], axis = 0).copy()

columns = list(health_model.columns)[3:-2]
health_model.fillna(0, inplace = True)
imp = SimpleImputer(strategy = 'mean', missing_values = 0)

health_model[columns] = imp.fit_transform(health_model[columns])
health_model[columns] = health_model[columns].astype(int)

health_model = health_model[health_model['Insurance_Category'] != 'Total']

# %% [markdown]
# **Cleaning testing data to match training data**

# %%
testDemo = spark.read.options(header = 'True').csv("/mnt/healthcare/modeldataIn/CleanedData/TestDemographics.csv").sort('State', 'County').toPandas()

# Making sure the columns are the same for the model and the testing data
counties = []
for i in list(testDemo['County'].sort_values().unique()):
    if i not in list(health_model['County'].sort_values().unique()):
        counties.append(i)

indeces = list(testDemo[testDemo.County.isin(counties) == True].index)
testDemo.drop(index = indeces, inplace = True)

# %% [markdown]
# **Pushing to SQL**

# %%
health_model = spark.createDataFrame(health_model)
testDemo = spark.createDataFrame(testDemo)

table = 'dbo.HealthModel'

health_model.sort('State', 'County').write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
        .mode("append") \
        .option("dbtable", table) \
        .option("user", k_username) \
        .option("password", k_password) \
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
        .save()

table = "dbo.TestDemo"

testDemo.sort('State', 'County').write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
        .mode("append") \
        .option("dbtable", table) \
        .option("user", k_username) \
        .option("password", k_password) \
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
        .save()
