# %%
import pyspark.sql.functions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.sql.functions import *
from pyspark.sql.types import StringType,DecimalType
from pyspark.sql.functions import input_file_name, substring
from pyspark.sql.functions import isnan, when, count, col

# Importing important info
from config import database, server, k_username, k_password

# Kafka producer and consumer imports
from confluent_kafka import Producer, Consumer, KafkaError, KafkaException, TopicPartition
from time import sleep
import uuid
import json
from confluent_kafka.admin import AdminClient, NewTopic

# %%
###### Mount Point 1 through Oauth security.
storageAccount = "gen10datafund2207"
storageContainer = "healthcare-capstone-group3"
clientSecret = "Cty8Q~AvEO_qC-MjvPvosYauiNsffOHKnMpj7cmd"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/healthcare/dataIn" # the mount point will be unique to you

configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

dbutils.fs.mount(
source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
mount_point = mount_point,
extra_configs = configs)
# Out:
# /mnt/healthcare/dataIn has been unmounted.
# Out[43]: True

# %%
State = spark.read.options(header = 'True').csv("/mnt/healthcare/dataIn/CleanedData/State.csv").sort('StateName').toPandas()
County = spark.read.options(header = 'True').csv("/mnt/healthcare/dataIn/CleanedData/County.csv").sort('CountyName').toPandas()

# %% [markdown]
# **Kafka Consumer**

# %%
# Error function

def error_cb(err):
    """ The error callback is used for generic client errors. These
        errors are generally to be considered informational as the client will
        automatically try to recover from all errors, and no extra action
        is typically required by the application.
        For this example however, we terminate the application if the client
        is unable to connect to any broker (_ALL_BROKERS_DOWN) and on
        authentication errors (_AUTHENTICATION). """

    print("Client error: {}".format(err))
    if err.code() == KafkaError._ALL_BROKERS_DOWN or \
       err.code() == KafkaError._AUTHENTICATION:
        # Any exception raised from this callback will be re-raised from the
        # triggering flush() or poll() call.
        raise KafkaException(err)

# %%
#KAFKA variables, Move to the OS variables or configuration
# This will work in local Jupyter Notebook, but in a databrick, hiding config.py is tougher. 
confluentClusterName = "stage3talent"
confluentBootstrapServers = "pkc-ldvmy.centralus.azure.confluent.cloud:9092"

# Topic name
confluentTopicName = "healthcare-insurance"

schemaRegistryUrl = "https://psrc-gq7pv.westus2.azure.confluent.cloud"
confluentApiKey = "YHMHG7E54LJA55XZ"
confluentSecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"
confluentRegistryApiKey = "YHMHG7E54LJA55XZ"
confluentRegistrySecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"

#Kakfa Class Setup.
c = Consumer({
    'bootstrap.servers': confluentBootstrapServers,
    'sasl.mechanism': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': confluentApiKey,
    'sasl.password': confluentSecret,
    'group.id': str(uuid.uuid1()),  # this will create a new consumer group on each invocation.
    'auto.offset.reset': 'earliest',
    'error_cb': error_cb,
})

c.subscribe([confluentTopicName])

# %% [markdown]
# **Health Insurance Characteristics Consumer**

# %%
healthstring = {}
healthListDict = []

for i in range(2_520):
    try:
        message = c.poll(timeout=1.0)
        if message is None:
            break
        elif message.error():
            print("Consumer error: {}".format(message.error()))
            break
        else:
            healthstring = json.loads('{}'.format(message.value().decode('utf-8')))
            healthListDict.append(healthstring)

    except Exception as e:
        print(e)

print(json.dumps(healthListDict, indent=1, sort_keys=True))
# Out:
# [
#  {
#   "African_American": "17668",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "51187",
#   "County": "Baldwin County",
#   "Female": "113950",
#   "Foreign_Born": "11002",
#   "High_School_or_Equivalet": "39988",
#   "Hispanic": "10517",
#   "Less_than_High_School": "14600",
#   "Male": "106961",
#   "Native_Born": "209909",
#   "Naturalized": "4495",
#   "Not_a_Citizen": "6507",
#   "Over_100000S": "76781",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "49486",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "220911",
#   "Under_25000S": "28456",
#   "Under_6_Y": "13169",
#   "White": "189325",
#   "_19_to_25_Y": "16549",
#   "_25000_to_49999S": "52417",
#   "_26_to_34_Y": "21835",
#   "_35_to_44_Y": "27872",
#   "_45_to_54_Y": "27174",
#   "_50000_to_74999S": "26888",
#   "_55_to_64_Y": "31542",
#   "_65_to_74_Y": "28682",
#   "_6_to_18_Y": "35932",
#   "_75000_to_99999S": "35705",
#   "_75_and_Older": "18156"
#  },
#  {
#   "African_American": "16020",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "49273",
#   "County": "Baldwin County",
#   "Female": "105903",
#   "Foreign_Born": "7720",
#   "High_School_or_Equivalet": "34826",
#   "Hispanic": "7601",
#   "Less_than_High_School": "11492",
#   "Male": "97080",
#   "Native_Born": "195263",
#   "Naturalized": "4070",
#   "Not_a_Citizen": "3650",
#   "Over_100000S": "73976",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "45898",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "202983",
#   "Under_25000S": "24708",
#   "Under_6_Y": "12868",
#   "White": "175379",
#   "_19_to_25_Y": "13734",
#   "_25000_to_49999S": "46458",
#   "_26_to_34_Y": "17251",
#   "_35_to_44_Y": "24272",
#   "_45_to_54_Y": "24410",
#   "_50000_to_74999S": "24647",
#   "_55_to_64_Y": "29073",
#   "_65_to_74_Y": "28327",
#   "_6_to_18_Y": "34892",
#   "_75000_to_99999S": "32639",
#   "_75_and_Older": "18156"
#  },
#  {
#   "African_American": "1648",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "1914",
#   "County": "Baldwin County",
#   "Female": "8047",
#   "Foreign_Born": "3282",
#   "High_School_or_Equivalet": "5162",
#   "Hispanic": "2916",
#   "Less_than_High_School": "3108",
#   "Male": "9881",
#   "Native_Born": "14646",
#   "Naturalized": "425",
#   "Not_a_Citizen": "2857",
#   "Over_100000S": "2805",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "3588",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "17928",
#   "Under_25000S": "3748",
#   "Under_6_Y": "301",
#   "White": "13946",
#   "_19_to_25_Y": "2815",
#   "_25000_to_49999S": "5959",
#   "_26_to_34_Y": "4584",
#   "_35_to_44_Y": "3600",
#   "_45_to_54_Y": "2764",
#   "_50000_to_74999S": "2241",
#   "_55_to_64_Y": "2469",
#   "_65_to_74_Y": "355",
#   "_6_to_18_Y": "1040",
#   "_75000_to_99999S": "3066",
#   "_75_and_Older": "0"
#  },
#  {
#   "African_American": "24662",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "14547",
#   "County": "Calhoun County",
#   "Female": "58633",
#   "Foreign_Born": "1720",
#   "High_School_or_Equivalet": "26149",
#   "Hispanic": "4542",
#   "Less_than_High_School": "12026",
#   "Male": "52442",
#   "Native_Born": "109355",
#   "Naturalized": "461",
#   "Not_a_Citizen": "1259",
#   "Over_100000S": "25919",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "22612",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "111075",
#   "Under_25000S": "21181",
#   "Under_6_Y": "8110",
#   "White": "80403",
#   "_19_to_25_Y": "10554",
#   "_25000_to_49999S": "25575",
#   "_26_to_34_Y": "12820",
#   "_35_to_44_Y": "13495",
#   "_45_to_54_Y": "13075",
#   "_50000_to_74999S": "21638",
#   "_55_to_64_Y": "15799",
#   "_65_to_74_Y": "12017",
#   "_6_to_18_Y": "17077",
#   "_75000_to_99999S": "14995",
#   "_75_and_Older": "8128"
#  },
#  {
#   "African_American": "21741",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "14200",
#   "County": "Calhoun County",
#   "Female": "53597",
#   "Foreign_Born": "704",
#   "High_School_or_Equivalet": "21375",
#   "Hispanic": "3437",
#   "Less_than_High_School": "9125",
#   "Male": "45199",
#   "Native_Born": "98092",
#   "Naturalized": "461",
#   "Not_a_Citizen": "243",
#   "Over_100000S": "25449",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "20069",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "98796",
#   "Under_25000S": "16724",
#   "Under_6_Y": "7769",
#   "White": "72983",
#   "_19_to_25_Y": "9747",
#   "_25000_to_49999S": "22678",
#   "_26_to_34_Y": "9718",
#   "_35_to_44_Y": "9901",
#   "_45_to_54_Y": "11178",
#   "_50000_to_74999S": "18484",
#   "_55_to_64_Y": "13918",
#   "_65_to_74_Y": "11926",
#   "_6_to_18_Y": "16511",
#   "_75000_to_99999S": "13940",
#   "_75_and_Older": "8128"
#  },
#  {
#   "African_American": "2921",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "347",
#   "County": "Calhoun County",
#   "Female": "5036",
#   "Foreign_Born": "1016",
#   "High_School_or_Equivalet": "4774",
#   "Hispanic": "1105",
#   "Less_than_High_School": "2901",
#   "Male": "7243",
#   "Native_Born": "11263",
#   "Naturalized": "0",
#   "Not_a_Citizen": "1016",
#   "Over_100000S": "470",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "2543",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "12279",
#   "Under_25000S": "4457",
#   "Under_6_Y": "341",
#   "White": "7420",
#   "_19_to_25_Y": "807",
#   "_25000_to_49999S": "2897",
#   "_26_to_34_Y": "3102",
#   "_35_to_44_Y": "3594",
#   "_45_to_54_Y": "1897",
#   "_50000_to_74999S": "3154",
#   "_55_to_64_Y": "1881",
#   "_65_to_74_Y": "91",
#   "_6_to_18_Y": "566",
#   "_75000_to_99999S": "1055",
#   "_75_and_Older": "0"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "9080",
#   "County": "Cullman County",
#   "Female": "42887",
#   "Foreign_Born": "2196",
#   "High_School_or_Equivalet": "17418",
#   "Hispanic": "0",
#   "Less_than_High_School": "10472",
#   "Male": "39954",
#   "Native_Born": "80645",
#   "Naturalized": "800",
#   "Not_a_Citizen": "1396",
#   "Over_100000S": "15107",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "20132",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "82841",
#   "Under_25000S": "9454",
#   "Under_6_Y": "6165",
#   "White": "78892",
#   "_19_to_25_Y": "6152",
#   "_25000_to_49999S": "18678",
#   "_26_to_34_Y": "9554",
#   "_35_to_44_Y": "10186",
#   "_45_to_54_Y": "11307",
#   "_50000_to_74999S": "23542",
#   "_55_to_64_Y": "11009",
#   "_65_to_74_Y": "8973",
#   "_6_to_18_Y": "13422",
#   "_75000_to_99999S": "15686",
#   "_75_and_Older": "6073"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "8558",
#   "County": "Cullman County",
#   "Female": "38807",
#   "Foreign_Born": "1678",
#   "High_School_or_Equivalet": "14395",
#   "Hispanic": "0",
#   "Less_than_High_School": "9104",
#   "Male": "35290",
#   "Native_Born": "72419",
#   "Naturalized": "788",
#   "Not_a_Citizen": "890",
#   "Over_100000S": "14209",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "17309",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "74097",
#   "Under_25000S": "7764",
#   "Under_6_Y": "6165",
#   "White": "70423",
#   "_19_to_25_Y": "5486",
#   "_25000_to_49999S": "16656",
#   "_26_to_34_Y": "6859",
#   "_35_to_44_Y": "8350",
#   "_45_to_54_Y": "9588",
#   "_50000_to_74999S": "21335",
#   "_55_to_64_Y": "9676",
#   "_65_to_74_Y": "8820",
#   "_6_to_18_Y": "13080",
#   "_75000_to_99999S": "13766",
#   "_75_and_Older": "6073"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "522",
#   "County": "Cullman County",
#   "Female": "4080",
#   "Foreign_Born": "518",
#   "High_School_or_Equivalet": "3023",
#   "Hispanic": "0",
#   "Less_than_High_School": "1368",
#   "Male": "4664",
#   "Native_Born": "8226",
#   "Naturalized": "12",
#   "Not_a_Citizen": "506",
#   "Over_100000S": "898",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "2823",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "8744",
#   "Under_25000S": "1690",
#   "Under_6_Y": "0",
#   "White": "8469",
#   "_19_to_25_Y": "666",
#   "_25000_to_49999S": "2022",
#   "_26_to_34_Y": "2695",
#   "_35_to_44_Y": "1836",
#   "_45_to_54_Y": "1719",
#   "_50000_to_74999S": "2207",
#   "_55_to_64_Y": "1333",
#   "_65_to_74_Y": "153",
#   "_6_to_18_Y": "342",
#   "_75000_to_99999S": "1920",
#   "_75_and_Older": "0"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "5930",
#   "County": "DeKalb County",
#   "Female": "35528",
#   "Foreign_Born": "5018",
#   "High_School_or_Equivalet": "17183",
#   "Hispanic": "0",
#   "Less_than_High_School": "9531",
#   "Male": "34864",
#   "Native_Born": "65374",
#   "Naturalized": "234",
#   "Not_a_Citizen": "4784",
#   "Over_100000S": "13385",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "12915",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "70392",
#   "Under_25000S": "16269",
#   "Under_6_Y": "5335",
#   "White": "58715",
#   "_19_to_25_Y": "6066",
#   "_25000_to_49999S": "15522",
#   "_26_to_34_Y": "7627",
#   "_35_to_44_Y": "8927",
#   "_45_to_54_Y": "8665",
#   "_50000_to_74999S": "16053",
#   "_55_to_64_Y": "8829",
#   "_65_to_74_Y": "6970",
#   "_6_to_18_Y": "13432",
#   "_75000_to_99999S": "8925",
#   "_75_and_Older": "4541"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "5748",
#   "County": "DeKalb County",
#   "Female": "31163",
#   "Foreign_Born": "2354",
#   "High_School_or_Equivalet": "14917",
#   "Hispanic": "0",
#   "Less_than_High_School": "6199",
#   "Male": "29306",
#   "Native_Born": "58115",
#   "Naturalized": "234",
#   "Not_a_Citizen": "2120",
#   "Over_100000S": "12138",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "10877",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "60469",
#   "Under_25000S": "12327",
#   "Under_6_Y": "5041",
#   "White": "51641",
#   "_19_to_25_Y": "4436",
#   "_25000_to_49999S": "13731",
#   "_26_to_34_Y": "5233",
#   "_35_to_44_Y": "6855",
#   "_45_to_54_Y": "7003",
#   "_50000_to_74999S": "14644",
#   "_55_to_64_Y": "7470",
#   "_65_to_74_Y": "6639",
#   "_6_to_18_Y": "13251",
#   "_75000_to_99999S": "7391",
#   "_75_and_Older": "4541"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "182",
#   "County": "DeKalb County",
#   "Female": "4365",
#   "Foreign_Born": "2664",
#   "High_School_or_Equivalet": "2266",
#   "Hispanic": "0",
#   "Less_than_High_School": "3332",
#   "Male": "5558",
#   "Native_Born": "7259",
#   "Naturalized": "0",
#   "Not_a_Citizen": "2664",
#   "Over_100000S": "1247",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "2038",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "9923",
#   "Under_25000S": "3942",
#   "Under_6_Y": "294",
#   "White": "7074",
#   "_19_to_25_Y": "1630",
#   "_25000_to_49999S": "1791",
#   "_26_to_34_Y": "2394",
#   "_35_to_44_Y": "2072",
#   "_45_to_54_Y": "1662",
#   "_50000_to_74999S": "1409",
#   "_55_to_64_Y": "1359",
#   "_65_to_74_Y": "331",
#   "_6_to_18_Y": "181",
#   "_75000_to_99999S": "1534",
#   "_75_and_Older": "0"
#  },
#  {
#   "African_American": "15049",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "13300",
#   "County": "Elmore County",
#   "Female": "39415",
#   "Foreign_Born": "2020",
#   "High_School_or_Equivalet": "17794",
#   "Hispanic": "0",
#   "Less_than_High_School": "4322",
#   "Male": "35994",
#   "Native_Born": "73389",
#   "Naturalized": "446",
#   "Not_a_Citizen": "1574",
#   "Over_100000S": "26645",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "15911",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "75409",
#   "Under_25000S": "8697",
#   "Under_6_Y": "6129",
#   "White": "58869",
#   "_19_to_25_Y": "5114",
#   "_25000_to_49999S": "15217",
#   "_26_to_34_Y": "10503",
#   "_35_to_44_Y": "8404",
#   "_45_to_54_Y": "9590",
#   "_50000_to_74999S": "15246",
#   "_55_to_64_Y": "10468",
#   "_65_to_74_Y": "7587",
#   "_6_to_18_Y": "12839",
#   "_75000_to_99999S": "9604",
#   "_75_and_Older": "4775"
#  },
#  {
#   "African_American": "14105",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "13243",
#   "County": "Elmore County",
#   "Female": "37450",
#   "Foreign_Born": "1444",
#   "High_School_or_Equivalet": "16422",
#   "Hispanic": "0",
#   "Less_than_High_School": "3445",
#   "Male": "33460",
#   "Native_Born": "69466",
#   "Naturalized": "446",
#   "Not_a_Citizen": "998",
#   "Over_100000S": "26174",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "15211",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "70910",
#   "Under_25000S": "7919",
#   "Under_6_Y": "5836",
#   "White": "55405",
#   "_19_to_25_Y": "4559",
#   "_25000_to_49999S": "13493",
#   "_26_to_34_Y": "9737",
#   "_35_to_44_Y": "7567",
#   "_45_to_54_Y": "8767",
#   "_50000_to_74999S": "14469",
#   "_55_to_64_Y": "9888",
#   "_65_to_74_Y": "7587",
#   "_6_to_18_Y": "12194",
#   "_75000_to_99999S": "8855",
#   "_75_and_Older": "4775"
#  },
#  {
#   "African_American": "944",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "57",
#   "County": "Elmore County",
#   "Female": "1965",
#   "Foreign_Born": "576",
#   "High_School_or_Equivalet": "1372",
#   "Hispanic": "0",
#   "Less_than_High_School": "877",
#   "Male": "2534",
#   "Native_Born": "3923",
#   "Naturalized": "0",
#   "Not_a_Citizen": "576",
#   "Over_100000S": "471",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "700",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "4499",
#   "Under_25000S": "778",
#   "Under_6_Y": "293",
#   "White": "3464",
#   "_19_to_25_Y": "555",
#   "_25000_to_49999S": "1724",
#   "_26_to_34_Y": "766",
#   "_35_to_44_Y": "837",
#   "_45_to_54_Y": "823",
#   "_50000_to_74999S": "777",
#   "_55_to_64_Y": "580",
#   "_65_to_74_Y": "0",
#   "_6_to_18_Y": "645",
#   "_75000_to_99999S": "749",
#   "_75_and_Older": "0"
#  },
#  {
#   "African_American": "15798",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "12169",
#   "County": "Etowah County",
#   "Female": "52699",
#   "Foreign_Born": "2999",
#   "High_School_or_Equivalet": "22336",
#   "Hispanic": "4230",
#   "Less_than_High_School": "10996",
#   "Male": "48771",
#   "Native_Born": "98471",
#   "Naturalized": "2081",
#   "Not_a_Citizen": "918",
#   "Over_100000S": "20872",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "24245",
#   "Some_Other_Race": "3207",
#   "State": "Alabama",
#   "Total_Population": "101470",
#   "Under_25000S": "24089",
#   "Under_6_Y": "6850",
#   "White": "79432",
#   "_19_to_25_Y": "8914",
#   "_25000_to_49999S": "24693",
#   "_26_to_34_Y": "10993",
#   "_35_to_44_Y": "11934",
#   "_45_to_54_Y": "13583",
#   "_50000_to_74999S": "20113",
#   "_55_to_64_Y": "13661",
#   "_65_to_74_Y": "11278",
#   "_6_to_18_Y": "15960",
#   "_75000_to_99999S": "11232",
#   "_75_and_Older": "8297"
#  },
#  {
#   "African_American": "12837",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "11162",
#   "County": "Etowah County",
#   "Female": "46515",
#   "Foreign_Born": "2335",
#   "High_School_or_Equivalet": "19289",
#   "Hispanic": "2917",
#   "Less_than_High_School": "8630",
#   "Male": "41570",
#   "Native_Born": "85750",
#   "Naturalized": "1823",
#   "Not_a_Citizen": "512",
#   "Over_100000S": "20451",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "21355",
#   "Some_Other_Race": "1864",
#   "State": "Alabama",
#   "Total_Population": "88085",
#   "Under_25000S": "17743",
#   "Under_6_Y": "6052",
#   "White": "71052",
#   "_19_to_25_Y": "7034",
#   "_25000_to_49999S": "21305",
#   "_26_to_34_Y": "8090",
#   "_35_to_44_Y": "9879",
#   "_45_to_54_Y": "11903",
#   "_50000_to_74999S": "18278",
#   "_55_to_64_Y": "11273",
#   "_65_to_74_Y": "10994",
#   "_6_to_18_Y": "14563",
#   "_75000_to_99999S": "9967",
#   "_75_and_Older": "8297"
#  },
#  {
#   "African_American": "2961",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "1007",
#   "County": "Etowah County",
#   "Female": "6184",
#   "Foreign_Born": "664",
#   "High_School_or_Equivalet": "3047",
#   "Hispanic": "1313",
#   "Less_than_High_School": "2366",
#   "Male": "7201",
#   "Native_Born": "12721",
#   "Naturalized": "258",
#   "Not_a_Citizen": "406",
#   "Over_100000S": "421",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "2890",
#   "Some_Other_Race": "1343",
#   "State": "Alabama",
#   "Total_Population": "13385",
#   "Under_25000S": "6346",
#   "Under_6_Y": "798",
#   "White": "8380",
#   "_19_to_25_Y": "1880",
#   "_25000_to_49999S": "3388",
#   "_26_to_34_Y": "2903",
#   "_35_to_44_Y": "2055",
#   "_45_to_54_Y": "1680",
#   "_50000_to_74999S": "1835",
#   "_55_to_64_Y": "2388",
#   "_65_to_74_Y": "284",
#   "_6_to_18_Y": "1397",
#   "_75000_to_99999S": "1265",
#   "_75_and_Older": "0"
#  },
#  {
#   "African_American": "29225",
#   "American_Indian": "0",
#   "Asian": "946",
#   "Bachelors_Degree_or_Higher": "16164",
#   "County": "Houston County",
#   "Female": "54818",
#   "Foreign_Born": "3587",
#   "High_School_or_Equivalet": "21625",
#   "Hispanic": "3595",
#   "Less_than_High_School": "10364",
#   "Male": "49786",
#   "Native_Born": "101017",
#   "Naturalized": "1945",
#   "Not_a_Citizen": "1642",
#   "Over_100000S": "26776",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "22226",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "104604",
#   "Under_25000S": "21698",
#   "Under_6_Y": "7846",
#   "White": "70844",
#   "_19_to_25_Y": "8471",
#   "_25000_to_49999S": "23680",
#   "_26_to_34_Y": "11548",
#   "_35_to_44_Y": "13018",
#   "_45_to_54_Y": "12931",
#   "_50000_to_74999S": "21341",
#   "_55_to_64_Y": "14260",
#   "_65_to_74_Y": "11017",
#   "_6_to_18_Y": "17908",
#   "_75000_to_99999S": "10882",
#   "_75_and_Older": "7605"
#  },
#  {
#   "African_American": "24754",
#   "American_Indian": "0",
#   "Asian": "748",
#   "Bachelors_Degree_or_Higher": "15511",
#   "County": "Houston County",
#   "Female": "48986",
#   "Foreign_Born": "1988",
#   "High_School_or_Equivalet": "17413",
#   "Hispanic": "2271",
#   "Less_than_High_School": "8316",
#   "Male": "42174",
#   "Native_Born": "89172",
#   "Naturalized": "1596",
#   "Not_a_Citizen": "392",
#   "Over_100000S": "25360",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "18981",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "91160",
#   "Under_25000S": "17518",
#   "Under_6_Y": "7716",
#   "White": "62460",
#   "_19_to_25_Y": "5933",
#   "_25000_to_49999S": "19471",
#   "_26_to_34_Y": "8246",
#   "_35_to_44_Y": "9888",
#   "_45_to_54_Y": "10658",
#   "_50000_to_74999S": "18533",
#   "_55_to_64_Y": "12897",
#   "_65_to_74_Y": "10992",
#   "_6_to_18_Y": "17290",
#   "_75000_to_99999S": "10106",
#   "_75_and_Older": "7540"
#  },
#  {
#   "African_American": "4471",
#   "American_Indian": "0",
#   "Asian": "198",
#   "Bachelors_Degree_or_Higher": "653",
#   "County": "Houston County",
#   "Female": "5832",
#   "Foreign_Born": "1599",
#   "High_School_or_Equivalet": "4212",
#   "Hispanic": "1324",
#   "Less_than_High_School": "2048",
#   "Male": "7612",
#   "Native_Born": "11845",
#   "Naturalized": "349",
#   "Not_a_Citizen": "1250",
#   "Over_100000S": "1416",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "3245",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "13444",
#   "Under_25000S": "4180",
#   "Under_6_Y": "130",
#   "White": "8384",
#   "_19_to_25_Y": "2538",
#   "_25000_to_49999S": "4209",
#   "_26_to_34_Y": "3302",
#   "_35_to_44_Y": "3130",
#   "_45_to_54_Y": "2273",
#   "_50000_to_74999S": "2808",
#   "_55_to_64_Y": "1363",
#   "_65_to_74_Y": "25",
#   "_6_to_18_Y": "618",
#   "_75000_to_99999S": "776",
#   "_75_and_Older": "65"
#  },
#  {
#   "African_American": "282433",
#   "American_Indian": "0",
#   "Asian": "11419",
#   "Bachelors_Degree_or_Higher": "152470",
#   "County": "Jefferson County",
#   "Female": "344872",
#   "Foreign_Born": "24933",
#   "High_School_or_Equivalet": "116523",
#   "Hispanic": "26820",
#   "Less_than_High_School": "38113",
#   "Male": "308093",
#   "Native_Born": "628032",
#   "Naturalized": "10272",
#   "Not_a_Citizen": "14661",
#   "Over_100000S": "209093",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "130584",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "652965",
#   "Under_25000S": "113215",
#   "Under_6_Y": "51016",
#   "White": "338890",
#   "_19_to_25_Y": "57242",
#   "_25000_to_49999S": "139325",
#   "_26_to_34_Y": "86125",
#   "_35_to_44_Y": "83453",
#   "_45_to_54_Y": "77839",
#   "_50000_to_74999S": "109246",
#   "_55_to_64_Y": "84633",
#   "_65_to_74_Y": "64247",
#   "_6_to_18_Y": "107017",
#   "_75000_to_99999S": "72085",
#   "_75_and_Older": "41393"
#  },
#  {
#   "African_American": "251560",
#   "American_Indian": "0",
#   "Asian": "10229",
#   "Bachelors_Degree_or_Higher": "145724",
#   "County": "Jefferson County",
#   "Female": "317197",
#   "Foreign_Born": "18061",
#   "High_School_or_Equivalet": "98060",
#   "Hispanic": "20697",
#   "Less_than_High_School": "28759",
#   "Male": "274118",
#   "Native_Born": "573254",
#   "Naturalized": "9293",
#   "Not_a_Citizen": "8768",
#   "Over_100000S": "201348",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "117333",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "591315",
#   "Under_25000S": "97811",
#   "Under_6_Y": "49285",
#   "White": "313445",
#   "_19_to_25_Y": "48362",
#   "_25000_to_49999S": "117990",
#   "_26_to_34_Y": "71846",
#   "_35_to_44_Y": "71032",
#   "_45_to_54_Y": "67561",
#   "_50000_to_74999S": "98570",
#   "_55_to_64_Y": "74179",
#   "_65_to_74_Y": "64122",
#   "_6_to_18_Y": "103792",
#   "_75000_to_99999S": "67194",
#   "_75_and_Older": "41136"
#  },
#  {
#   "African_American": "30873",
#   "American_Indian": "0",
#   "Asian": "1190",
#   "Bachelors_Degree_or_Higher": "6746",
#   "County": "Jefferson County",
#   "Female": "27675",
#   "Foreign_Born": "6872",
#   "High_School_or_Equivalet": "18463",
#   "Hispanic": "6123",
#   "Less_than_High_School": "9354",
#   "Male": "33975",
#   "Native_Born": "54778",
#   "Naturalized": "979",
#   "Not_a_Citizen": "5893",
#   "Over_100000S": "7745",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "13251",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "61650",
#   "Under_25000S": "15404",
#   "Under_6_Y": "1731",
#   "White": "25445",
#   "_19_to_25_Y": "8880",
#   "_25000_to_49999S": "21335",
#   "_26_to_34_Y": "14279",
#   "_35_to_44_Y": "12421",
#   "_45_to_54_Y": "10278",
#   "_50000_to_74999S": "10676",
#   "_55_to_64_Y": "10454",
#   "_65_to_74_Y": "125",
#   "_6_to_18_Y": "3225",
#   "_75000_to_99999S": "4891",
#   "_75_and_Older": "257"
#  },
#  {
#   "African_American": "10476",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "13609",
#   "County": "Lauderdale County",
#   "Female": "47330",
#   "Foreign_Born": "995",
#   "High_School_or_Equivalet": "21702",
#   "Hispanic": "0",
#   "Less_than_High_School": "9025",
#   "Male": "44515",
#   "Native_Born": "90850",
#   "Naturalized": "381",
#   "Not_a_Citizen": "614",
#   "Over_100000S": "20409",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "18142",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "91845",
#   "Under_25000S": "16789",
#   "Under_6_Y": "4302",
#   "White": "78351",
#   "_19_to_25_Y": "9367",
#   "_25000_to_49999S": "22619",
#   "_26_to_34_Y": "9617",
#   "_35_to_44_Y": "10533",
#   "_45_to_54_Y": "10981",
#   "_50000_to_74999S": "15023",
#   "_55_to_64_Y": "12319",
#   "_65_to_74_Y": "11248",
#   "_6_to_18_Y": "15698",
#   "_75000_to_99999S": "16025",
#   "_75_and_Older": "7780"
#  },
#  {
#   "African_American": "8568",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "13193",
#   "County": "Lauderdale County",
#   "Female": "41352",
#   "Foreign_Born": "411",
#   "High_School_or_Equivalet": "18102",
#   "Hispanic": "0",
#   "Less_than_High_School": "7055",
#   "Male": "39748",
#   "Native_Born": "80689",
#   "Naturalized": "381",
#   "Not_a_Citizen": "30",
#   "Over_100000S": "18917",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "16323",
#   "Some_Other_Race": "0",
#   "State": "Alabama",
#   "Total_Population": "81100",
#   "Under_25000S": "13822",
#   "Under_6_Y": "3727",
#   "White": "70323",
#   "_19_to_25_Y": "8117",
#   "_25000_to_49999S": "18496",
#   "_26_to_34_Y": "7201",
#   "_35_to_44_Y": "7951",
#   "_45_to_54_Y": "9189",
#   "_50000_to_74999S": "13848",
#   "_55_to_64_Y": "11304",
#   "_65_to_74_Y": "11248",
#   "_6_to_18_Y": "14583",
#   "_75000_to_99999S": "15210",
#   "_75_and_Older": "7780"
#  },
#  {
#   "African_American": "1908",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "416",
#   "County": "Lauderdale County",
#   "Female": "5978",
#   "Foreign_Born": "584",
#   "High_School_or_Equivalet": "3600",
#   "Hispanic": "0",
#   "Less_than_High_School": "1970",
#   "Male": "4767",
#   "Native_Born": "10161",
#   "Naturalized": "0",
#   "Not_a_Citizen": "584",
#   "Over_100000S": "1492",
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#
#   "_75000_to_99999S": "15059",
#   "_75_and_Older": "8011"
#  },
#  {
#   "African_American": "2780",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "13470",
#   "County": "Lawrence County",
#   "Female": "41414",
#   "Foreign_Born": "1267",
#   "High_School_or_Equivalet": "25141",
#   "Hispanic": "0",
#   "Less_than_High_School": "3843",
#   "Male": "38469",
#   "Native_Born": "78616",
#   "Naturalized": "959",
#   "Not_a_Citizen": "308",
#   "Over_100000S": "19403",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "14240",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "79883",
#   "Under_25000S": "11328",
#   "Under_6_Y": "5218",
#   "White": "73844",
#   "_19_to_25_Y": "6267",
#   "_25000_to_49999S": "17748",
#   "_26_to_34_Y": "7929",
#   "_35_to_44_Y": "8242",
#   "_45_to_54_Y": "10064",
#   "_50000_to_74999S": "15889",
#   "_55_to_64_Y": "12032",
#   "_65_to_74_Y": "10416",
#   "_6_to_18_Y": "11704",
#   "_75000_to_99999S": "14489",
#   "_75_and_Older": "8011"
#  },
#  {
#   "African_American": "108",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "498",
#   "County": "Lawrence County",
#   "Female": "2182",
#   "Foreign_Born": "113",
#   "High_School_or_Equivalet": "1318",
#   "Hispanic": "0",
#   "Less_than_High_School": "673",
#   "Male": "2480",
#   "Native_Born": "4549",
#   "Naturalized": "0",
#   "Not_a_Citizen": "113",
#   "Over_100000S": "712",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "840",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "4662",
#   "Under_25000S": "537",
#   "Under_6_Y": "248",
#   "White": "4288",
#   "_19_to_25_Y": "670",
#   "_25000_to_49999S": "1991",
#   "_26_to_34_Y": "838",
#   "_35_to_44_Y": "783",
#   "_45_to_54_Y": "609",
#   "_50000_to_74999S": "717",
#   "_55_to_64_Y": "1057",
#   "_65_to_74_Y": "42",
#   "_6_to_18_Y": "415",
#   "_75000_to_99999S": "570",
#   "_75_and_Older": "0"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "20157",
#   "County": "Lebanon County",
#   "Female": "71173",
#   "Foreign_Born": "6195",
#   "High_School_or_Equivalet": "41284",
#   "Hispanic": "20022",
#   "Less_than_High_School": "12719",
#   "Male": "68712",
#   "Native_Born": "133690",
#   "Naturalized": "3705",
#   "Not_a_Citizen": "2490",
#   "Over_100000S": "45760",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "20876",
#   "Some_Other_Race": "10308",
#   "State": "Pennsylvania",
#   "Total_Population": "139885",
#   "Under_25000S": "15338",
#   "Under_6_Y": "9330",
#   "White": "120140",
#   "_19_to_25_Y": "12121",
#   "_25000_to_49999S": "24059",
#   "_26_to_34_Y": "15764",
#   "_35_to_44_Y": "16017",
#   "_45_to_54_Y": "17583",
#   "_50000_to_74999S": "30052",
#   "_55_to_64_Y": "19593",
#   "_65_to_74_Y": "14762",
#   "_6_to_18_Y": "23398",
#   "_75000_to_99999S": "22828",
#   "_75_and_Older": "11317"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "19592",
#   "County": "Lebanon County",
#   "Female": "66029",
#   "Foreign_Born": "4905",
#   "High_School_or_Equivalet": "39058",
#   "Hispanic": "17220",
#   "Less_than_High_School": "10091",
#   "Male": "63314",
#   "Native_Born": "124438",
#   "Naturalized": "3572",
#   "Not_a_Citizen": "1333",
#   "Over_100000S": "43282",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "19154",
#   "Some_Other_Race": "9098",
#   "State": "Pennsylvania",
#   "Total_Population": "129343",
#   "Under_25000S": "13776",
#   "Under_6_Y": "8118",
#   "White": "113291",
#   "_19_to_25_Y": "11187",
#   "_25000_to_49999S": "22681",
#   "_26_to_34_Y": "12184",
#   "_35_to_44_Y": "14709",
#   "_45_to_54_Y": "16379",
#   "_50000_to_74999S": "26298",
#   "_55_to_64_Y": "18739",
#   "_65_to_74_Y": "14598",
#   "_6_to_18_Y": "22143",
#   "_75000_to_99999S": "21523",
#   "_75_and_Older": "11286"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "565",
#   "County": "Lebanon County",
#   "Female": "5144",
#   "Foreign_Born": "1290",
#   "High_School_or_Equivalet": "2226",
#   "Hispanic": "2802",
#   "Less_than_High_School": "2628",
#   "Male": "5398",
#   "Native_Born": "9252",
#   "Naturalized": "133",
#   "Not_a_Citizen": "1157",
#   "Over_100000S": "2478",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "1722",
#   "Some_Other_Race": "1210",
#   "State": "Pennsylvania",
#   "Total_Population": "10542",
#   "Under_25000S": "1562",
#   "Under_6_Y": "1212",
#   "White": "6849",
#   "_19_to_25_Y": "934",
#   "_25000_to_49999S": "1378",
#   "_26_to_34_Y": "3580",
#   "_35_to_44_Y": "1308",
#   "_45_to_54_Y": "1204",
#   "_50000_to_74999S": "3754",
#   "_55_to_64_Y": "854",
#   "_65_to_74_Y": "164",
#   "_6_to_18_Y": "1255",
#   "_75000_to_99999S": "1305",
#   "_75_and_Older": "31"
#  },
#  {
#   "African_American": "31031",
#   "American_Indian": "0",
#   "Asian": "12177",
#   "Bachelors_Degree_or_Higher": "73103",
#   "County": "Lehigh County",
#   "Female": "185647",
#   "Foreign_Born": "42508",
#   "High_School_or_Equivalet": "85721",
#   "Hispanic": "95987",
#   "Less_than_High_School": "24175",
#   "Male": "178434",
#   "Native_Born": "321573",
#   "Naturalized": "24286",
#   "Not_a_Citizen": "18222",
#   "Over_100000S": "129208",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "61516",
#   "Some_Other_Race": "15392",
#   "State": "Pennsylvania",
#   "Total_Population": "364081",
#   "Under_25000S": "44503",
#   "Under_6_Y": "26073",
#   "White": "294129",
#   "_19_to_25_Y": "31541",
#   "_25000_to_49999S": "70245",
#   "_26_to_34_Y": "43982",
#   "_35_to_44_Y": "46842",
#   "_45_to_54_Y": "45666",
#   "_50000_to_74999S": "61408",
#   "_55_to_64_Y": "48229",
#   "_65_to_74_Y": "34866",
#   "_6_to_18_Y": "61952",
#   "_75000_to_99999S": "52770",
#   "_75_and_Older": "24930"
#  },
#  {
#   "African_American": "28481",
#   "American_Indian": "0",
#   "Asian": "10949",
#   "Bachelors_Degree_or_Higher": "70802",
#   "County": "Lehigh County",
#   "Female": "174822",
#   "Foreign_Born": "34521",
#   "High_School_or_Equivalet": "78444",
#   "Hispanic": "82508",
#   "Less_than_High_School": "21425",
#   "Male": "164952",
#   "Native_Born": "305253",
#   "Naturalized": "21406",
#   "Not_a_Citizen": "13115",
#   "Over_100000S": "125480",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "56933",
#   "Some_Other_Race": "13876",
#   "State": "Pennsylvania",
#   "Total_Population": "339774",
#   "Under_25000S": "39474",
#   "Under_6_Y": "25132",
#   "White": "275495",
#   "_19_to_25_Y": "26692",
#   "_25000_to_49999S": "63796",
#   "_26_to_34_Y": "38186",
#   "_35_to_44_Y": "42764",
#   "_45_to_54_Y": "41349",
#   "_50000_to_74999S": "56431",
#   "_55_to_64_Y": "45555",
#   "_65_to_74_Y": "34820",
#   "_6_to_18_Y": "60346",
#   "_75000_to_99999S": "48760",
#   "_75_and_Older": "24930"
#  },
#  {
#   "African_American": "2550",
#   "American_Indian": "0",
#   "Asian": "1228",
#   "Bachelors_Degree_or_Higher": "2301",
#   "County": "Lehigh County",
#   "Female": "10825",
#   "Foreign_Born": "7987",
#   "High_School_or_Equivalet": "7277",
#   "Hispanic": "13479",
#   "Less_than_High_School": "2750",
#   "Male": "13482",
#   "Native_Born": "16320",
#   "Naturalized": "2880",
#   "Not_a_Citizen": "5107",
#   "Over_100000S": "3728",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "4583",
#   "Some_Other_Race": "1516",
#   "State": "Pennsylvania",
#   "Total_Population": "24307",
#   "Under_25000S": "5029",
#   "Under_6_Y": "941",
#   "White": "18634",
#   "_19_to_25_Y": "4849",
#   "_25000_to_49999S": "6449",
#   "_26_to_34_Y": "5796",
#   "_35_to_44_Y": "4078",
#   "_45_to_54_Y": "4317",
#   "_50000_to_74999S": "4977",
#   "_55_to_64_Y": "2674",
#   "_65_to_74_Y": "46",
#   "_6_to_18_Y": "1606",
#   "_75000_to_99999S": "4010",
#   "_75_and_Older": "0"
#  },
#  {
#   "African_American": "20439",
#   "American_Indian": "0",
#   "Asian": "3034",
#   "Bachelors_Degree_or_Higher": "48118",
#   "County": "Luzerne County",
#   "Female": "158926",
#   "Foreign_Born": "21572",
#   "High_School_or_Equivalet": "85345",
#   "Hispanic": "42882",
#   "Less_than_High_School": "17138",
#   "Male": "150824",
#   "Native_Born": "288178",
#   "Naturalized": "11092",
#   "Not_a_Citizen": "10480",
#   "Over_100000S": "80775",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "65694",
#   "Some_Other_Race": "16494",
#   "State": "Pennsylvania",
#   "Total_Population": "309750",
#   "Under_25000S": "49789",
#   "Under_6_Y": "20323",
#   "White": "262211",
#   "_19_to_25_Y": "26084",
#   "_25000_to_49999S": "67414",
#   "_26_to_34_Y": "34856",
#   "_35_to_44_Y": "36623",
#   "_45_to_54_Y": "39856",
#   "_50000_to_74999S": "61237",
#   "_55_to_64_Y": "44794",
#   "_65_to_74_Y": "34105",
#   "_6_to_18_Y": "47048",
#   "_75000_to_99999S": "46227",
#   "_75_and_Older": "26061"
#  },
#  {
#   "African_American": "18286",
#   "American_Indian": "0",
#   "Asian": "2786",
#   "Bachelors_Degree_or_Higher": "46637",
#   "County": "Luzerne County",
#   "Female": "152553",
#   "Foreign_Born": "17473",
#   "High_School_or_Equivalet": "80148",
#   "Hispanic": "36452",
#   "Less_than_High_School": "15336",
#   "Male": "139033",
#   "Native_Born": "274113",
#   "Naturalized": "9916",
#   "Not_a_Citizen": "7557",
#   "Over_100000S": "78410",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "61235",
#   "Some_Other_Race": "13802",
#   "State": "Pennsylvania",
#   "Total_Population": "291586",
#   "Under_25000S": "46842",
#   "Under_6_Y": "19479",
#   "White": "249977",
#   "_19_to_25_Y": "22916",
#   "_25000_to_49999S": "61941",
#   "_26_to_34_Y": "30559",
#   "_35_to_44_Y": "33303",
#   "_45_to_54_Y": "37458",
#   "_50000_to_74999S": "55668",
#   "_55_to_64_Y": "42267",
#   "_65_to_74_Y": "33902",
#   "_6_to_18_Y": "45835",
#   "_75000_to_99999S": "44492",
#   "_75_and_Older": "25867"
#  },
#  {
#   "African_American": "2153",
#   "American_Indian": "0",
#   "Asian": "248",
#   "Bachelors_Degree_or_Higher": "1481",
#   "County": "Luzerne County",
#   "Female": "6373",
#   "Foreign_Born": "4099",
#   "High_School_or_Equivalet": "5197",
#   "Hispanic": "6430",
#   "Less_than_High_School": "1802",
#   "Male": "11791",
#   "Native_Born": "14065",
#   "Naturalized": "1176",
#   "Not_a_Citizen": "2923",
#   "Over_100000S": "2365",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "4459",
#   "Some_Other_Race": "2692",
#   "State": "Pennsylvania",
#   "Total_Population": "18164",
#   "Under_25000S": "2947",
#   "Under_6_Y": "844",
#   "White": "12234",
#   "_19_to_25_Y": "3168",
#   "_25000_to_49999S": "5473",
#   "_26_to_34_Y": "4297",
#   "_35_to_44_Y": "3320",
#   "_45_to_54_Y": "2398",
#   "_50000_to_74999S": "5569",
#   "_55_to_64_Y": "2527",
#   "_65_to_74_Y": "203",
#   "_6_to_18_Y": "1213",
#   "_75000_to_99999S": "1735",
#   "_75_and_Older": "194"
#  },
#  {
#   "African_American": "5576",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "19127",
#   "County": "Lycoming County",
#   "Female": "54717",
#   "Foreign_Born": "2095",
#   "High_School_or_Equivalet": "30954",
#   "Hispanic": "0",
#   "Less_than_High_School": "7258",
#   "Male": "55208",
#   "Native_Born": "107830",
#   "Naturalized": "750",
#   "Not_a_Citizen": "1345",
#   "Over_100000S": "29935",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "19194",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "109925",
#   "Under_25000S": "17183",
#   "Under_6_Y": "7163",
#   "White": "101377",
#   "_19_to_25_Y": "8663",
#   "_25000_to_49999S": "20650",
#   "_26_to_34_Y": "13009",
#   "_35_to_44_Y": "12641",
#   "_45_to_54_Y": "13335",
#   "_50000_to_74999S": "18970",
#   "_55_to_64_Y": "15846",
#   "_65_to_74_Y": "12723",
#   "_6_to_18_Y": "17566",
#   "_75000_to_99999S": "20476",
#   "_75_and_Older": "8979"
#  },
#  {
#   "African_American": "5073",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "18273",
#   "County": "Lycoming County",
#   "Female": "51586",
#   "Foreign_Born": "1595",
#   "High_School_or_Equivalet": "29552",
#   "Hispanic": "0",
#   "Less_than_High_School": "6535",
#   "Male": "51473",
#   "Native_Born": "101464",
#   "Naturalized": "750",
#   "Not_a_Citizen": "845",
#   "Over_100000S": "29369",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "17174",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "103059",
#   "Under_25000S": "15402",
#   "Under_6_Y": "7017",
#   "White": "95176",
#   "_19_to_25_Y": "7713",
#   "_25000_to_49999S": "17592",
#   "_26_to_34_Y": "11402",
#   "_35_to_44_Y": "10980",
#   "_45_to_54_Y": "12178",
#   "_50000_to_74999S": "18209",
#   "_55_to_64_Y": "15300",
#   "_65_to_74_Y": "12695",
#   "_6_to_18_Y": "16795",
#   "_75000_to_99999S": "20007",
#   "_75_and_Older": "8979"
#  },
#  {
#   "African_American": "503",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "854",
#   "County": "Lycoming County",
#   "Female": "3131",
#   "Foreign_Born": "500",
#   "High_School_or_Equivalet": "1402",
#   "Hispanic": "0",
#   "Less_than_High_School": "723",
#   "Male": "3735",
#   "Native_Born": "6366",
#   "Naturalized": "0",
#   "Not_a_Citizen": "500",
#   "Over_100000S": "566",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "2020",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "6866",
#   "Under_25000S": "1781",
#   "Under_6_Y": "146",
#   "White": "6201",
#   "_19_to_25_Y": "950",
#   "_25000_to_49999S": "3058",
#   "_26_to_34_Y": "1607",
#   "_35_to_44_Y": "1661",
#   "_45_to_54_Y": "1157",
#   "_50000_to_74999S": "761",
#   "_55_to_64_Y": "546",
#   "_65_to_74_Y": "28",
#   "_6_to_18_Y": "771",
#   "_75000_to_99999S": "469",
#   "_75_and_Older": "0"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "17820",
#   "County": "Mercer County",
#   "Female": "54829",
#   "Foreign_Born": "1387",
#   "High_School_or_Equivalet": "30487",
#   "Hispanic": "0",
#   "Less_than_High_School": "7558",
#   "Male": "50314",
#   "Native_Born": "103756",
#   "Naturalized": "1160",
#   "Not_a_Citizen": "227",
#   "Over_100000S": "27443",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "17912",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "105143",
#   "Under_25000S": "14228",
#   "Under_6_Y": "7034",
#   "White": "96276",
#   "_19_to_25_Y": "9816",
#   "_25000_to_49999S": "22240",
#   "_26_to_34_Y": "9524",
#   "_35_to_44_Y": "10528",
#   "_45_to_54_Y": "13584",
#   "_50000_to_74999S": "20684",
#   "_55_to_64_Y": "16356",
#   "_65_to_74_Y": "13438",
#   "_6_to_18_Y": "14516",
#   "_75000_to_99999S": "17402",
#   "_75_and_Older": "10347"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "17399",
#   "County": "Mercer County",
#   "Female": "52088",
#   "Foreign_Born": "1348",
#   "High_School_or_Equivalet": "29419",
#   "Hispanic": "0",
#   "Less_than_High_School": "6283",
#   "Male": "47109",
#   "Native_Born": "97849",
#   "Naturalized": "1136",
#   "Not_a_Citizen": "212",
#   "Over_100000S": "26401",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "17237",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "99197",
#   "Under_25000S": "13439",
#   "Under_6_Y": "6551",
#   "White": "90650",
#   "_19_to_25_Y": "8825",
#   "_25000_to_49999S": "20541",
#   "_26_to_34_Y": "8438",
#   "_35_to_44_Y": "9879",
#   "_45_to_54_Y": "12558",
#   "_50000_to_74999S": "19127",
#   "_55_to_64_Y": "15775",
#   "_65_to_74_Y": "13399",
#   "_6_to_18_Y": "13483",
#   "_75000_to_99999S": "16873",
#   "_75_and_Older": "10289"
#  },
#  {
#   "African_American": "0",
#   "American_Indian": "0",
#   "Asian": "0",
#   "Bachelors_Degree_or_Higher": "421",
#   "County": "Mercer County",
#   "Female": "2741",
#   "Foreign_Born": "39",
#   "High_School_or_Equivalet": "1068",
#   "Hispanic": "0",
#   "Less_than_High_School": "1275",
#   "Male": "3205",
#   "Native_Born": "5907",
#   "Naturalized": "24",
#   "Not_a_Citizen": "15",
#   "Over_100000S": "1042",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "675",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "5946",
#   "Under_25000S": "789",
#   "Under_6_Y": "483",
#   "White": "5626",
#   "_19_to_25_Y": "991",
#   "_25000_to_49999S": "1699",
#   "_26_to_34_Y": "1086",
#   "_35_to_44_Y": "649",
#   "_45_to_54_Y": "1026",
#   "_50000_to_74999S": "1557",
#   "_55_to_64_Y": "581",
#   "_65_to_74_Y": "39",
#   "_6_to_18_Y": "1033",
#   "_75000_to_99999S": "529",
#   "_75_and_Older": "58"
#  },
#  {
#   "African_American": "24412",
#   "American_Indian": "0",
#   "Asian": "4151",
#   "Bachelors_Degree_or_Higher": "29529",
#   "County": "Monroe County",
#   "Female": "85257",
#   "Foreign_Born": "14055",
#   "High_School_or_Equivalet": "39811",
#   "Hispanic": "28392",
#   "Less_than_High_School": "9845",
#   "Male": "83629",
#   "Native_Born": "154831",
#   "Naturalized": "10752",
#   "Not_a_Citizen": "3303",
#   "Over_100000S": "63014",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "35301",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "168886",
#   "Under_25000S": "16832",
#   "Under_6_Y": "10808",
#   "White": "131737",
#   "_19_to_25_Y": "19227",
#   "_25000_to_49999S": "34267",
#   "_26_to_34_Y": "15705",
#   "_35_to_44_Y": "18146",
#   "_45_to_54_Y": "23338",
#   "_50000_to_74999S": "31043",
#   "_55_to_64_Y": "27888",
#   "_65_to_74_Y": "18163",
#   "_6_to_18_Y": "24365",
#   "_75000_to_99999S": "22542",
#   "_75_and_Older": "11246"
#  },
#  {
#   "African_American": "23331",
#   "American_Indian": "0",
#   "Asian": "3611",
#   "Bachelors_Degree_or_Higher": "28191",
#   "County": "Monroe County",
#   "Female": "79081",
#   "Foreign_Born": "12690",
#   "High_School_or_Equivalet": "36416",
#   "Hispanic": "25736",
#   "Less_than_High_School": "8734",
#   "Male": "77258",
#   "Native_Born": "143649",
#   "Naturalized": "9921",
#   "Not_a_Citizen": "2769",
#   "Over_100000S": "59903",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "32683",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "156339",
#   "Under_25000S": "14830",
#   "Under_6_Y": "9724",
#   "White": "121294",
#   "_19_to_25_Y": "16932",
#   "_25000_to_49999S": "31610",
#   "_26_to_34_Y": "13840",
#   "_35_to_44_Y": "14938",
#   "_45_to_54_Y": "20907",
#   "_50000_to_74999S": "27387",
#   "_55_to_64_Y": "26930",
#   "_65_to_74_Y": "18163",
#   "_6_to_18_Y": "23659",
#   "_75000_to_99999S": "21430",
#   "_75_and_Older": "11246"
#  },
#  {
#   "African_American": "1081",
#   "American_Indian": "0",
#   "Asian": "540",
#   "Bachelors_Degree_or_Higher": "1338",
#   "County": "Monroe County",
#   "Female": "6176",
#   "Foreign_Born": "1365",
#   "High_School_or_Equivalet": "3395",
#   "Hispanic": "2656",
#   "Less_than_High_School": "1111",
#   "Male": "6371",
#   "Native_Born": "11182",
#   "Naturalized": "831",
#   "Not_a_Citizen": "534",
#   "Over_100000S": "3111",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "2618",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "12547",
#   "Under_25000S": "2002",
#   "Under_6_Y": "1084",
#   "White": "10443",
#   "_19_to_25_Y": "2295",
#   "_25000_to_49999S": "2657",
#   "_26_to_34_Y": "1865",
#   "_35_to_44_Y": "3208",
#   "_45_to_54_Y": "2431",
#   "_50000_to_74999S": "3656",
#   "_55_to_64_Y": "958",
#   "_65_to_74_Y": "0",
#   "_6_to_18_Y": "706",
#   "_75000_to_99999S": "1112",
#   "_75_and_Older": "0"
#  },
#  {
#   "African_American": "74034",
#   "American_Indian": "0",
#   "Asian": "63844",
#   "Bachelors_Degree_or_Higher": "286909",
#   "County": "Montgomery County",
#   "Female": "422112",
#   "Foreign_Born": "86135",
#   "High_School_or_Equivalet": "124403",
#   "Hispanic": "44351",
#   "Less_than_High_School": "26787",
#   "Male": "394170",
#   "Native_Born": "730147",
#   "Naturalized": "55702",
#   "Not_a_Citizen": "30433",
#   "Over_100000S": "457388",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "126018",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "816282",
#   "Under_25000S": "52591",
#   "Under_6_Y": "54500",
#   "White": "646818",
#   "_19_to_25_Y": "62893",
#   "_25000_to_49999S": "82520",
#   "_26_to_34_Y": "92823",
#   "_35_to_44_Y": "104737",
#   "_45_to_54_Y": "106473",
#   "_50000_to_74999S": "97852",
#   "_55_to_64_Y": "115179",
#   "_65_to_74_Y": "82470",
#   "_6_to_18_Y": "134772",
#   "_75000_to_99999S": "117530",
#   "_75_and_Older": "62435"
#  },
#  {
#   "African_American": "69814",
#   "American_Indian": "0",
#   "Asian": "61216",
#   "Bachelors_Degree_or_Higher": "282169",
#   "County": "Montgomery County",
#   "Female": "408387",
#   "Foreign_Born": "76813",
#   "High_School_or_Equivalet": "116384",
#   "Hispanic": "36356",
#   "Less_than_High_School": "23376",
#   "Male": "377130",
#   "Native_Born": "708704",
#   "Naturalized": "51850",
#   "Not_a_Citizen": "24963",
#   "Over_100000S": "449720",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "120937",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "785517",
#   "Under_25000S": "47680",
#   "Under_6_Y": "53266",
#   "White": "625093",
#   "_19_to_25_Y": "58335",
#   "_25000_to_49999S": "75894",
#   "_26_to_34_Y": "88123",
#   "_35_to_44_Y": "97850",
#   "_45_to_54_Y": "101896",
#   "_50000_to_74999S": "91413",
#   "_55_to_64_Y": "110843",
#   "_65_to_74_Y": "81956",
#   "_6_to_18_Y": "131050",
#   "_75000_to_99999S": "113064",
#   "_75_and_Older": "62198"
#  },
#  {
#   "African_American": "4220",
#   "American_Indian": "0",
#   "Asian": "2628",
#   "Bachelors_Degree_or_Higher": "4740",
#   "County": "Montgomery County",
#   "Female": "13725",
#   "Foreign_Born": "9322",
#   "High_School_or_Equivalet": "8019",
#   "Hispanic": "7995",
#   "Less_than_High_School": "3411",
#   "Male": "17040",
#   "Native_Born": "21443",
#   "Naturalized": "3852",
#   "Not_a_Citizen": "5470",
#   "Over_100000S": "7668",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "5081",
#   "Some_Other_Race": "0",
#   "State": "Pennsylvania",
#   "Total_Population": "30765",
#   "Under_25000S": "4911",
#   "Under_6_Y": "1234",
#   "White": "21725",
#   "_19_to_25_Y": "4558",
#   "_25000_to_49999S": "6626",
#   "_26_to_34_Y": "4700",
#   "_35_to_44_Y": "6887",
#   "_45_to_54_Y": "4577",
#   "_50000_to_74999S": "6439",
#   "_55_to_64_Y": "4336",
#   "_65_to_74_Y": "514",
#   "_6_to_18_Y": "3722",
#   "_75000_to_99999S": "4466",
#   "_75_and_Older": "237"
#  },
#  {
#   "African_American": "18042",
#   "American_Indian": "0",
#   "Asian": "8501",
#   "Bachelors_Degree_or_Higher": "65100",
#   "County": "Northampton County",
#   "Female": "153442",
#   "Foreign_Born": "23884",
#   "High_School_or_Equivalet": "73370",
#   "Hispanic": "42821",
#   "Less_than_High_School": "18155",
#   "Male": "149082",
#   "Native_Born": "278640",
#   "Naturalized": "15243",
#   "Not_a_Citizen": "8641",
#   "Over_100000S": "132416",
#   "Pacific_Islander": "0",
#   "Population_Category": "Total",
#   "Some_College": "53252",
#   "Some_Other_Race": "13244",
#   "State": "Pennsylvania",
#   "Total_Population": "302524",
#   "Under_25000S": "23271",
#   "Under_6_Y": "17469",
#   "White": "251912",
#   "_19_to_25_Y": "26294",
#   "_25000_to_49999S": "44523",
#   "_26_to_34_Y": "34541",
#   "_35_to_44_Y": "34943",
#   "_45_to_54_Y": "39199",
#   "_50000_to_74999S": "50650",
#   "_55_to_64_Y": "43229",
#   "_65_to_74_Y": "32230",
#   "_6_to_18_Y": "48884",
#   "_75000_to_99999S": "43265",
#   "_75_and_Older": "25735"
#  },
#  {
#   "African_American": "16850",
#   "American_Indian": "0",
#   "Asian": "8372",
#   "Bachelors_Degree_or_Higher": "63294",
#   "County": "Northampton County",
#   "Female": "149609",
#   "Foreign_Born": "21906",
#   "High_School_or_Equivalet": "69499",
#   "Hispanic": "39964",
#   "Less_than_High_School": "17154",
#   "Male": "142842",
#   "Native_Born": "270545",
#   "Naturalized": "14500",
#   "Not_a_Citizen": "7406",
#   "Over_100000S": "128522",
#   "Pacific_Islander": "0",
#   "Population_Category": "Insured",
#   "Some_College": "52108",
#   "Some_Other_Race": "12239",
#   "State": "Pennsylvania",
#   "Total_Population": "292451",
#   "Under_25000S": "22232",
#   "Under_6_Y": "17263",
#   "White": "244279",
#   "_19_to_25_Y": "24919",
#   "_25000_to_49999S": "42531",
#   "_26_to_34_Y": "32947",
#   "_35_to_44_Y": "32879",
#   "_45_to_54_Y": "37245",
#   "_50000_to_74999S": "48975",
#   "_55_to_64_Y": "41173",
#   "_65_to_74_Y": "32187",
#   "_6_to_18_Y": "48214",
#   "_75000_to_99999S": "41998",
#   "_75_and_Older": "25624"
#  },
#  {
#   "African_American": "1192",
#   "American_Indian": "0",
#   "Asian": "129",
#   "Bachelors_Degree_or_Higher": "1806",
#   "County": "Northampton County",
#   "Female": "3833",
#   "Foreign_Born": "1978",
#   "High_School_or_Equivalet": "3871",
#   "Hispanic": "2857",
#   "Less_than_High_School": "1001",
#   "Male": "6240",
#   "Native_Born": "8095",
#   "Naturalized": "743",
#   "Not_a_Citizen": "1235",
#   "Over_100000S": "3894",
#   "Pacific_Islander": "0",
#   "Population_Category": "Uninsured",
#   "Some_College": "1144",
#   "Some_Other_Race": "1005",
#   "State": "Pennsylvania",
#   "Total_Population": "10073",
#   "Under_25000S": "1039",
#   "Under_6_Y": "206",
#   "White": "7633",
#   "_19_to_25_Y": "1375",
#   "_25000_to_49999S": "1992",
#   "_26_to_34_Y": "1594",
#   "_35_to_44_Y": "2064",
#   "_45_to_54_Y": "1954",
#   "_50000_to_74999S": "1675",
#   "_55_to_64_Y": "2056",
#   "_65_to_74_Y": "43",
#   "_6_to_18_Y": "670",
#   "_75000_to_99999S": "1267",
#   "_75_and_Older": "111"
#  }
# ]

# %%
health = spark.createDataFrame(healthListDict).select('State', 'County', 'Population_Category', 'Total_Population', 'Under_6_Y', '_6_to_18_Y', '_19_to_25_Y', '_26_to_34_Y', '_35_to_44_Y', '_45_to_54_Y', '_55_to_64_Y', '_65_to_74_Y', '_75_and_Older', 'Male', 'Female', 'White', 'African_American', 'American_Indian', 'Asian', 'Pacific_Islander', 'Some_Other_Race', 'Hispanic', 'Native_Born', 'Foreign_Born', 'Naturalized', 'Not_a_Citizen', 'Less_than_High_School', 'High_School_or_Equivalet', 'Some_College', 'Bachelors_Degree_or_Higher', 'Under_25000S', '_25000_to_49999S', '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S').toPandas()

# %% [markdown]
# *Replacing State and County name with State and County ID from tables*

# %%
for i in State.StateName:
    health['State'].replace(i, int(State.loc[State['StateName'] == i, 'StateID']), inplace = True)

for i in County.CountyName:
    health['County'].replace(i, int(County.loc[County['CountyName'] == i, 'CountyID']), inplace = True)

# Renaming the columns
health.columns = ['StateID', 'CountyID', 'Insurance_Category', 'Total_Population',
       'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y',
       '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male',
       'Female', 'White', 'African_American', 'American_Indian', 'Asian',
       'Pacific_Islander', 'Some_Other_Race', 'Hispanic', 'Native_Born',
       'Foreign_Born', 'Naturalized', 'Not_a_Citizen', 'Less_than_High_School',
       'High_School_or_Equivalent', 'Some_College',
       'Bachelors_or_Higher', 'Under_25000S', '_25000_to_49999S',
       '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']

# List of columns to be changed to integers
columns = ['Total_Population',
       'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y',
       '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male',
       'Female', 'White', 'African_American', 'American_Indian', 'Asian',
       'Pacific_Islander', 'Some_Other_Race', 'Hispanic', 'Native_Born',
       'Foreign_Born', 'Naturalized', 'Not_a_Citizen', 'Less_than_High_School',
       'High_School_or_Equivalent', 'Some_College',
       'Bachelors_or_Higher', 'Under_25000S', '_25000_to_49999S',
       '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']

for i in columns:
    health[i] = health[i].astype('float')

healthID = []
for i in range(1, health.shape[0]+1):
    healthID.append(i)

health2 = health.sort_values(by = ['StateID', 'CountyID']).copy()

health2['HealthID'] = healthID
health2 = health2[['HealthID', 'StateID', 'CountyID', 'Insurance_Category', 'Total_Population',
       'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y',
       '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male',
       'Female', 'White', 'African_American', 'American_Indian', 'Asian',
       'Pacific_Islander', 'Some_Other_Race', 'Hispanic', 'Native_Born',
       'Foreign_Born', 'Naturalized', 'Not_a_Citizen', 'Less_than_High_School',
       'High_School_or_Equivalent', 'Some_College',
       'Bachelors_or_Higher', 'Under_25000S', '_25000_to_49999S',
       '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']]

health = spark.createDataFrame(health)
health2 = spark.createDataFrame(health2)

# %%
States = spark.createDataFrame(State)
Counties = spark.createDataFrame(County)

# %% [markdown]
# **SQL Connection**

# %%
table = 'dbo.County'

CountyCheck = spark.read.format("jdbc") \
    .option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .option("dbtable", table) \
    .option("user", k_username) \
    .option("password", k_password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .load()

if CountyCheck.count() != 1_999: # Total number of rows in dataset
    Counties.select('CountyName').sort('CountyName').write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
        .mode("append") \
        .option("dbtable", table) \
        .option("user", k_username) \
        .option("password", k_password) \
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
        .save()

# %%
table = "dbo.State"

StateCheck = spark.read.format("jdbc") \
    .option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .option("dbtable", table) \
    .option("user", k_username) \
    .option("password", k_password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .load()

if StateCheck.count() != 56: # Total number of rows in dataset
    States.select('StateName').sort('StateName').write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
        .mode("append") \
        .option("dbtable", table) \
        .option("user", k_username) \
        .option("password", k_password) \
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
        .save()

# %%
table = "dbo.HealthInsurance"

healthNew = spark.read.format("jdbc") \
    .option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .option("dbtable", table) \
    .option("user", k_username) \
    .option("password", k_password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .load()

# Adding the first 
if healthNew.count() != 2520: # Total number of rows in original dataset
    health.sort('StateID', 'CountyID').write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
        .mode("append") \
        .option("dbtable", table) \
        .option("user", k_username) \
        .option("password", k_password) \
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
        .save()

else:
    health2.sort('StateID', 'CountyID').write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
        .mode("overwrite") \
        .option("dbtable", table) \
        .option("user", k_username) \
        .option("password", k_password) \
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
        .save()
