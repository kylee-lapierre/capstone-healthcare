# %%
import pyspark.sql.functions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.sql.functions import *
from pyspark.sql.types import StringType,DecimalType
from pyspark.sql.functions import input_file_name, substring
from pyspark.sql.functions import isnan, when, count, col

# Kafka producer and consumer imports
from confluent_kafka import Producer, Consumer, KafkaError, KafkaException, TopicPartition
from time import sleep
import uuid
import json
from confluent_kafka.admin import AdminClient, NewTopic

# %%
###### Mount Point 1 through Oauth security.
storageAccount = "gen10datafund2207"
storageContainer = "healthcare-capstone-group3"
clientSecret = "Cty8Q~AvEO_qC-MjvPvosYauiNsffOHKnMpj7cmd"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/healthcare/dataIn" # the mount point will be unique to you

configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

dbutils.fs.mount(
source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
mount_point = mount_point,
extra_configs = configs)
# Out:
# /mnt/healthcare/dataIn has been unmounted.
# Out[2]: True

# %%
State = spark.read.options(header = 'True').csv("/mnt/healthcare/dataIn/CleanedData/State.csv").sort('StateName').toPandas()
County = spark.read.options(header = 'True').csv("/mnt/healthcare/dataIn/CleanedData/County.csv").sort('CountyName').toPandas()

# %% [markdown]
# **Kafka Consumer**

# %%
# Error function

def error_cb(err):
    """ The error callback is used for generic client errors. These
        errors are generally to be considered informational as the client will
        automatically try to recover from all errors, and no extra action
        is typically required by the application.
        For this example however, we terminate the application if the client
        is unable to connect to any broker (_ALL_BROKERS_DOWN) and on
        authentication errors (_AUTHENTICATION). """

    print("Client error: {}".format(err))
    if err.code() == KafkaError._ALL_BROKERS_DOWN or \
       err.code() == KafkaError._AUTHENTICATION:
        # Any exception raised from this callback will be re-raised from the
        # triggering flush() or poll() call.
        raise KafkaException(err)

# %%
#KAFKA variables, Move to the OS variables or configuration
# This will work in local Jupyter Notebook, but in a databrick, hiding config.py is tougher. 
confluentClusterName = "stage3talent"
confluentBootstrapServers = "pkc-ldvmy.centralus.azure.confluent.cloud:9092"

# Topic name
confluentTopicName = "healthcare-insurance"

schemaRegistryUrl = "https://psrc-gq7pv.westus2.azure.confluent.cloud"
confluentApiKey = "YHMHG7E54LJA55XZ"
confluentSecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"
confluentRegistryApiKey = "YHMHG7E54LJA55XZ"
confluentRegistrySecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"

#Kakfa Class Setup.
c = Consumer({
    'bootstrap.servers': confluentBootstrapServers,
    'sasl.mechanism': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': confluentApiKey,
    'sasl.password': confluentSecret,
    'group.id': str(uuid.uuid1()),  # this will create a new consumer group on each invocation.
    'auto.offset.reset': 'earliest',
    'error_cb': error_cb,
})

c.subscribe([confluentTopicName])

# %% [markdown]
# **Health Insurance Characteristics Consumer**

# %%
healthstring = {}
healthListDict = []

for i in range(2_520):
    try:
        message = c.poll(timeout=1.0)
        if message is None:
            break
        elif message.error():
            print("Consumer error: {}".format(message.error()))
            break
        else:
            healthstring = json.loads('{}'.format(message.value().decode('utf-8')))
            healthListDict.append(healthstring)

    except Exception as e:
        print(e)

print(json.dumps(healthListDict, indent=1, sort_keys=True))
# Out:
# [
#  {
#   "African_American": "17668",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "51187",
#   "County": "Baldwin County",
#   "Female": "113950",
#   "Foreign_Born": "11002",
#   "High_School_or_Equivalet": "39988",
#   "Hispanic": "10517",
#   "Less_than_High_School": "14600",
#   "Male": "106961",
#   "Native_Born": "209909",
#   "Naturalized": "4495",
#   "Not_a_Citizen": "6507",
#   "Over_100000S": "76781",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "49486",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "220911",
#   "Under_25000S": "28456",
#   "Under_6_Y": "13169",
#   "White": "189325",
#   "_19_to_25_Y": "16549",
#   "_25000_to_49999S": "52417",
#   "_26_to_34_Y": "21835",
#   "_35_to_44_Y": "27872",
#   "_45_to_54_Y": "27174",
#   "_50000_to_74999S": "26888",
#   "_55_to_64_Y": "31542",
#   "_65_to_74_Y": "28682",
#   "_6_to_18_Y": "35932",
#   "_75000_to_99999S": "35705",
#   "_75_and_Older": "18156"
#  },
#  {
#   "African_American": "16020",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "49273",
#   "County": "Baldwin County",
#   "Female": "105903",
#   "Foreign_Born": "7720",
#   "High_School_or_Equivalet": "34826",
#   "Hispanic": "7601",
#   "Less_than_High_School": "11492",
#   "Male": "97080",
#   "Native_Born": "195263",
#   "Naturalized": "4070",
#   "Not_a_Citizen": "3650",
#   "Over_100000S": "73976",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "45898",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "202983",
#   "Under_25000S": "24708",
#   "Under_6_Y": "12868",
#   "White": "175379",
#   "_19_to_25_Y": "13734",
#   "_25000_to_49999S": "46458",
#   "_26_to_34_Y": "17251",
#   "_35_to_44_Y": "24272",
#   "_45_to_54_Y": "24410",
#   "_50000_to_74999S": "24647",
#   "_55_to_64_Y": "29073",
#   "_65_to_74_Y": "28327",
#   "_6_to_18_Y": "34892",
#   "_75000_to_99999S": "32639",
#   "_75_and_Older": "18156"
#  },
#  {
#   "African_American": "1648",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "1914",
#   "County": "Baldwin County",
#   "Female": "8047",
#   "Foreign_Born": "3282",
#   "High_School_or_Equivalet": "5162",
#   "Hispanic": "2916",
#   "Less_than_High_School": "3108",
#   "Male": "9881",
#   "Native_Born": "14646",
#   "Naturalized": "425",
#   "Not_a_Citizen": "2857",
#   "Over_100000S": "2805",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "3588",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "17928",
#   "Under_25000S": "3748",
#   "Under_6_Y": "301",
#   "White": "13946",
#   "_19_to_25_Y": "2815",
#   "_25000_to_49999S": "5959",
#   "_26_to_34_Y": "4584",
#   "_35_to_44_Y": "3600",
#   "_45_to_54_Y": "2764",
#   "_50000_to_74999S": "2241",
#   "_55_to_64_Y": "2469",
#   "_65_to_74_Y": "355",
#   "_6_to_18_Y": "1040",
#   "_75000_to_99999S": "3066",
#   "_75_and_Older": "17869"
#  },
#  {
#   "African_American": "24662",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "14547",
#   "County": "Calhoun County",
#   "Female": "58633",
#   "Foreign_Born": "1720",
#   "High_School_or_Equivalet": "26149",
#   "Hispanic": "4542",
#   "Less_than_High_School": "12026",
#   "Male": "52442",
#   "Native_Born": "109355",
#   "Naturalized": "461",
#   "Not_a_Citizen": "1259",
#   "Over_100000S": "25919",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "22612",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "111075",
#   "Under_25000S": "21181",
#   "Under_6_Y": "8110",
#   "White": "80403",
#   "_19_to_25_Y": "10554",
#   "_25000_to_49999S": "25575",
#   "_26_to_34_Y": "12820",
#   "_35_to_44_Y": "13495",
#   "_45_to_54_Y": "13075",
#   "_50000_to_74999S": "21638",
#   "_55_to_64_Y": "15799",
#   "_65_to_74_Y": "12017",
#   "_6_to_18_Y": "17077",
#   "_75000_to_99999S": "14995",
#   "_75_and_Older": "8128"
#  },
#  {
#   "African_American": "21741",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "14200",
#   "County": "Calhoun County",
#   "Female": "53597",
#   "Foreign_Born": "704",
#   "High_School_or_Equivalet": "21375",
#   "Hispanic": "3437",
#   "Less_than_High_School": "9125",
#   "Male": "45199",
#   "Native_Born": "98092",
#   "Naturalized": "461",
#   "Not_a_Citizen": "243",
#   "Over_100000S": "25449",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "20069",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "98796",
#   "Under_25000S": "16724",
#   "Under_6_Y": "7769",
#   "White": "72983",
#   "_19_to_25_Y": "9747",
#   "_25000_to_49999S": "22678",
#   "_26_to_34_Y": "9718",
#   "_35_to_44_Y": "9901",
#   "_45_to_54_Y": "11178",
#   "_50000_to_74999S": "18484",
#   "_55_to_64_Y": "13918",
#   "_65_to_74_Y": "11926",
#   "_6_to_18_Y": "16511",
#   "_75000_to_99999S": "13940",
#   "_75_and_Older": "8128"
#  },
#  {
#   "African_American": "2921",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "347",
#   "County": "Calhoun County",
#   "Female": "5036",
#   "Foreign_Born": "1016",
#   "High_School_or_Equivalet": "4774",
#   "Hispanic": "1105",
#   "Less_than_High_School": "2901",
#   "Male": "7243",
#   "Native_Born": "11263",
#   "Naturalized": "18989",
#   "Not_a_Citizen": "1016",
#   "Over_100000S": "470",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "2543",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "12279",
#   "Under_25000S": "4457",
#   "Under_6_Y": "341",
#   "White": "7420",
#   "_19_to_25_Y": "807",
#   "_25000_to_49999S": "2897",
#   "_26_to_34_Y": "3102",
#   "_35_to_44_Y": "3594",
#   "_45_to_54_Y": "1897",
#   "_50000_to_74999S": "3154",
#   "_55_to_64_Y": "1881",
#   "_65_to_74_Y": "91",
#   "_6_to_18_Y": "566",
#   "_75000_to_99999S": "1055",
#   "_75_and_Older": "17869"
#  },
#  {
#   "African_American": "43774",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "9080",
#   "County": "Cullman County",
#   "Female": "42887",
#   "Foreign_Born": "2196",
#   "High_School_or_Equivalet": "17418",
#   "Hispanic": "56833",
#   "Less_than_High_School": "10472",
#   "Male": "39954",
#   "Native_Born": "80645",
#   "Naturalized": "800",
#   "Not_a_Citizen": "1396",
#   "Over_100000S": "15107",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "20132",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "82841",
#   "Under_25000S": "9454",
#   "Under_6_Y": "6165",
#   "White": "78892",
#   "_19_to_25_Y": "6152",
#   "_25000_to_49999S": "18678",
#   "_26_to_34_Y": "9554",
#   "_35_to_44_Y": "10186",
#   "_45_to_54_Y": "11307",
#   "_50000_to_74999S": "23542",
#   "_55_to_64_Y": "11009",
#   "_65_to_74_Y": "8973",
#   "_6_to_18_Y": "13422",
#   "_75000_to_99999S": "15686",
#   "_75_and_Older": "6073"
#  },
#  {
#   "African_American": "43774",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "8558",
#   "County": "Cullman County",
#   "Female": "38807",
#   "Foreign_Born": "1678",
#   "High_School_or_Equivalet": "14395",
#   "Hispanic": "56833",
#   "Less_than_High_School": "9104",
#   "Male": "35290",
#   "Native_Born": "72419",
#   "Naturalized": "788",
#   "Not_a_Citizen": "890",
#   "Over_100000S": "14209",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "17309",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "74097",
#   "Under_25000S": "7764",
#   "Under_6_Y": "6165",
#   "White": "70423",
#   "_19_to_25_Y": "5486",
#   "_25000_to_49999S": "16656",
#   "_26_to_34_Y": "6859",
#   "_35_to_44_Y": "8350",
#   "_45_to_54_Y": "9588",
#   "_50000_to_74999S": "21335",
#   "_55_to_64_Y": "9676",
#   "_65_to_74_Y": "8820",
#   "_6_to_18_Y": "13080",
#   "_75000_to_99999S": "13766",
#   "_75_and_Older": "6073"
#  },
#  {
#   "African_American": "43774",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "522",
#   "County": "Cullman County",
#   "Female": "4080",
#   "Foreign_Born": "518",
#   "High_School_or_Equivalet": "3023",
#   "Hispanic": "56833",
#   "Less_than_High_School": "1368",
#   "Male": "4664",
#   "Native_Born": "8226",
#   "Naturalized": "12",
#   "Not_a_Citizen": "506",
#   "Over_100000S": "898",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "2823",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "8744",
#   "Under_25000S": "1690",
#   "Under_6_Y": "16327",
#   "White": "8469",
#   "_19_to_25_Y": "666",
#   "_25000_to_49999S": "2022",
#   "_26_to_34_Y": "2695",
#   "_35_to_44_Y": "1836",
#   "_45_to_54_Y": "1719",
#   "_50000_to_74999S": "2207",
#   "_55_to_64_Y": "1333",
#   "_65_to_74_Y": "153",
#   "_6_to_18_Y": "342",
#   "_75000_to_99999S": "1920",
#   "_75_and_Older": "17869"
#  },
#  {
#   "African_American": "43774",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "5930",
#   "County": "DeKalb County",
#   "Female": "35528",
#   "Foreign_Born": "5018",
#   "High_School_or_Equivalet": "17183",
#   "Hispanic": "56833",
#   "Less_than_High_School": "9531",
#   "Male": "34864",
#   "Native_Born": "65374",
#   "Naturalized": "234",
#   "Not_a_Citizen": "4784",
#   "Over_100000S": "13385",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "12915",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "70392",
#   "Under_25000S": "16269",
#   "Under_6_Y": "5335",
#   "White": "58715",
#   "_19_to_25_Y": "6066",
#   "_25000_to_49999S": "15522",
#   "_26_to_34_Y": "7627",
#   "_35_to_44_Y": "8927",
#   "_45_to_54_Y": "8665",
#   "_50000_to_74999S": "16053",
#   "_55_to_64_Y": "8829",
#   "_65_to_74_Y": "6970",
#   "_6_to_18_Y": "13432",
#   "_75000_to_99999S": "8925",
#   "_75_and_Older": "4541"
#  },
#  {
#   "African_American": "43774",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "5748",
#   "County": "DeKalb County",
#   "Female": "31163",
#   "Foreign_Born": "2354",
#   "High_School_or_Equivalet": "14917",
#   "Hispanic": "56833",
#   "Less_than_High_School": "6199",
#   "Male": "29306",
#   "Native_Born": "58115",
#   "Naturalized": "234",
#   "Not_a_Citizen": "2120",
#   "Over_100000S": "12138",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "10877",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "60469",
#   "Under_25000S": "12327",
#   "Under_6_Y": "5041",
#   "White": "51641",
#   "_19_to_25_Y": "4436",
#   "_25000_to_49999S": "13731",
#   "_26_to_34_Y": "5233",
#   "_35_to_44_Y": "6855",
#   "_45_to_54_Y": "7003",
#   "_50000_to_74999S": "14644",
#   "_55_to_64_Y": "7470",
#   "_65_to_74_Y": "6639",
#   "_6_to_18_Y": "13251",
#   "_75000_to_99999S": "7391",
#   "_75_and_Older": "4541"
#  },
#  {
#   "African_American": "43774",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "182",
#   "County": "DeKalb County",
#   "Female": "4365",
#   "Foreign_Born": "2664",
#   "High_School_or_Equivalet": "2266",
#   "Hispanic": "56833",
#   "Less_than_High_School": "3332",
#   "Male": "5558",
#   "Native_Born": "7259",
#   "Naturalized": "18989",
#   "Not_a_Citizen": "2664",
#   "Over_100000S": "1247",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "2038",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "9923",
#   "Under_25000S": "3942",
#   "Under_6_Y": "294",
#   "White": "7074",
#   "_19_to_25_Y": "1630",
#   "_25000_to_49999S": "1791",
#   "_26_to_34_Y": "2394",
#   "_35_to_44_Y": "2072",
#   "_45_to_54_Y": "1662",
#   "_50000_to_74999S": "1409",
#   "_55_to_64_Y": "1359",
#   "_65_to_74_Y": "331",
#   "_6_to_18_Y": "181",
#   "_75000_to_99999S": "1534",
#   "_75_and_Older": "17869"
#  },
#  {
#   "African_American": "15049",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "13300",
#   "County": "Elmore County",
#   "Female": "39415",
#   "Foreign_Born": "2020",
#   "High_School_or_Equivalet": "17794",
#   "Hispanic": "56833",
#   "Less_than_High_School": "4322",
#   "Male": "35994",
#   "Native_Born": "73389",
#   "Naturalized": "446",
#   "Not_a_Citizen": "1574",
#   "Over_100000S": "26645",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "15911",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "75409",
#   "Under_25000S": "8697",
#   "Under_6_Y": "6129",
#   "White": "58869",
#   "_19_to_25_Y": "5114",
#   "_25000_to_49999S": "15217",
#   "_26_to_34_Y": "10503",
#   "_35_to_44_Y": "8404",
#   "_45_to_54_Y": "9590",
#   "_50000_to_74999S": "15246",
#   "_55_to_64_Y": "10468",
#   "_65_to_74_Y": "7587",
#   "_6_to_18_Y": "12839",
#   "_75000_to_99999S": "9604",
#   "_75_and_Older": "4775"
#  },
#  {
#   "African_American": "14105",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "13243",
#   "County": "Elmore County",
#   "Female": "37450",
#   "Foreign_Born": "1444",
#   "High_School_or_Equivalet": "16422",
#   "Hispanic": "56833",
#   "Less_than_High_School": "3445",
#   "Male": "33460",
#   "Native_Born": "69466",
#   "Naturalized": "446",
#   "Not_a_Citizen": "998",
#   "Over_100000S": "26174",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "15211",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "70910",
#   "Under_25000S": "7919",
#   "Under_6_Y": "5836",
#   "White": "55405",
#   "_19_to_25_Y": "4559",
#   "_25000_to_49999S": "13493",
#   "_26_to_34_Y": "9737",
#   "_35_to_44_Y": "7567",
#   "_45_to_54_Y": "8767",
#   "_50000_to_74999S": "14469",
#   "_55_to_64_Y": "9888",
#   "_65_to_74_Y": "7587",
#   "_6_to_18_Y": "12194",
#   "_75000_to_99999S": "8855",
#   "_75_and_Older": "4775"
#  },
#  {
#   "African_American": "944",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "57",
#   "County": "Elmore County",
#   "Female": "1965",
#   "Foreign_Born": "576",
#   "High_School_or_Equivalet": "1372",
#   "Hispanic": "56833",
#   "Less_than_High_School": "877",
#   "Male": "2534",
#   "Native_Born": "3923",
#   "Naturalized": "18989",
#   "Not_a_Citizen": "576",
#   "Over_100000S": "471",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "700",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "4499",
#   "Under_25000S": "778",
#   "Under_6_Y": "293",
#   "White": "3464",
#   "_19_to_25_Y": "555",
#   "_25000_to_49999S": "1724",
#   "_26_to_34_Y": "766",
#   "_35_to_44_Y": "837",
#   "_45_to_54_Y": "823",
#   "_50000_to_74999S": "777",
#   "_55_to_64_Y": "580",
#   "_65_to_74_Y": "22998",
#   "_6_to_18_Y": "645",
#   "_75000_to_99999S": "749",
#   "_75_and_Older": "17869"
#  },
#  {
#   "African_American": "15798",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "12169",
#   "County": "Etowah County",
#   "Female": "52699",
#   "Foreign_Born": "2999",
#   "High_School_or_Equivalet": "22336",
#   "Hispanic": "4230",
#   "Less_than_High_School": "10996",
#   "Male": "48771",
#   "Native_Born": "98471",
#   "Naturalized": "2081",
#   "Not_a_Citizen": "918",
#   "Over_100000S": "20872",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "24245",
#   "Some_Other_Race": "3207",
#   "State": "Alabama",
#   "Total_Population": "101470",
#   "Under_25000S": "24089",
#   "Under_6_Y": "6850",
#   "White": "79432",
#   "_19_to_25_Y": "8914",
#   "_25000_to_49999S": "24693",
#   "_26_to_34_Y": "10993",
#   "_35_to_44_Y": "11934",
#   "_45_to_54_Y": "13583",
#   "_50000_to_74999S": "20113",
#   "_55_to_64_Y": "13661",
#   "_65_to_74_Y": "11278",
#   "_6_to_18_Y": "15960",
#   "_75000_to_99999S": "11232",
#   "_75_and_Older": "8297"
#  },
#  {
#   "African_American": "12837",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "11162",
#   "County": "Etowah County",
#   "Female": "46515",
#   "Foreign_Born": "2335",
#   "High_School_or_Equivalet": "19289",
#   "Hispanic": "2917",
#   "Less_than_High_School": "8630",
#   "Male": "41570",
#   "Native_Born": "85750",
#   "Naturalized": "1823",
#   "Not_a_Citizen": "512",
#   "Over_100000S": "20451",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "21355",
#   "Some_Other_Race": "1864",
#   "State": "Alabama",
#   "Total_Population": "88085",
#   "Under_25000S": "17743",
#   "Under_6_Y": "6052",
#   "White": "71052",
#   "_19_to_25_Y": "7034",
#   "_25000_to_49999S": "21305",
#   "_26_to_34_Y": "8090",
#   "_35_to_44_Y": "9879",
#   "_45_to_54_Y": "11903",
#   "_50000_to_74999S": "18278",
#   "_55_to_64_Y": "11273",
#   "_65_to_74_Y": "10994",
#   "_6_to_18_Y": "14563",
#   "_75000_to_99999S": "9967",
#   "_75_and_Older": "8297"
#  },
#  {
#   "African_American": "2961",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "1007",
#   "County": "Etowah County",
#   "Female": "6184",
#   "Foreign_Born": "664",
#   "High_School_or_Equivalet": "3047",
#   "Hispanic": "1313",
#   "Less_than_High_School": "2366",
#   "Male": "7201",
#   "Native_Born": "12721",
#   "Naturalized": "258",
#   "Not_a_Citizen": "406",
#   "Over_100000S": "421",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "2890",
#   "Some_Other_Race": "1343",
#   "State": "Alabama",
#   "Total_Population": "13385",
#   "Under_25000S": "6346",
#   "Under_6_Y": "798",
#   "White": "8380",
#   "_19_to_25_Y": "1880",
#   "_25000_to_49999S": "3388",
#   "_26_to_34_Y": "2903",
#   "_35_to_44_Y": "2055",
#   "_45_to_54_Y": "1680",
#   "_50000_to_74999S": "1835",
#   "_55_to_64_Y": "2388",
#   "_65_to_74_Y": "284",
#   "_6_to_18_Y": "1397",
#   "_75000_to_99999S": "1265",
#   "_75_and_Older": "17869"
#  },
#  {
#   "African_American": "29225",
#   "American_Indian": "7337",
#   "Asian": "946",
#   "Bachelors_Degree_or_Higher": "16164",
#   "County": "Houston County",
#   "Female": "54818",
#   "Foreign_Born": "3587",
#   "High_School_or_Equivalet": "21625",
#   "Hispanic": "3595",
#   "Less_than_High_School": "10364",
#   "Male": "49786",
#   "Native_Born": "101017",
#   "Naturalized": "1945",
#   "Not_a_Citizen": "1642",
#   "Over_100000S": "26776",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "22226",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "104604",
#   "Under_25000S": "21698",
#   "Under_6_Y": "7846",
#   "White": "70844",
#   "_19_to_25_Y": "8471",
#   "_25000_to_49999S": "23680",
#   "_26_to_34_Y": "11548",
#   "_35_to_44_Y": "13018",
#   "_45_to_54_Y": "12931",
#   "_50000_to_74999S": "21341",
#   "_55_to_64_Y": "14260",
#   "_65_to_74_Y": "11017",
#   "_6_to_18_Y": "17908",
#   "_75000_to_99999S": "10882",
#   "_75_and_Older": "7605"
#  },
#  {
#   "African_American": "24754",
#   "American_Indian": "7337",
#   "Asian": "748",
#   "Bachelors_Degree_or_Higher": "15511",
#   "County": "Houston County",
#   "Female": "48986",
#   "Foreign_Born": "1988",
#   "High_School_or_Equivalet": "17413",
#   "Hispanic": "2271",
#   "Less_than_High_School": "8316",
#   "Male": "42174",
#   "Native_Born": "89172",
#   "Naturalized": "1596",
#   "Not_a_Citizen": "392",
#   "Over_100000S": "25360",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "18981",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "91160",
#   "Under_25000S": "17518",
#   "Under_6_Y": "7716",
#   "White": "62460",
#   "_19_to_25_Y": "5933",
#   "_25000_to_49999S": "19471",
#   "_26_to_34_Y": "8246",
#   "_35_to_44_Y": "9888",
#   "_45_to_54_Y": "10658",
#   "_50000_to_74999S": "18533",
#   "_55_to_64_Y": "12897",
#   "_65_to_74_Y": "10992",
#   "_6_to_18_Y": "17290",
#   "_75000_to_99999S": "10106",
#   "_75_and_Older": "7540"
#  },
#  {
#   "African_American": "4471",
#   "American_Indian": "7337",
#   "Asian": "198",
#   "Bachelors_Degree_or_Higher": "653",
#   "County": "Houston County",
#   "Female": "5832",
#   "Foreign_Born": "1599",
#   "High_School_or_Equivalet": "4212",
#   "Hispanic": "1324",
#   "Less_than_High_School": "2048",
#   "Male": "7612",
#   "Native_Born": "11845",
#   "Naturalized": "349",
#   "Not_a_Citizen": "1250",
#   "Over_100000S": "1416",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "3245",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "13444",
#   "Under_25000S": "4180",
#   "Under_6_Y": "130",
#   "White": "8384",
#   "_19_to_25_Y": "2538",
#   "_25000_to_49999S": "4209",
#   "_26_to_34_Y": "3302",
#   "_35_to_44_Y": "3130",
#   "_45_to_54_Y": "2273",
#   "_50000_to_74999S": "2808",
#   "_55_to_64_Y": "1363",
#   "_65_to_74_Y": "25",
#   "_6_to_18_Y": "618",
#   "_75000_to_99999S": "776",
#   "_75_and_Older": "65"
#  },
#  {
#   "African_American": "282433",
#   "American_Indian": "7337",
#   "Asian": "11419",
#   "Bachelors_Degree_or_Higher": "152470",
#   "County": "Jefferson County",
#   "Female": "344872",
#   "Foreign_Born": "24933",
#   "High_School_or_Equivalet": "116523",
#   "Hispanic": "26820",
#   "Less_than_High_School": "38113",
#   "Male": "308093",
#   "Native_Born": "628032",
#   "Naturalized": "10272",
#   "Not_a_Citizen": "14661",
#   "Over_100000S": "209093",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "130584",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "652965",
#   "Under_25000S": "113215",
#   "Under_6_Y": "51016",
#   "White": "338890",
#   "_19_to_25_Y": "57242",
#   "_25000_to_49999S": "139325",
#   "_26_to_34_Y": "86125",
#   "_35_to_44_Y": "83453",
#   "_45_to_54_Y": "77839",
#   "_50000_to_74999S": "109246",
#   "_55_to_64_Y": "84633",
#   "_65_to_74_Y": "64247",
#   "_6_to_18_Y": "107017",
#   "_75000_to_99999S": "72085",
#   "_75_and_Older": "41393"
#  },
#  {
#   "African_American": "251560",
#   "American_Indian": "7337",
#   "Asian": "10229",
#   "Bachelors_Degree_or_Higher": "145724",
#   "County": "Jefferson County",
#   "Female": "317197",
#   "Foreign_Born": "18061",
#   "High_School_or_Equivalet": "98060",
#   "Hispanic": "20697",
#   "Less_than_High_School": "28759",
#   "Male": "274118",
#   "Native_Born": "573254",
#   "Naturalized": "9293",
#   "Not_a_Citizen": "8768",
#   "Over_100000S": "201348",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "117333",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "591315",
#   "Under_25000S": "97811",
#   "Under_6_Y": "49285",
#   "White": "313445",
#   "_19_to_25_Y": "48362",
#   "_25000_to_49999S": "117990",
#   "_26_to_34_Y": "71846",
#   "_35_to_44_Y": "71032",
#   "_45_to_54_Y": "67561",
#   "_50000_to_74999S": "98570",
#   "_55_to_64_Y": "74179",
#   "_65_to_74_Y": "64122",
#   "_6_to_18_Y": "103792",
#   "_75000_to_99999S": "67194",
#   "_75_and_Older": "41136"
#  },
#  {
#   "African_American": "30873",
#   "American_Indian": "7337",
#   "Asian": "1190",
#   "Bachelors_Degree_or_Higher": "6746",
#   "County": "Jefferson County",
#   "Female": "27675",
#   "Foreign_Born": "6872",
#   "High_School_or_Equivalet": "18463",
#   "Hispanic": "6123",
#   "Less_than_High_School": "9354",
#   "Male": "33975",
#   "Native_Born": "54778",
#   "Naturalized": "979",
#   "Not_a_Citizen": "5893",
#   "Over_100000S": "7745",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "13251",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "61650",
#   "Under_25000S": "15404",
#   "Under_6_Y": "1731",
#   "White": "25445",
#   "_19_to_25_Y": "8880",
#   "_25000_to_49999S": "21335",
#   "_26_to_34_Y": "14279",
#   "_35_to_44_Y": "12421",
#   "_45_to_54_Y": "10278",
#   "_50000_to_74999S": "10676",
#   "_55_to_64_Y": "10454",
#   "_65_to_74_Y": "125",
#   "_6_to_18_Y": "3225",
#   "_75000_to_99999S": "4891",
#   "_75_and_Older": "257"
#  },
#  {
#   "African_American": "10476",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "13609",
#   "County": "Lauderdale County",
#   "Female": "47330",
#   "Foreign_Born": "995",
#   "High_School_or_Equivalet": "21702",
#   "Hispanic": "56833",
#   "Less_than_High_School": "9025",
#   "Male": "44515",
#   "Native_Born": "90850",
#   "Naturalized": "381",
#   "Not_a_Citizen": "614",
#   "Over_100000S": "20409",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "18142",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "91845",
#   "Under_25000S": "16789",
#   "Under_6_Y": "4302",
#   "White": "78351",
#   "_19_to_25_Y": "9367",
#   "_25000_to_49999S": "22619",
#   "_26_to_34_Y": "9617",
#   "_35_to_44_Y": "10533",
#   "_45_to_54_Y": "10981",
#   "_50000_to_74999S": "15023",
#   "_55_to_64_Y": "12319",
#   "_65_to_74_Y": "11248",
#   "_6_to_18_Y": "15698",
#   "_75000_to_99999S": "16025",
#   "_75_and_Older": "7780"
#  },
#  {
#   "African_American": "8568",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "13193",
#   "County": "Lauderdale County",
#   "Female": "41352",
#   "Foreign_Born": "411",
#   "High_School_or_Equivalet": "18102",
#   "Hispanic": "56833",
#   "Less_than_High_School": "7055",
#   "Male": "39748",
#   "Native_Born": "80689",
#   "Naturalized": "381",
#   "Not_a_Citizen": "30",
#   "Over_100000S": "18917",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "16323",
#   "Some_Other_Race": "31703",
#   "State": "Alabama",
#   "Total_Population": "81100",
#   "Under_25000S": "13822",
#   "Under_6_Y": "3727",
#   "White": "70323",
#   "_19_to_25_Y": "8117",
#   "_25000_to_49999S": "18496",
#   "_26_to_34_Y": "7201",
#   "_35_to_44_Y": "7951",
#   "_45_to_54_Y": "9189",
#   "_50000_to_74999S": "13848",
#   "_55_to_64_Y": "11304",
#   "_65_to_74_Y": "11248",
#   "_6_to_18_Y": "14583",
#   "_75000_to_99999S":
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# 04",
#   "Male": "48210",
#   "Native_Born": "95693",
#   "Naturalized": "1031",
#   "Not_a_Citizen": "1051",
#   "Over_100000S": "42394",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "20803",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "97775",
#   "Under_25000S": "12375",
#   "Under_6_Y": "6768",
#   "White": "85815",
#   "_19_to_25_Y": "8340",
#   "_25000_to_49999S": "11632",
#   "_26_to_34_Y": "10435",
#   "_35_to_44_Y": "11627",
#   "_45_to_54_Y": "13087",
#   "_50000_to_74999S": "14009",
#   "_55_to_64_Y": "14829",
#   "_65_to_74_Y": "9915",
#   "_6_to_18_Y": "16316",
#   "_75000_to_99999S": "16932",
#   "_75_and_Older": "6458"
#  },
#  {
#   "African_American": "43774",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "204",
#   "County": "Cecil County",
#   "Female": "1721",
#   "Foreign_Born": "830",
#   "High_School_or_Equivalet": "1398",
#   "Hispanic": "1248",
#   "Less_than_High_School": "688",
#   "Male": "2195",
#   "Native_Born": "3086",
#   "Naturalized": "18989",
#   "Not_a_Citizen": "830",
#   "Over_100000S": "1359",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "414",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "3916",
#   "Under_25000S": "188",
#   "Under_6_Y": "147",
#   "White": "3503",
#   "_19_to_25_Y": "755",
#   "_25000_to_49999S": "1302",
#   "_26_to_34_Y": "954",
#   "_35_to_44_Y": "437",
#   "_45_to_54_Y": "655",
#   "_50000_to_74999S": "299",
#   "_55_to_64_Y": "658",
#   "_65_to_74_Y": "22998",
#   "_6_to_18_Y": "310",
#   "_75000_to_99999S": "768",
#   "_75_and_Older": "17869"
#  },
#  {
#   "African_American": "81378",
#   "American_Indian": "7337",
#   "Asian": "5467",
#   "Bachelors_Degree_or_Higher": "30567",
#   "County": "Charles County",
#   "Female": "83936",
#   "Foreign_Born": "12138",
#   "High_School_or_Equivalet": "33986",
#   "Hispanic": "56833",
#   "Less_than_High_School": "7462",
#   "Male": "76678",
#   "Native_Born": "148476",
#   "Naturalized": "6762",
#   "Not_a_Citizen": "5376",
#   "Over_100000S": "98219",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "33281",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "160614",
#   "Under_25000S": "7186",
#   "Under_6_Y": "10136",
#   "White": "65378",
#   "_19_to_25_Y": "14969",
#   "_25000_to_49999S": "14789",
#   "_26_to_34_Y": "16612",
#   "_35_to_44_Y": "21376",
#   "_45_to_54_Y": "24308",
#   "_50000_to_74999S": "19064",
#   "_55_to_64_Y": "22705",
#   "_65_to_74_Y": "12608",
#   "_6_to_18_Y": "30213",
#   "_75000_to_99999S": "21089",
#   "_75_and_Older": "7687"
#  },
#  {
#   "African_American": "78887",
#   "American_Indian": "7337",
#   "Asian": "4882",
#   "Bachelors_Degree_or_Higher": "30300",
#   "County": "Charles County",
#   "Female": "81423",
#   "Foreign_Born": "11390",
#   "High_School_or_Equivalet": "32484",
#   "Hispanic": "56833",
#   "Less_than_High_School": "6448",
#   "Male": "73236",
#   "Native_Born": "143269",
#   "Naturalized": "6467",
#   "Not_a_Citizen": "4923",
#   "Over_100000S": "96631",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "32205",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "154659",
#   "Under_25000S": "6648",
#   "Under_6_Y": "9672",
#   "White": "62895",
#   "_19_to_25_Y": "14760",
#   "_25000_to_49999S": "13984",
#   "_26_to_34_Y": "15541",
#   "_35_to_44_Y": "20348",
#   "_45_to_54_Y": "23714",
#   "_50000_to_74999S": "17711",
#   "_55_to_64_Y": "21747",
#   "_65_to_74_Y": "12400",
#   "_6_to_18_Y": "28790",
#   "_75000_to_99999S": "19425",
#   "_75_and_Older": "7687"
#  },
#  {
#   "African_American": "2491",
#   "American_Indian": "7337",
#   "Asian": "585",
#   "Bachelors_Degree_or_Higher": "267",
#   "County": "Charles County",
#   "Female": "2513",
#   "Foreign_Born": "748",
#   "High_School_or_Equivalet": "1502",
#   "Hispanic": "56833",
#   "Less_than_High_School": "1014",
#   "Male": "3442",
#   "Native_Born": "5207",
#   "Naturalized": "295",
#   "Not_a_Citizen": "453",
#   "Over_100000S": "1588",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "1076",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "5955",
#   "Under_25000S": "538",
#   "Under_6_Y": "464",
#   "White": "2483",
#   "_19_to_25_Y": "209",
#   "_25000_to_49999S": "805",
#   "_26_to_34_Y": "1071",
#   "_35_to_44_Y": "1028",
#   "_45_to_54_Y": "594",
#   "_50000_to_74999S": "1353",
#   "_55_to_64_Y": "958",
#   "_65_to_74_Y": "208",
#   "_6_to_18_Y": "1423",
#   "_75000_to_99999S": "1664",
#   "_75_and_Older": "17869"
#  },
#  {
#   "African_American": "26662",
#   "American_Indian": "7337",
#   "Asian": "12298",
#   "Bachelors_Degree_or_Higher": "72735",
#   "County": "Frederick County",
#   "Female": "130623",
#   "Foreign_Born": "27511",
#   "High_School_or_Equivalet": "42314",
#   "Hispanic": "27315",
#   "Less_than_High_School": "12767",
#   "Male": "126502",
#   "Native_Born": "229614",
#   "Naturalized": "15280",
#   "Not_a_Citizen": "12231",
#   "Over_100000S": "156765",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "45066",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "257125",
#   "Under_25000S": "12026",
#   "Under_6_Y": "18974",
#   "White": "204768",
#   "_19_to_25_Y": "20243",
#   "_25000_to_49999S": "24413",
#   "_26_to_34_Y": "29455",
#   "_35_to_44_Y": "35954",
#   "_45_to_54_Y": "35103",
#   "_50000_to_74999S": "29059",
#   "_55_to_64_Y": "34323",
#   "_65_to_74_Y": "24122",
#   "_6_to_18_Y": "45026",
#   "_75000_to_99999S": "32068",
#   "_75_and_Older": "13925"
#  },
#  {
#   "African_American": "25761",
#   "American_Indian": "7337",
#   "Asian": "11547",
#   "Bachelors_Degree_or_Higher": "71412",
#   "County": "Frederick County",
#   "Female": "125294",
#   "Foreign_Born": "22481",
#   "High_School_or_Equivalet": "39959",
#   "Hispanic": "23031",
#   "Less_than_High_School": "9819",
#   "Male": "120661",
#   "Native_Born": "223474",
#   "Naturalized": "14393",
#   "Not_a_Citizen": "8088",
#   "Over_100000S": "152333",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "43223",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "245955",
#   "Under_25000S": "11322",
#   "Under_6_Y": "18808",
#   "White": "195838",
#   "_19_to_25_Y": "18340",
#   "_25000_to_49999S": "22305",
#   "_26_to_34_Y": "27923",
#   "_35_to_44_Y": "32339",
#   "_45_to_54_Y": "33616",
#   "_50000_to_74999S": "27043",
#   "_55_to_64_Y": "32574",
#   "_65_to_74_Y": "24036",
#   "_6_to_18_Y": "44394",
#   "_75000_to_99999S": "30388",
#   "_75_and_Older": "13925"
#  },
#  {
#   "African_American": "901",
#   "American_Indian": "7337",
#   "Asian": "751",
#   "Bachelors_Degree_or_Higher": "1323",
#   "County": "Frederick County",
#   "Female": "5329",
#   "Foreign_Born": "5030",
#   "High_School_or_Equivalet": "2355",
#   "Hispanic": "4284",
#   "Less_than_High_School": "2948",
#   "Male": "5841",
#   "Native_Born": "6140",
#   "Naturalized": "887",
#   "Not_a_Citizen": "4143",
#   "Over_100000S": "4432",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "1843",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "11170",
#   "Under_25000S": "704",
#   "Under_6_Y": "166",
#   "White": "8930",
#   "_19_to_25_Y": "1903",
#   "_25000_to_49999S": "2108",
#   "_26_to_34_Y": "1532",
#   "_35_to_44_Y": "3615",
#   "_45_to_54_Y": "1487",
#   "_50000_to_74999S": "2016",
#   "_55_to_64_Y": "1749",
#   "_65_to_74_Y": "86",
#   "_6_to_18_Y": "632",
#   "_75000_to_99999S": "1680",
#   "_75_and_Older": "17869"
#  },
#  {
#   "African_American": "35854",
#   "American_Indian": "7337",
#   "Asian": "7299",
#   "Bachelors_Degree_or_Higher": "64240",
#   "County": "Harford County",
#   "Female": "130025",
#   "Foreign_Born": "12094",
#   "High_School_or_Equivalet": "43936",
#   "Hispanic": "12173",
#   "Less_than_High_School": "10816",
#   "Male": "123463",
#   "Native_Born": "241394",
#   "Naturalized": "9604",
#   "Not_a_Citizen": "2490",
#   "Over_100000S": "141268",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "54365",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "253488",
#   "Under_25000S": "16871",
#   "Under_6_Y": "17480",
#   "White": "198168",
#   "_19_to_25_Y": "20370",
#   "_25000_to_49999S": "26983",
#   "_26_to_34_Y": "27580",
#   "_35_to_44_Y": "31553",
#   "_45_to_54_Y": "35578",
#   "_50000_to_74999S": "31830",
#   "_55_to_64_Y": "36911",
#   "_65_to_74_Y": "24782",
#   "_6_to_18_Y": "42281",
#   "_75000_to_99999S": "36251",
#   "_75_and_Older": "16953"
#  },
#  {
#   "African_American": "34375",
#   "American_Indian": "7337",
#   "Asian": "6976",
#   "Bachelors_Degree_or_Higher": "62932",
#   "County": "Harford County",
#   "Female": "125812",
#   "Foreign_Born": "11516",
#   "High_School_or_Equivalet": "41478",
#   "Hispanic": "11023",
#   "Less_than_High_School": "10442",
#   "Male": "119761",
#   "Native_Born": "234057",
#   "Naturalized": "9261",
#   "Not_a_Citizen": "2255",
#   "Over_100000S": "137730",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "52179",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "245573",
#   "Under_25000S": "15824",
#   "Under_6_Y": "16987",
#   "White": "192421",
#   "_19_to_25_Y": "19979",
#   "_25000_to_49999S": "25488",
#   "_26_to_34_Y": "25768",
#   "_35_to_44_Y": "29668",
#   "_45_to_54_Y": "34479",
#   "_50000_to_74999S": "30801",
#   "_55_to_64_Y": "35417",
#   "_65_to_74_Y": "24773",
#   "_6_to_18_Y": "41576",
#   "_75000_to_99999S": "35481",
#   "_75_and_Older": "16926"
#  },
#  {
#   "African_American": "1479",
#   "American_Indian": "7337",
#   "Asian": "323",
#   "Bachelors_Degree_or_Higher": "1308",
#   "County": "Harford County",
#   "Female": "4213",
#   "Foreign_Born": "578",
#   "High_School_or_Equivalet": "2458",
#   "Hispanic": "1150",
#   "Less_than_High_School": "374",
#   "Male": "3702",
#   "Native_Born": "7337",
#   "Naturalized": "343",
#   "Not_a_Citizen": "235",
#   "Over_100000S": "3538",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "2186",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "7915",
#   "Under_25000S": "1047",
#   "Under_6_Y": "493",
#   "White": "5747",
#   "_19_to_25_Y": "391",
#   "_25000_to_49999S": "1495",
#   "_26_to_34_Y": "1812",
#   "_35_to_44_Y": "1885",
#   "_45_to_54_Y": "1099",
#   "_50000_to_74999S": "1029",
#   "_55_to_64_Y": "1494",
#   "_65_to_74_Y": "9",
#   "_6_to_18_Y": "705",
#   "_75000_to_99999S": "770",
#   "_75_and_Older": "27"
#  },
#  {
#   "African_American": "63025",
#   "American_Indian": "7337",
#   "Asian": "60235",
#   "Bachelors_Degree_or_Higher": "139773",
#   "County": "Howard County",
#   "Female": "166178",
#   "Foreign_Born": "68067",
#   "High_School_or_Equivalet": "28347",
#   "Hispanic": "23794",
#   "Less_than_High_School": "10195",
#   "Male": "156074",
#   "Native_Born": "254185",
#   "Naturalized": "40640",
#   "Not_a_Citizen": "27427",
#   "Over_100000S": "219899",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "36872",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "322252",
#   "Under_25000S": "16159",
#   "Under_6_Y": "22729",
#   "White": "177311",
#   "_19_to_25_Y": "23562",
#   "_25000_to_49999S": "25865",
#   "_26_to_34_Y": "35759",
#   "_35_to_44_Y": "45336",
#   "_45_to_54_Y": "45433",
#   "_50000_to_74999S": "23473",
#   "_55_to_64_Y": "42616",
#   "_65_to_74_Y": "28151",
#   "_6_to_18_Y": "60774",
#   "_75000_to_99999S": "35769",
#   "_75_and_Older": "17892"
#  },
#  {
#   "African_American": "58366",
#   "American_Indian": "7337",
#   "Asian": "57524",
#   "Bachelors_Degree_or_Higher": "135871",
#   "County": "Howard County",
#   "Female": "158633",
#   "Foreign_Born": "60356",
#   "High_School_or_Equivalet": "26616",
#   "Hispanic": "19050",
#   "Less_than_High_School": "7967",
#   "Male": "149012",
#   "Native_Born": "247289",
#   "Naturalized": "38527",
#   "Not_a_Citizen": "21829",
#   "Over_100000S": "214295",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "34119",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "307645",
#   "Under_25000S": "14991",
#   "Under_6_Y": "21205",
#   "White": "171274",
#   "_19_to_25_Y": "22261",
#   "_25000_to_49999S": "22763",
#   "_26_to_34_Y": "31057",
#   "_35_to_44_Y": "43260",
#   "_45_to_54_Y": "44112",
#   "_50000_to_74999S": "22607",
#   "_55_to_64_Y": "40977",
#   "_65_to_74_Y": "27388",
#   "_6_to_18_Y": "59606",
#   "_75000_to_99999S": "32386",
#   "_75_and_Older": "17779"
#  },
#  {
#   "African_American": "4659",
#   "American_Indian": "7337",
#   "Asian": "2711",
#   "Bachelors_Degree_or_Higher": "3902",
#   "County": "Howard County",
#   "Female": "7545",
#   "Foreign_Born": "7711",
#   "High_School_or_Equivalet": "1731",
#   "Hispanic": "4744",
#   "Less_than_High_School": "2228",
#   "Male": "7062",
#   "Native_Born": "6896",
#   "Naturalized": "2113",
#   "Not_a_Citizen": "5598",
#   "Over_100000S": "5604",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "2753",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "14607",
#   "Under_25000S": "1168",
#   "Under_6_Y": "1524",
#   "White": "6037",
#   "_19_to_25_Y": "1301",
#   "_25000_to_49999S": "3102",
#   "_26_to_34_Y": "4702",
#   "_35_to_44_Y": "2076",
#   "_45_to_54_Y": "1321",
#   "_50000_to_74999S": "866",
#   "_55_to_64_Y": "1639",
#   "_65_to_74_Y": "763",
#   "_6_to_18_Y": "1168",
#   "_75000_to_99999S": "3383",
#   "_75_and_Older": "113"
#  },
#  {
#   "African_American": "196737",
#   "American_Indian": "7337",
#   "Asian": "156415",
#   "Bachelors_Degree_or_Higher": "410023",
#   "County": "Montgomery County",
#   "Female": "538507",
#   "Foreign_Born": "339537",
#   "High_School_or_Equivalet": "101255",
#   "Hispanic": "209617",
#   "Less_than_High_School": "69679",
#   "Male": "502241",
#   "Native_Born": "701211",
#   "Naturalized": "185002",
#   "Not_a_Citizen": "154535",
#   "Over_100000S": "630249",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "125256",
#   "Some_Other_Race": "106713",
#   "State": "Maryland",
#   "Total_Population": "1040748",
#   "Under_25000S": "67459",
#   "Under_6_Y": "75153",
#   "White": "531505",
#   "_19_to_25_Y": "79810",
#   "_25000_to_49999S": "98688",
#   "_26_to_34_Y": "117144",
#   "_35_to_44_Y": "143537",
#   "_45_to_54_Y": "143308",
#   "_50000_to_74999S": "122068",
#   "_55_to_64_Y": "136949",
#   "_65_to_74_Y": "94355",
#   "_6_to_18_Y": "179572",
#   "_75000_to_99999S": "119831",
#   "_75_and_Older": "70920"
#  },
#  {
#   "African_American": "182266",
#   "American_Indian": "7337",
#   "Asian": "149332",
#   "Bachelors_Degree_or_Higher": "400323",
#   "County": "Montgomery County",
#   "Female": "502976",
#   "Foreign_Born": "281793",
#   "High_School_or_Equivalet": "83583",
#   "Hispanic": "162612",
#   "Less_than_High_School": "45852",
#   "Male": "459568",
#   "Native_Born": "680751",
#   "Naturalized": "176029",
#   "Not_a_Citizen": "105764",
#   "Over_100000S": "605235",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "115768",
#   "Some_Other_Race": "71271",
#   "State": "Maryland",
#   "Total_Population": "962544",
#   "Under_25000S": "57008",
#   "Under_6_Y": "73373",
#   "White": "512612",
#   "_19_to_25_Y": "70148",
#   "_25000_to_49999S": "85486",
#   "_26_to_34_Y": "99290",
#   "_35_to_44_Y": "123788",
#   "_45_to_54_Y": "131144",
#   "_50000_to_74999S": "104130",
#   "_55_to_64_Y": "128866",
#   "_65_to_74_Y": "92654",
#   "_6_to_18_Y": "173497",
#   "_75000_to_99999S": "108400",
#   "_75_and_Older": "69784"
#  },
#  {
#   "African_American": "14471",
#   "American_Indian": "7337",
#   "Asian": "7083",
#   "Bachelors_Degree_or_Higher": "9700",
#   "County": "Montgomery County",
#   "Female": "35531",
#   "Foreign_Born": "57744",
#   "High_School_or_Equivalet": "17672",
#   "Hispanic": "47005",
#   "Less_than_High_School": "23827",
#   "Male": "42673",
#   "Native_Born": "20460",
#   "Naturalized": "8973",
#   "Not_a_Citizen": "48771",
#   "Over_100000S": "25014",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "9488",
#   "Some_Other_Race": "35442",
#   "State": "Maryland",
#   "Total_Population": "78204",
#   "Under_25000S": "10451",
#   "Under_6_Y": "1780",
#   "White": "18893",
#   "_19_to_25_Y": "9662",
#   "_25000_to_49999S": "13202",
#   "_26_to_34_Y": "17854",
#   "_35_to_44_Y": "19749",
#   "_45_to_54_Y": "12164",
#   "_50000_to_74999S": "17938",
#   "_55_to_64_Y": "8083",
#   "_65_to_74_Y": "1701",
#   "_6_to_18_Y": "6075",
#   "_75000_to_99999S": "11431",
#   "_75_and_Older": "1136"
#  },
#  {
#   "African_American": "557559",
#   "American_Indian": "7337",
#   "Asian": "37115",
#   "Bachelors_Degree_or_Higher": "201976",
#   "County": "Prince George's County",
#   "Female": "470441",
#   "Foreign_Born": "214047",
#   "High_School_or_Equivalet": "155617",
#   "Hispanic": "177105",
#   "Less_than_High_School": "81787",
#   "Male": "431677",
#   "Native_Born": "688071",
#   "Naturalized": "89424",
#   "Not_a_Citizen": "124623",
#   "Over_100000S": "442099",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "162431",
#   "Some_Other_Race": "133948",
#   "State": "Maryland",
#   "Total_Population": "902118",
#   "Under_25000S": "64623",
#   "Under_6_Y": "69898",
#   "White": "143256",
#   "_19_to_25_Y": "84969",
#   "_25000_to_49999S": "110088",
#   "_26_to_34_Y": "115723",
#   "_35_to_44_Y": "120933",
#   "_45_to_54_Y": "121500",
#   "_50000_to_74999S": "138081",
#   "_55_to_64_Y": "119347",
#   "_65_to_74_Y": "78463",
#   "_6_to_18_Y": "145440",
#   "_75000_to_99999S": "132872",
#   "_75_and_Older": "45845"
#  },
#  {
#   "African_American": "525468",
#   "American_Indian": "7337",
#   "Asian": "34711",
#   "Bachelors_Degree_or_Higher": "193851",
#   "County": "Prince George's County",
#   "Female": "433780",
#   "Foreign_Born": "152101",
#   "High_School_or_Equivalet": "137161",
#   "Hispanic": "126559",
#   "Less_than_High_School": "55652",
#   "Male": "379554",
#   "Native_Born": "661233",
#   "Naturalized": "82807",
#   "Not_a_Citizen": "69294",
#   "Over_100000S": "408580",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "149421",
#   "Some_Other_Race": "92691",
#   "State": "Maryland",
#   "Total_Population": "813334",
#   "Under_25000S": "55035",
#   "Under_6_Y": "67514",
#   "White": "131599",
#   "_19_to_25_Y": "74127",
#   "_25000_to_49999S": "96435",
#   "_26_to_34_Y": "93138",
#   "_35_to_44_Y": "99695",
#   "_45_to_54_Y": "110011",
#   "_50000_to_74999S": "119055",
#   "_55_to_64_Y": "111629",
#   "_65_to_74_Y": "76196",
#   "_6_to_18_Y": "135608",
#   "_75000_to_99999S": "119949",
#   "_75_and_Older": "45416"
#  },
#  {
#   "African_American": "32091",
#   "American_Indian": "7337",
#   "Asian": "2404",
#   "Bachelors_Degree_or_Higher": "8125",
#   "County": "Prince George's County",
#   "Female": "36661",
#   "Foreign_Born": "61946",
#   "High_School_or_Equivalet": "18456",
#   "Hispanic": "50546",
#   "Less_than_High_School": "26135",
#   "Male": "52123",
#   "Native_Born": "26838",
#   "Naturalized": "6617",
#   "Not_a_Citizen": "55329",
#   "Over_100000S": "33519",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "13010",
#   "Some_Other_Race": "41257",
#   "State": "Maryland",
#   "Total_Population": "88784",
#   "Under_25000S": "9588",
#   "Under_6_Y": "2384",
#   "White": "11657",
#   "_19_to_25_Y": "10842",
#   "_25000_to_49999S": "13653",
#   "_26_to_34_Y": "22585",
#   "_35_to_44_Y": "21238",
#   "_45_to_54_Y": "11489",
#   "_50000_to_74999S": "19026",
#   "_55_to_64_Y": "7718",
#   "_65_to_74_Y": "2267",
#   "_6_to_18_Y": "9832",
#   "_75000_to_99999S": "12923",
#   "_75_and_Older": "429"
#  },
#  {
#   "African_American": "43774",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "22039",
#   "County": "St. Mary's County",
#   "Female": "56215",
#   "Foreign_Born": "5895",
#   "High_School_or_Equivalet": "24819",
#   "Hispanic": "6257",
#   "Less_than_High_School": "6895",
#   "Male": "54765",
#   "Native_Born": "105085",
#   "Naturalized": "3935",
#   "Not_a_Citizen": "1960",
#   "Over_100000S": "58768",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "17837",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "110980",
#   "Under_25000S": "10077",
#   "Under_6_Y": "7803",
#   "White": "85397",
#   "_19_to_25_Y": "10689",
#   "_25000_to_49999S": "12261",
#   "_26_to_34_Y": "13024",
#   "_35_to_44_Y": "13707",
#   "_45_to_54_Y": "14565",
#   "_50000_to_74999S": "15224",
#   "_55_to_64_Y": "15537",
#   "_65_to_74_Y": "8440",
#   "_6_to_18_Y": "20898",
#   "_75000_to_99999S": "13092",
#   "_75_and_Older": "6317"
#  },
#  {
#   "African_American": "43774",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "21630",
#   "County": "St. Mary's County",
#   "Female": "54789",
#   "Foreign_Born": "5196",
#   "High_School_or_Equivalet": "24406",
#   "Hispanic": "5512",
#   "Less_than_High_School": "5582",
#   "Male": "52594",
#   "Native_Born": "102187",
#   "Naturalized": "3696",
#   "Not_a_Citizen": "1500",
#   "Over_100000S": "57704",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "17294",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "107383",
#   "Under_25000S": "9251",
#   "Under_6_Y": "7715",
#   "White": "82668",
#   "_19_to_25_Y": "10126",
#   "_25000_to_49999S": "12188",
#   "_26_to_34_Y": "12742",
#   "_35_to_44_Y": "12713",
#   "_45_to_54_Y": "13796",
#   "_50000_to_74999S": "14036",
#   "_55_to_64_Y": "15006",
#   "_65_to_74_Y": "8338",
#   "_6_to_18_Y": "20630",
#   "_75000_to_99999S": "12675",
#   "_75_and_Older": "6317"
#  },
#  {
#   "African_American": "43774",
#   "American_Indian": "7337",
#   "Asian": "32063",
#   "Bachelors_Degree_or_Higher": "409",
#   "County": "St. Mary's County",
#   "Female": "1426",
#   "Foreign_Born": "699",
#   "High_School_or_Equivalet": "413",
#   "Hispanic": "745",
#   "Less_than_High_School": "1313",
#   "Male": "2171",
#   "Native_Born": "2898",
#   "Naturalized": "239",
#   "Not_a_Citizen": "460",
#   "Over_100000S": "1064",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "543",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "3597",
#   "Under_25000S": "826",
#   "Under_6_Y": "88",
#   "White": "2729",
#   "_19_to_25_Y": "563",
#   "_25000_to_49999S": "73",
#   "_26_to_34_Y": "282",
#   "_35_to_44_Y": "994",
#   "_45_to_54_Y": "769",
#   "_50000_to_74999S": "1188",
#   "_55_to_64_Y": "531",
#   "_65_to_74_Y": "102",
#   "_6_to_18_Y": "268",
#   "_75000_to_99999S": "417",
#   "_75_and_Older": "17869"
#  },
#  {
#   "African_American": "13669",
#   "American_Indian": "7337",
#   "Asian": "2888",
#   "Bachelors_Degree_or_Higher": "23276",
#   "County": "Washington County",
#   "Female": "73696",
#   "Foreign_Born": "8921",
#   "High_School_or_Equivalet": "35674",
#   "Hispanic": "8091",
#   "Less_than_High_School": "11130",
#   "Male": "69470",
#   "Native_Born": "134245",
#   "Naturalized": "4206",
#   "Not_a_Citizen": "4715",
#   "Over_100000S": "50201",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Total",
#   "Some_College": "27457",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "143166",
#   "Under_25000S": "17768",
#   "Under_6_Y": "10461",
#   "White": "118831",
#   "_19_to_25_Y": "11213",
#   "_25000_to_49999S": "27503",
#   "_26_to_34_Y": "16090",
#   "_35_to_44_Y": "17444",
#   "_45_to_54_Y": "19104",
#   "_50000_to_74999S": "25913",
#   "_55_to_64_Y": "19812",
#   "_65_to_74_Y": "14759",
#   "_6_to_18_Y": "23955",
#   "_75000_to_99999S": "21040",
#   "_75_and_Older": "10328"
#  },
#  {
#   "African_American": "12815",
#   "American_Indian": "7337",
#   "Asian": "2732",
#   "Bachelors_Degree_or_Higher": "22925",
#   "County": "Washington County",
#   "Female": "70196",
#   "Foreign_Born": "7344",
#   "High_School_or_Equivalet": "34148",
#   "Hispanic": "7139",
#   "Less_than_High_School": "8716",
#   "Male": "65488",
#   "Native_Born": "128340",
#   "Naturalized": "4136",
#   "Not_a_Citizen": "3208",
#   "Over_100000S": "48373",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Insured",
#   "Some_College": "26028",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "135684",
#   "Under_25000S": "16998",
#   "Under_6_Y": "9860",
#   "White": "112818",
#   "_19_to_25_Y": "10565",
#   "_25000_to_49999S": "25854",
#   "_26_to_34_Y": "14037",
#   "_35_to_44_Y": "15593",
#   "_45_to_54_Y": "18267",
#   "_50000_to_74999S": "23851",
#   "_55_to_64_Y": "18833",
#   "_65_to_74_Y": "14759",
#   "_6_to_18_Y": "23442",
#   "_75000_to_99999S": "19984",
#   "_75_and_Older": "10328"
#  },
#  {
#   "African_American": "854",
#   "American_Indian": "7337",
#   "Asian": "156",
#   "Bachelors_Degree_or_Higher": "351",
#   "County": "Washington County",
#   "Female": "3500",
#   "Foreign_Born": "1577",
#   "High_School_or_Equivalet": "1526",
#   "Hispanic": "952",
#   "Less_than_High_School": "2414",
#   "Male": "3982",
#   "Native_Born": "5905",
#   "Naturalized": "70",
#   "Not_a_Citizen": "1507",
#   "Over_100000S": "1828",
#   "Pacific_Islander": "9729",
#   "Population_Category": "Uninsured",
#   "Some_College": "1429",
#   "Some_Other_Race": "31703",
#   "State": "Maryland",
#   "Total_Population": "7482",
#   "Under_25000S": "770",
#   "Under_6_Y": "601",
#   "White": "6013",
#   "_19_to_25_Y": "648",
#   "_25000_to_49999S": "1649",
#   "_26_to_34_Y": "2053",
#   "_35_to_44_Y": "1851",
#   "_45_to_54_Y": "837",
#   "_50000_to_74999S": "2062",
#   "_55_to_64_Y": "979",
#   "_65_to_74_Y": "22998",
#   "_6_to_18_Y": "513",
#   "_75000_to_99999S": "1056",
#   "_75_and_Older": "17869"
#  }
# ]

# %%
health = spark.createDataFrame(healthListDict).select('State', 'County', 'Population_Category', 'Total_Population', 'Under_6_Y', '_6_to_18_Y', '_19_to_25_Y', '_26_to_34_Y', '_35_to_44_Y', '_45_to_54_Y', '_55_to_64_Y', '_65_to_74_Y', '_75_and_Older', 'Male', 'Female', 'White', 'African_American', 'American_Indian', 'Asian', 'Pacific_Islander', 'Some_Other_Race', 'Hispanic', 'Native_Born', 'Foreign_Born', 'Naturalized', 'Not_a_Citizen', 'Less_than_High_School', 'High_School_or_Equivalet', 'Some_College', 'Bachelors_Degree_or_Higher', 'Under_25000S', '_25000_to_49999S', '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S')

# %% [markdown]
# *Replacing State and County name with State and County ID from tables*

# %%
for i in States.StateName:
    health['State'].replace(i, int(States.loc[States['StateName'] == i, 'StateID']), inplace = True)

for i in Counties.CountyName:
    health['County'].replace(i, int(Counties.loc[Counties['CountyName'] == i, 'CountyID']), inplace = True)

health.columns = ['StateID', 'CountyID', 'Population_Category', 'Total_Population',
       'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y',
       '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male',
       'Female', 'White', 'African_American', 'American_Indian', 'Asian',
       'Pacific_Islander', 'Some_Other_Race', 'Hispanic', 'Native_Born',
       'Foreign_Born', 'Naturalized', 'Not_a_Citizen', 'Less_than_High_School',
       'High_School_or_Equivalent', 'Some_College',
       'Bachelors_or_Higher', 'Under_25000S', '_25000_to_49999S',
       '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']

columns = ['Total_Population',
       'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y',
       '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male',
       'Female', 'White', 'African_American', 'American_Indian', 'Asian',
       'Pacific_Islander', 'Some_Other_Race', 'Hispanic', 'Native_Born',
       'Foreign_Born', 'Naturalized', 'Not_a_Citizen', 'Less_than_High_School',
       'High_School_or_Equivalent', 'Some_College',
       'Bachelors_or_Higher', 'Under_25000S', '_25000_to_49999S',
       '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']

for i in columns:
    health[i] = health[i].astype('int')

healthID = []
for i in range(1, health.shape[0]+1):
    healthID.append(i)

health2 = health.sort_values(by = ['StateID', 'CountyID']).copy()

health2['HealthID'] = healthID
health2 = health2[['HealthID', 'StateID', 'CountyID', 'Population_Category', 'Total_Population',
       'Under_6Y', '_6_to_18Y', '_19_to_25Y', '_26_to_34Y', '_35_to_44Y',
       '_45_to_54Y', '_55_to_64Y', '_65_to_74Y', '_75_and_Older', 'Male',
       'Female', 'White', 'African_American', 'American_Indian', 'Asian',
       'Pacific_Islander', 'Some_Other_Race', 'Hispanic', 'Native_Born',
       'Foreign_Born', 'Naturalized', 'Not_a_Citizen', 'Less_than_High_School',
       'High_School_or_Equivalent', 'Some_College',
       'Bachelors_or_Higher', 'Under_25000S', '_25000_to_49999S',
       '_50000_to_74999S', '_75000_to_99999S', 'Over_100000S']]

health = spark.createDataFrame(health)
health2 = spark.createDataFrame(health2)

# %%
States = spark.createDataFrame(States)
Counties = spark.createDataFrame(Counties)

# %% [markdown]
# **SQL Connection**

# %%
database = "Healthcare-Capstone"
user = "HealthKylee"
password  = "IWantToBeADataScientist123!@#"
server = "gen10-data-fundamentals-22-07-sql-server.database.windows.net"

# %%
table = 'dbo.County'

CountyCheck = spark.read.format("jdbc") \
    .option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .option("dbtable", table) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .load()

if CountyCheck.count() != 1_999: # Total number of rows in dataset
    Counties.select('CountyName').sort('CountyName').write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
        .mode("append") \
        .option("dbtable", table) \
        .option("user", user) \
        .option("password", password) \
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
        .save()

# %%
table = "dbo.State"

StateCheck = spark.read.format("jdbc") \
    .option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .option("dbtable", table) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .load()

if StateCheck.count() != 56: # Total number of rows in dataset
    States.select('StateName').sort('StateName').write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
        .mode("append") \
        .option("dbtable", table) \
        .option("user", user) \
        .option("password", password) \
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
        .save()

# %%
table = "dbo.HealthInsurance"

healthNew = spark.read.format("jdbc") \
    .option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .option("dbtable", table) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .load()

# Adding the first 
if healthNew.count() != 2520: # Total number of rows in original dataset
    health.sort('StateID', 'CountyID').write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
        .mode("append") \
        .option("dbtable", table) \
        .option("user", user) \
        .option("password", password) \
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
        .save()

else:
    health2.sort('StateID', 'CountyID').write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
        .mode("overwrite") \
        .option("dbtable", table) \
        .option("user", user) \
        .option("password", password) \
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
        .save()
